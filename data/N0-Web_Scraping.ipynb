# %% [markdown]
# We want to get the CPU model specifications by scraping the web.
#
# The main source I have found is: "https://www.techpowerup.com/cpu-specs/"

# %%
import time, random, re
from typing import Dict, Iterable, Tuple, List, Optional
from urllib.parse import quote_plus, urljoin

import dill as pickle
import pandas as pd

import requests
from bs4 import BeautifulSoup
from rapidfuzz import process, fuzz
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
# --- FULL UNDERLYING FUNCTIONS (serial, robots-aware, adaptive backoff) ---
# pip install requests beautifulsoup4 lxml rapidfuzz
from io import StringIO

import time, random, re
from typing import Dict, Iterable, Tuple, List, Optional
from urllib.parse import quote_plus, urljoin, urlparse
from email.utils import parsedate_to_datetime
from functools import lru_cache
import urllib.robotparser as robotparser

import requests
from bs4 import BeautifulSoup
from rapidfuzz import process, fuzz
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# -------- constants --------
BASE = "https://www.techpowerup.com"
CPU_SEARCH = f"{BASE}/cpu-specs/?q="
CPU_PAGE_RE = re.compile(r"^/cpu-specs/[^/]+\.c\d+/?$")
USER_AGENT = "Mozilla/5.0 (compatible; SpecScraper/2.0)"

# -------- pacing (strictly serial) --------
MIN_GAP_S = 8.0            # min pause between ANY two requests (seconds)
MAX_GAP_S = 30.0           # cap for adaptive backoff
JITTER = (30, 120)        # extra randomness to avoid cadence
ADAPTIVE_BACKOFF = True

# -------- HTTP session (no parallelism) --------
def _build_session() -> requests.Session:
    s = requests.Session()
    s.headers.update({"User-Agent": USER_AGENT})
    # Handle network flakiness; 429 handled manually
    retry = Retry(
        total=3, connect=3, read=3, backoff_factor=0.6,
        status_forcelist=[500, 502, 503, 504],
        allowed_methods=["GET", "HEAD"]
    )
    s.mount("https://", HTTPAdapter(max_retries=retry, pool_connections=1, pool_maxsize=1))
    s.mount("http://",  HTTPAdapter(max_retries=retry, pool_connections=1, pool_maxsize=1))
    return s

_SESSION = _build_session()
_last_hit = 0.0              # monotonic timestamp of last successful GET
_curr_gap = MIN_GAP_S        # adaptive min gap (AIMD behavior)

# -------- robots.txt (disallow + crawl-delay) --------
_ROBOTS = None
_ROBOTS_LAST_LOAD = 0.0
_ROBOTS_TTL = 60 * 30  # refresh robots every 30 minutes

def _load_robots(force: bool = False):
    global _ROBOTS, _ROBOTS_LAST_LOAD
    now = time.monotonic()
    if force or _ROBOTS is None or (now - _ROBOTS_LAST_LOAD) > _ROBOTS_TTL:
        rp = robotparser.RobotFileParser()
        rp.set_url(urljoin(BASE, "/robots.txt"))
        try:
            rp.read()
            _ROBOTS = rp
            _ROBOTS_LAST_LOAD = now
        except Exception:
            _ROBOTS = None  # fail open; change to fail-closed if you prefer

def _robots_crawl_delay() -> Optional[float]:
    _load_robots()
    if _ROBOTS is None:
        return None
    delay = _ROBOTS.crawl_delay(USER_AGENT)
    if delay is None:
        delay = _ROBOTS.crawl_delay("*")
    return float(delay) if delay is not None else None

def _robots_can_fetch(url: str) -> bool:
    _load_robots()
    if _ROBOTS is None:
        return True  # fail open
    return _ROBOTS.can_fetch(USER_AGENT, url)

# Bootstrap adaptive gap from robots.txt crawl-delay if present
_rd = _robots_crawl_delay()
if _rd:
    _curr_gap = max(_curr_gap, _rd)

# -------- pacing helpers --------
def _sleep_gap():
    """Wait the current adaptive gap plus jitter before issuing a request."""
    global _last_hit
    now = time.monotonic()
    # Respect robots crawl-delay as a floor each time (it may change)
    rd = _robots_crawl_delay()
    floor = max(MIN_GAP_S, rd) if rd else MIN_GAP_S
    gap_target = max(_curr_gap if ADAPTIVE_BACKOFF else MIN_GAP_S, floor)
    wait = gap_target - (now - _last_hit)
    if wait > 0:
        time.sleep(wait)
    time.sleep(random.uniform(*JITTER))  # jitter every time

def _parse_retry_after(v: Optional[str]) -> Optional[float]:
    if not v:
        return None
    v = v.strip()
    if v.isdigit():
        return float(v)
    try:
        tgt = parsedate_to_datetime(v)
        now = parsedate_to_datetime(time.strftime("%a, %d %b %Y %H:%M:%S GMT", time.gmtime()))
        return max(0.0, (tgt - now).total_seconds())
    except Exception:
        return None

def _on_success():
    global _curr_gap
    if ADAPTIVE_BACKOFF:
        _curr_gap = max(MIN_GAP_S, _curr_gap - 0.5)  # gentle recovery

def _on_throttle(retry_after: Optional[float]):
    global _curr_gap
    if ADAPTIVE_BACKOFF:
        _curr_gap = min(MAX_GAP_S, max(MIN_GAP_S * 2, _curr_gap * 2))  # multiplicative increase
    time.sleep((retry_after if retry_after is not None else 10.0) + random.uniform(*JITTER))

def _polite_get(url: str, timeout=(5, 20)) -> requests.Response:
    """Strictly serial GET: robots-aware + min gap + jitter + 429/503 backoff."""
    global _last_hit
    # robots disallow check
    if not _robots_can_fetch(url):
        raise PermissionError(f"Blocked by robots.txt: {url}")

    _sleep_gap()
    resp = _SESSION.get(url, timeout=timeout)

    if resp.status_code in (429, 503):
        ra = _parse_retry_after(resp.headers.get("Retry-After"))
        _on_throttle(ra)
        _sleep_gap()
        resp = _SESSION.get(url, timeout=timeout)

    resp.raise_for_status()
    _last_hit = time.monotonic()
    _on_success()
    return resp

def fetch_html(url: str) -> str:
    """Download HTML with the polite session/limits."""
    return _polite_get(url).text

# -------- normalization helpers (for matching) --------
_TM_RE = re.compile(r"[™®©]")
PARENS_RE = re.compile(r"\((?:.*?)\)")
MULTISPACE_RE = re.compile(r"\s+")
NON_ALNUM_SPACE_RE = re.compile(r"[^0-9a-z]+")

_LEADING_MULTI_RE = re.compile(r"^\s*(\d+)\s*(?:x|×)\s*", re.I)
_TRAILING_CORES_THREADS_RE = re.compile(
    r"""\s*(?:\(\s*)?(?:[/,]|and)?\s*\d+\s*-?\s*(?:core|cores|c)\b
        (?:\s*(?:[/,]|and)\s*\d+\s*-?\s*(?:thread|threads|t)\b)?\s*(?:\)\s*)?\s*$""",
    re.I | re.X,
)

def _strip_multiplier(s: str) -> str:
    return _LEADING_MULTI_RE.sub("", s)

def _strip_core_trailer(s: str) -> str:
    return _TRAILING_CORES_THREADS_RE.sub("", s)

def _simplify_for_match(s: str) -> str:
    s = s.strip()
    s = _strip_multiplier(s)
    s = _strip_core_trailer(s)
    s = s.replace("×", "x").replace("-", " ").replace("_", " ")
    s = _TM_RE.sub("", s)
    s = PARENS_RE.sub("", s)
    s = s.lower()
    s = NON_ALNUM_SPACE_RE.sub(" ", s)
    s = MULTISPACE_RE.sub(" ", s).strip()
    return s

# -------- search results parsing (cached) --------
@lru_cache(maxsize=1024)
def _search_results(query: str) -> List[tuple[str, str]]:
    """Return list of (link_text, absolute_url) from CPU search results (cached in-process)."""
    url = f"{CPU_SEARCH}{quote_plus(query)}"
    soup = BeautifulSoup(_polite_get(url).text, "lxml")
    results = []
    for a in soup.select("a[href]"):
        href = a.get("href", "").strip()
        if CPU_PAGE_RE.match(href):
            abs_url = urljoin(BASE, href)
            text = a.get_text(" ", strip=True) or abs_url
            results.append((text, abs_url))
    return results

def _pick_best(query: str, candidates: List[tuple[str, str]], min_score: int) -> Optional[str]:
    """Rank candidates by fuzzy match to simplified query; return best URL or None."""
    if not candidates:
        return None
    q = _simplify_for_match(query)
    names = [_simplify_for_match(text) for text, _ in candidates]
    best = None
    for scorer in (fuzz.WRatio, fuzz.token_set_ratio, fuzz.token_sort_ratio, fuzz.QRatio, fuzz.partial_ratio):
        cand = process.extractOne(q, names, scorer=scorer)
        if cand and (best is None or cand[1] > best[1]):
            best = cand  # (matched_text, score, idx)
    if best and best[1] >= min_score:
        return candidates[best[2]][1]
    return None

# -------- PUBLIC: strictly-serial resolver via site search --------
def build_model_url_map_via_search(
    models: Iterable[str], *, min_score: int = 86
) -> Tuple[Dict[str, str], Dict[str, dict]]:
    """
    Resolve models to TechPowerUp detail URLs via /cpu-specs/?q=...
    - Serial only: one request at a time
    - robots-aware: disallow + crawl-delay floor
    - adaptive backoff on 429/503 + Retry-After
    """
    model_to_url: Dict[str, str] = {}
    unresolved: Dict[str, dict] = {}
    models = list(models)
    for i, m in enumerate(models, 1):
        start = time.time()
        print(f"[{i}/{len(models)}] {m}")
        # 1) raw query
        results = _search_results(m)
        url = _pick_best(m, results, min_score=min_score)
        # 2) simplified query fallback
        if not url:
            simple_q = _simplify_for_match(m)
            results2 = _search_results(simple_q)
            url = _pick_best(simple_q, results2, min_score=min_score)
        if url:
            model_to_url[m] = url
        else:
            unresolved[m] = {
                "simple_query": _simplify_for_match(m),
                "candidates": results[:3],
            }
        # extra politeness between models (beyond per-request gap)
        time.sleep(random.uniform(*JITTER))
        end = time.time()
        print(f"Iteration taken: {end-start}")
    return model_to_url, unresolved

# %%
# Load model list
with open("CPU_models.pkl", "rb") as f:
    models = pickle.load(f)
    print(models)
# Out:
# ['AMD Ryzen 9 9950X 16-Core' 'AMD RYZEN AI MAX+ 395'
#  'Intel Core i9-13900K' 'AMD Ryzen 7 7700X 8-Core'
#  'AMD Ryzen 9 7950X 16-Core' 'Intel Core i9-14900K'
#  'AMD EPYC 4364P 8-Core' 'AMD Ryzen 9 7900X 12-Core'
#  'Intel Core i9-12900K' 'AMD EPYC 4564P 16-Core' 'AMD EPYC 4464P 12-Core'
#  'AMD EPYC 4584PX 16-Core' 'AMD EPYC 4484PX 12-Core'
#  'AMD Ryzen 9 5900X 12-Core' 'AMD Ryzen 5 7600X 6-Core'
#  'Intel Core i9-11900K' 'AMD Ryzen 9 5950X 16-Core'
#  'AMD Ryzen 7 5800X 8-Core' 'AMD Ryzen 7 5800X3D 8-Core'
#  'Intel Core i9-10900K' 'Intel Core i5-13600K' 'AMD EPYC 4124P 4-Core'
#  'AMD Ryzen Threadripper 3970X 32-Core'
#  'AMD Ryzen Threadripper 3990X 64-Core' 'AMD Ryzen 9 3900XT 12-Core'
#  'Intel Core i5-12600K' 'Intel Core i7-7900X' 'Intel Core i5-11600K'
#  'Intel Core i9-7980XE' 'Intel Core i5-13400' 'AMD Ryzen 7 PRO 5850U'
#  'AMD Ryzen Threadripper 2990WX 32-Core' 'AMD Ryzen 7 PRO 6850U'
#  'AMD Ryzen 5 3600XT 6-Core' 'AMD EPYC 73F3 16-Core'
#  'AMD EPYC 75F3 32-Core' 'AMD Ryzen Threadripper 3960X 24-Core'
#  'AMD EPYC 74F3 24-Core' '2 x AMD EPYC 73F3 16-Core'
#  'Intel Xeon E-2278GEL' 'AMD Ryzen 7 1700 Eight-Core'
#  'ARMv8 Cortex-A78E 12-Core' 'AMD EPYC 7713 64-Core'
#  'Intel Core i9-9900KS' 'AMD EPYC 7F52 16-Core' 'Intel Core i9-9900K'
#  '2 x AMD EPYC 7513 32-Core' '2 x AMD EPYC 7713 64-Core'
#  '2 x AMD EPYC 7F52 16-Core' '2 x AMD EPYC 7763 64-Core'
#  'AMD Ryzen 5 4500U' '2 x Intel Xeon Gold 6248R' 'Intel Core i7-1280P'
#  'AMD EPYC 7542 32-Core' 'AMD EPYC 7742 64-Core' 'Intel Core i7-6700'
#  'AMD EPYC 7502P 32-Core' 'AMD EPYC 7402P 24-Core' 'Intel Xeon Gold 6258R'
#  '2 x AMD EPYC 7742 64-Core' 'Intel Core i7-6800K'
#  'AMD EPYC 7302P 16-Core' 'AMD EPYC 7532 32-Core'
#  'Intel Xeon Platinum 8280' 'AMD EPYC 7552 48-Core'
#  'AMD EPYC 7642 48-Core' 'AMD EPYC 7662 64-Core' 'Intel Xeon E-2388G'
#  'AMD EPYC 7272 12-Core' 'AMD EPYC 7232P 8-Core'
#  '2 x Intel Xeon Gold 5220R' 'AMD EPYC 7282 16-Core'
#  'Intel Xeon Gold 6226R' 'Intel Xeon Gold 5220R'
#  'ARMv8 Cortex-A78E 8-Core' 'AMD Ryzen 7 3800XT 8-Core'
#  'Intel Core i7-8700K' 'AMD Ryzen 7 PRO 3700 8-Core'
#  'AMD Ryzen 9 PRO 3900 12-Core' 'Intel Xeon E5-1680 v3'
#  'Intel Core i7-7700K' 'Intel Xeon E-2278G' 'Intel Core i7-1165G7'
#  'AMD Ryzen 7 2700 Eight-Core' 'AMD Ryzen Threadripper 2970WX 24-Core'
#  'Intel Xeon E5-2687W v3' 'Intel Core i5-9400F'
#  'AMD Ryzen Threadripper 2950X 16-Core' 'Intel Xeon E3-1275 v6'
#  'AMD EPYC 7601 32-Core' 'Intel Core i7-9750H' 'Intel Core i7-8565U'
#  '2 x AMD EPYC 7601 32-Core' 'Intel Xeon E3-1245 v5'
#  'Intel Xeon E3-1280 v5' 'Intel Core i7-1065G7' 'Intel Core i7-4790K'
#  'AMD Ryzen 5 3400G' 'Intel Xeon Silver 4216' 'AMD EPYC 7551 32-Core'
#  'Intel Celeron G6900' 'Intel Core i7-5775C' 'Intel Xeon E5-2609 v4'
#  'Ampere eMAG ARMv8 32-Core' 'Intel Core i7-4600U' '4 x EPYC 9V64H'
#  '2 x Intel Xeon 6980P' '2 x AMD EPYC 9755 128-Core'
#  '2 x AMD EPYC 9575F 64-Core' '2 x AMD EPYC 9655 96-Core'
#  '2 x AMD EPYC 9965 192-Core' '2 x AMD EPYC 9684X 96-Core'
#  '2 x AMD EPYC 9374F 32-Core' '2 x AMD EPYC 9554 64-Core'
#  '2 x AMD EPYC 9384X 32-Core' 'Intel Xeon 6980P'
#  '2 x AMD EPYC 9184X 16-Core' '2 x INTEL XEON PLATINUM 8592+'
#  'AMD EPYC 9755 128-Core' 'AMD EPYC 9575F 64-Core'
#  '2 x Intel Xeon Platinum 8490H' '2 x Intel Xeon Platinum 8468'
#  'AMD EPYC 9655 96-Core' 'AMD EPYC 9965 192-Core'
#  '2 x Intel Xeon Platinum 8462Y+' 'AMD EPYC 9655P 96-Core'
#  '2 x Intel Xeon Gold 6442Y' 'AMD EPYC 9845 160-Core'
#  'AMD EPYC 9684X 96-Core' 'AMD EPYC 9374F 32-Core' 'AMD EPYC 9554 64-Core'
#  'AMD EPYC 9654 96-Core' 'AMD EPYC 9754 128-Core'
#  '2 x Intel Xeon Platinum 8380' '2 x Intel Xeon Platinum 8362'
#  'ARMv8 Neoverse-V2 72-Core' '2 x AMD EPYC 7773X 64-Core'
#  '2 x AMD EPYC 7573X 32-Core' '2 x AMD EPYC 7663 56-Core'
#  '2 x AMD EPYC 74F3 24-Core' '2 x Intel Xeon Gold 6342'
#  '2 x AMD EPYC 7543 32-Core' '2 x AMD EPYC 7373X 16-Core'
#  'AmpereOne 160-Core' 'INTEL XEON PLATINUM 8592+' 'AmpereOne 192-Core'
#  'AmpereOne 128-Core' '2 x AMD EPYC 75F3 32-Core'
#  'ARMv8 Neoverse-V1 64-Core' 'AmpereOne 96-Core'
#  'AMD Ryzen Threadripper PRO 7995WX 96-Cores' '2 x AMD EPYC 7443 24-Core'
#  '2 x AMD EPYC 7343 16-Core' '2 x Intel Xeon Gold 6346'
#  '2 x AMD EPYC 7551 32-Core' 'Intel Xeon Platinum 8468'
#  'Intel Xeon Platinum 8490H' 'Intel Xeon Max 9480'
#  '2 x AMD EPYC 9534 64-Core' 'Intel Xeon Platinum 8471N'
#  'Intel Xeon Platinum 8462Y+' 'Intel Xeon Gold 6442Y'
#  'Ampere ARMv8 Neoverse-N1 256-Core' '2 x AMD EPYC 7F72 24-Core'
#  '2 x Intel Xeon Platinum 8280' 'AmpereOne 64-Core'
#  'AMD Ryzen Threadripper PRO 9995WX 96-Cores' 'AMD EPYC 8534P 64-Core'
#  'AMD EPYC 8534PN 64-Core' 'AMD Ryzen Threadripper 9970X 32-Cores'
#  'AMD EPYC 7573X 32-Core' 'Intel Xeon Platinum 8362'
#  'ARMv8 Neoverse-N1 128-Core' 'AMD EPYC 7773X 64-Core'
#  'Intel Xeon Platinum 8380' 'Intel Xeon Gold 6342' 'AMD EPYC 7543 32-Core'
#  'AMD EPYC 7763 64-Core' 'AMD EPYC 7343 16-Core' 'AMD EPYC 7443 24-Core'
#  'Intel Xeon Gold 6346' 'AMD Ryzen Threadripper 7970X 32-Cores'
#  'AMD Ryzen Threadripper 7980X 64-Cores' 'AMD EPYC 7702 64-Core'
#  '2 x Intel Xeon E5-2699 v4' 'AmpereOne 32-Core'
#  'Ampere ARMv8 Neoverse-N1 128-Core' '2 x Intel Xeon E5-2696 v4'
#  'Intel Core Ultra 9 285K' '2 x Intel Xeon Gold 5218'
#  'AMD Ryzen 9 9900X3D 12-Core' 'Intel Core i9-7960X'
#  'AMD Ryzen 9 9950X3D 16-Core' 'Intel Core i3-14100'
#  'AMD Ryzen 7 9800X3D 8-Core' 'Intel Core i9-10980XE' 'AMD Ryzen 5 8600G'
#  'AMD Ryzen 5 8500G' 'AMD Ryzen 7 7800X3D 8-Core'
#  'AMD Ryzen 9 7900X3D 12-Core' 'AMD Ryzen 9 7950X3D 16-Core'
#  'AMD Ryzen 9 7900 12-Core' 'AMD Ryzen 5 7600 6-Core'
#  'AMD Ryzen 7 7700 8-Core' 'Intel Core i5-14500' 'AMD Ryzen 9 6900HX'
#  'Intel Core i9-12900H' 'Apple M2' 'Intel Core i7-12700K' 'Apple M1'
#  'Intel Core i9-11980HK' 'Intel Core i7-11700K' 'Intel Core i7-11700B'
#  'AMD Ryzen 7 1800X Eight-Core' 'Intel Core i5-10600K'
#  'Intel Core i7-8086K' 'Intel Core i5-8400' 'AMD Ryzen 5 5600G'
#  'AMD Ryzen 5 5600X 6-Core' 'Intel Core i7-7740K' 'AMD Ryzen 3 1300X'
#  'AMD Ryzen 3 3300X 4-Core' 'AMD Ryzen 5 PRO 6650U'
#  'AMD Ryzen 9 3900X 12-Core' 'Intel Core i7-8809G'
#  'AMD Ryzen 7 2700X Eight-Core' 'AMD Ryzen 7 3700X 8-Core'
#  'Intel Core i7-10700T' 'Intel Xeon E-2288G' 'AMD Ryzen 3 2200G'
#  'POWER9 4-Core' 'Intel Core i9-10885H' 'AMD Ryzen 9 3950X 16-Core'
#  'AMD Ryzen 5 2400G' 'Intel Core i7-7700' 'Intel Xeon E-2336'
#  'Intel Core i7-5960X' 'Intel Xeon E3-1260L v5' 'Intel Core i5-6500'
#  'Intel Core i3-10100' 'AMD Custom APU 0405' 'Intel Core i5-6260U'
#  'Intel Xeon E3-1235L v5' 'Intel Xeon E3-1240 v5' 'Intel Core i7-8550U'
#  'Intel Xeon E3-1270 v5' 'Intel Xeon E3-1231 v3' 'Intel Core i7-4790'
#  'Intel Core i5-3470' 'Intel Core i7-4770K' 'Intel Core i5-4670'
#  'Intel Core i7-4960X' 'Intel Core i7-5600U' 'AMD FX-8370 Eight-Core'
#  'Intel Core i5-7600K' 'AMD Ryzen 3 3200U' 'Intel Core i5-5200U'
#  'Loongson-3A5000LL' 'Intel Core i7-3770K' 'Spacemit X60'
#  'ARMv8 Cortex-A55 4-Core' 'ARMv8 Cortex-A72 4-Core'
#  '2 x Intel Xeon Max 9480' 'ARMv8 Neoverse-V2 96-Core'
#  '2 x AMD EPYC 9754 128-Core' '2 x Intel Xeon Gold 6444Y'
#  'ARMv8 Neoverse-V1 32-Core' 'ARMv8 Neoverse-N1 64-Core'
#  'AMD RYZEN AI MAX PRO 390' 'AMD Ryzen Threadripper PRO 5965WX 24-Cores'
#  'AMD EPYC 7F32 8-Core' 'Intel Core Ultra 5 245K'
#  'AMD Ryzen 9 9900X 12-Core' 'Intel Core i5-14600K'
#  'AMD Ryzen 7 9700X 8-Core' 'AMD Ryzen 5 9600X 6-Core'
#  'AMD Ryzen 7 PRO 7840U' 'AMD Ryzen Z1 Extreme' 'AMD Ryzen 7 7840U'
#  'Intel Core i7-1185G7' 'AMD Ryzen 5 5500U' 'ARMv8 Cortex-A72 16-Core'
#  'AMD Ryzen 9 5900HX' 'Loongson-3A6000' '2 x AMD EPYC 9654 96-Core'
#  '2 x AMD EPYC 9634 84-Core' 'AMD EPYC 9634 84-Core'
#  '2 x AMD EPYC 7643 48-Core' 'AMD EPYC 7643 48-Core'
#  '2 x Intel Xeon Platinum 8260' 'AMD Ryzen 7 7840HS'
#  'AMD EPYC 72F3 8-Core' 'AMD Ryzen 7 7735HS' 'AMD Ryzen 5 5560U'
#  'AMD Ryzen 7 4700U' '2 x Intel Xeon L5640' 'Intel Core i3-12100'
#  'Intel Core i5-8250U' 'Intel Core i3-7100' 'AMD EPYC 9384X 32-Core'
#  'Intel Xeon 6780E' 'Intel Xeon 6766E' '2 x AMD EPYC 7313 16-Core'
#  'AMD Ryzen Threadripper 9980X 64-Cores' 'AMD EPYC 7373X 16-Core'
#  'Intel Xeon Max 9468' 'AMD EPYC 7313 16-Core' '2 x Intel Xeon Max 9468'
#  '2 x AMD EPYC 7642 48-Core' 'Intel Xeon Silver 4108' 'AMD Ryzen 7 5800H'
#  'AMD Ryzen 5 3600X 6-Core' 'Intel Core i7 990X'
#  'Ampere Altra ARMv8 Neoverse-N1 160-Core' '2 x AMD EPYC 7453 28-Core'
#  'AMD Ryzen Threadripper PRO 3975WX 32-Cores' 'AMD EPYC 7453 28-Core'
#  'AMD EPYC 7502 32-Core' 'AMD EPYC 7452 32-Core'
#  '2 x Intel Xeon Gold 6138' 'AMD EPYC 7F72 24-Core'
#  '2 x Intel Xeon Gold 6140' 'AMD EPYC 7352 24-Core'
#  '2 x Intel Xeon E5-2683 v4' '4 x Intel Xeon E5-4620 v4'
#  'AMD Ryzen Threadripper 1950X 16-Core' '2 x Intel Xeon E5-2680 v2'
#  'AMD Ryzen Threadripper 2920X 12-Core' '2 x Intel Xeon Silver 4210'
#  'AMD EPYC 7351P 16-Core' 'Intel Xeon Gold 5218'
#  '2 x Intel Xeon E5-2643 v3' 'AMD Ryzen 7 PRO 4750G' 'AMD Ryzen 7 5700G'
#  'Intel Xeon Silver 4214R' 'AMD Ryzen 7 3800X 8-Core'
#  'AMD Ryzen 7 5700X 8-Core' 'AMD EPYC 7262 8-Core'
#  'AMD Ryzen 7 1700X Eight-Core' '2 x Intel Xeon X5675'
#  'AMD EPYC 7252 8-Core' 'Intel Xeon Silver 4215R' 'Intel Xeon Gold 5217'
#  '2 x Intel Xeon E5-2620 v2' 'AMD Ryzen 5 3600 6-Core'
#  'AMD Ryzen 5 2600X Six-Core' 'AMD Ryzen 5 5500'
#  'AMD Ryzen 5 1600X Six-Core' 'Intel Core i5-12400' 'AMD EPYC 7251 8-Core'
#  'AMD Ryzen 5 2600 Six-Core' 'AMD Ryzen 5 1600 Six-Core'
#  'Intel Xeon Gold 5215' 'AMD Ryzen 5 2400G with Radeon Vega'
#  'Intel Core i5-10210U' 'AMD Ryzen 5 1500X' 'Intel Core i7-6700K'
#  'Intel Core i5-8400H' 'AMD FX-8350 Eight-Core'
#  '8 x AMD EPYC 7601 32-Core' 'Intel Core i7-2700K' 'Intel Core i5-1135G7'
#  'Intel Core i3-8100' 'Intel Core i7-3632QM'
#  'Rockchip ARMv8 Cortex-A76 4-Core' 'Intel Core i5-4460'
#  'ARMv8 Cortex-A76 4-Core' 'Intel Core i5-2400' 'Intel Core i7-5557U'
#  'AMD Phenom 9650' 'AMD Phenom II X3 720' 'Intel Core i5-3320M'
#  'Intel Core i5-7200U' 'Intel Core i5-6300U' 'Intel Core i7-6500U'
#  'Intel Core i5-4210U' 'Intel Core i3-7020U' 'ARMv7 Cortex-A72 4-Core'
#  'Intel Core 2 Duo T9500' 'ARMv7 rev 1 4-Core' 'POWER9 44-Core'
#  'AMD Ryzen 7 4800U' 'Intel Core i7-9700TE' 'Intel Pentium Gold G6400'
#  'Intel Celeron G5900' 'AMD EPYC 4585PX 16-Core' 'AMD EPYC 4565P 16-Core'
#  'AMD EPYC 4345P 8-Core' 'AMD EPYC 4465P 12-Core' 'AMD EPYC 4545P 16-Core'
#  'AMD EPYC 4245P 6-Core' 'Apple M4 Pro' 'AMD EPYC 4344P 8-Core'
#  'AMD EPYC 4244P 6-Core' 'Intel Xeon 6369P' 'AMD Ryzen 7 8700G'
#  'Apple M2 Max' 'Intel Xeon E E-2488' 'AMD Ryzen 5 8400F 6-Core'
#  'Intel Core Ultra 7 155H' 'Intel Core i5-14400F' 'Intel Xeon W-1370P'
#  'Apple M1 Pro' 'Intel Core i9-10900KF' 'AMD Ryzen AI 9 HX 370'
#  '2 x AMD EPYC 72F3 8-Core' 'Intel Xeon Gold 5412U'
#  'AMD EPYC 7313P 16-Core' 'AMD EPYC 7K83 64-Core' 'Intel Core i9-9900'
#  'AMD EPYC 7663 56-Core' 'Intel Core i7-8700B' 'Intel Xeon W-2295'
#  '2 x AMD EPYC 7F32 8-Core' 'AMD Ryzen 3 3100 4-Core'
#  '2 x Intel Xeon Platinum 8272CL' '2 x Intel Xeon Platinum 8259L'
#  '2 x Intel Xeon Gold 6226R' '2 x Intel Xeon Gold 6254'
#  'Intel Xeon Platinum 8253' 'Intel Core i7-6700HQ'
#  '4 x Intel Xeon Gold 6254' 'AMD Athlon 3000G' 'AMD Ryzen 3 3200G'
#  '2 x Intel Xeon E5-2678 v3' 'Intel Core i5-5300U' 'Intel Core i7-5500U'
#  'Intel Core i7-3517U' 'Intel Core i3-4130' '2 x Intel Xeon E5-2650 0'
#  'AMD A10-7870K Radeon R7 12 Compute Cores 4C+8G' 'AMD FX-8150 Eight-Core'
#  'AMD A10-7850K APU' 'Loongson-3C5000' 'ARMv7 4-Core'
#  'AMD EPYC 7713P 64-Core' '2 x Intel Xeon Gold 6338'
#  'AMD EPYC 7513 32-Core' 'AMD EPYC 7413 24-Core' 'Intel Xeon Gold 6338'
#  '4 x Intel Xeon 6728P' '2 x Intel Xeon Platinum 8474C'
#  '2 x AMD EPYC 7K62 48-Core' 'AMD EPYC 7473X 24-Core'
#  'AMD EPYC 7663P 56-Core' '2 x Intel Xeon E5-2690 v4'
#  '2 x Intel Xeon E5-2670 0' 'AMD RYZEN AI MAX+ PRO 395'
#  'AMD Ryzen AI MAX+ PRO 395' 'AMD Ryzen AI 9 365'
#  'Intel Core Ultra 7 256V' 'Intel Core Ultra 7 258V' 'AMD Ryzen AI 5 340'
#  'AMD Ryzen AI 7 PRO 360' 'Intel Core i5-1334U' 'Apple M4'
#  'Intel Core i5-12600' 'AMD Ryzen 7 8845HS' 'Intel Xeon Platinum 8480+'
#  'Intel Core Ultra 7 165U' 'AMD Ryzen 7 5800U' 'Intel Core i9-10850K'
#  'AMD Ryzen 5 PRO 4650G' 'Intel N150' 'AMD Ryzen 5 3500X 6-Core'
#  'AMD Ryzen Threadripper 1900X 8-Core' 'AMD Ryzen 7 PRO 3700U'
#  'Intel Core i7-8700' 'Intel Core i5-1035G1' 'Intel Core i5-8300H'
#  'Intel Core i5-8600K' '2 x AMD EPYC 7402 24-Core' 'AMD EPYC 7302 16-Core'
#  'Intel Pentium G4400' '2 x AMD EPYC 7502 32-Core' 'Intel Core i7-8559U'
#  'Intel Core i7-9850H' 'AMD Ryzen 5 3500U' 'Intel Core i5-3550'
#  'Intel Core i5-3570K' 'Intel Core i5-6500T' 'Intel Core i7-5820K'
#  'Intel Core i5-4300M' 'Intel Core i5-4430' '2 x Intel Xeon Gold 6130'
#  '2 x Intel Xeon Gold 6142' 'Intel Xeon W-2123' 'Intel Core i5-2500S'
#  'Intel Core i5-6200U' 'Intel Core i3-8100T' 'Intel Core i7-4558U'
#  'Intel Core m3-7Y30' 'Intel Core i3-2120' 'Intel Core i7-3770'
#  'Intel Core i7-2600' 'Intel Core i5-3427U'
#  'Rockchip ARMv8 Cortex-A76 6-Core' 'AMD FX-6300 Six-Core'
#  'Intel Core i5-4278U' 'AMD A12-9720P RADEON R7 12 COMPUTE CORES 4C+8G'
#  'Intel Core i5' '2 x Intel Xeon Silver 4214' 'Intel Core i5-2410M'
#  'Intel Core 2 Duo E8500' 'Intel Core i5-2520M' 'Intel Core i7-3630QM'
#  'Intel Core i7 920' 'Intel Core m3-6Y30' 'Intel Core 2 Duo T7700'
#  'Intel Xeon E3-12xx v2' 'Intel Core i3-3110M' 'ZHAOXIN KaiXian KX-6640MA'
#  'Intel Celeron N3350' 'Intel Core 2 Duo T7100' 'Intel Pentium N4200'
#  'Intel Celeron J3455' 'Intel Core 2 Duo P7350' 'ARMv8 Cortex-A73 8-Core'
#  'ARMv8 Cortex-A57 6-Core' 'Intel Celeron N2830'
#  'POWER9 altivec supported 64-Core' 'ARMv8 rev 3 6-Core'
#  'AMD A6-3410MX APU' 'ARMv7 rev 3 4-Core' 'ARMv8 Cortex-A72 6-Core'
#  'ARMVv8 Cortex-A73 6-Core' 'rv64imafdcvsu' 'ARMv8 Cortex-A57 4-Core'
#  'ARMv8 rev 1 4-Core' 'Intel Core i5 460M' 'Intel Atom x5-Z8350' 'Ky X1'
#  'Rockchip ARMv8 Cortex-A53 4-Core' 'ARMv7 rev 4 4-Core'
#  'ARMv7 Cortex-A7 4-Core' '2 x AMD EPYC 7303 16-Core'
#  'Intel Xeon Gold 6414U' '2 x Intel Xeon 6766E' 'Intel Xeon Gold 5416S'
#  'Apple M3 Max' '2 x Intel Xeon E5-2687W 0' 'Intel Core i7-12700KF'
#  '2 x Intel Xeon Gold 6144' 'Intel Core i7-1185G7E' 'Intel Core i3-1005G1']

# %%
# Process model list
import re

# Matches: "2 x", "2x", "2 ×" (case-insensitive), with optional spaces
_MULTIPLIER_RE = re.compile(r'^\s*(?P<multi>\d+)\s*(?:x|×)\s*', re.IGNORECASE)

# Matches a *trailing* core/thread suffix like:
#  "32-Core", "32 Core", "32C", optionally plus "/ 64-Thread", ", 64 Threads", "and 64T"
#  optionally wrapped in parentheses, e.g. "(32-Core / 64-Thread)"
_TRAILING_CORES_THREADS_RE = re.compile(
    r"""
    \s*                              
    (?:\(\s*)?                       
    (?:[/,]|and)?\s*                 
    \d+\s*-?\s*(?:core|cores|c)\b    
    (?:                              
        \s*(?:[/,]|and)\s*
        \d+\s*-?\s*(?:thread|threads|t)\b
    )?
    \s*(?:\)\s*)?                    
    \s*$                             
    """,
    re.IGNORECASE | re.VERBOSE,
)

def normalize_model_and_multiplier(raw: str) -> tuple[str, int]:
    """
    Returns (base_model, multiplier).
      - base_model has any leading "<n> x" stripped
        and any trailing "<n>-Core[/<m>-Thread]" stripped.
      - multiplier is the leading <n> (default 1).
    """
    s = raw.strip()

    # 1) Extract leading multiplier (default 1)
    multiplier = 1
    m = _MULTIPLIER_RE.match(s)
    if m:
        multiplier = int(m.group("multi"))
        s = s[m.end():]  # chop it off

    # 2) Remove trailing core/thread decorations (only at end)
    s = _TRAILING_CORES_THREADS_RE.sub("", s)

    # 3) Collapse internal whitespace
    s = " ".join(s.split())
    return s, multiplier

# %%
clean_models = []
multipliers = []
for model in models:
    #print(model)
    clean, mult = normalize_model_and_multiplier(model)
    clean_models.append(clean)
    multipliers.append(mult)

model_comparisons = pd.DataFrame({"Models":models,"Cleaned":clean_models, "Multipliers":multipliers})
print(model_comparisons)
# Out:
#                         Models                Cleaned  Multipliers
# 0    AMD Ryzen 9 9950X 16-Core      AMD Ryzen 9 9950X            1
# 1        AMD RYZEN AI MAX+ 395  AMD RYZEN AI MAX+ 395            1
# 2         Intel Core i9-13900K   Intel Core i9-13900K            1
# 3     AMD Ryzen 7 7700X 8-Core      AMD Ryzen 7 7700X            1
# 4    AMD Ryzen 9 7950X 16-Core      AMD Ryzen 9 7950X            1
# ..                         ...                    ...          ...
# 540  2 x Intel Xeon E5-2687W 0  Intel Xeon E5-2687W 0            2
# 541      Intel Core i7-12700KF  Intel Core i7-12700KF            1
# 542   2 x Intel Xeon Gold 6144   Intel Xeon Gold 6144            2
# 543      Intel Core i7-1185G7E  Intel Core i7-1185G7E            1
# 544       Intel Core i3-1005G1   Intel Core i3-1005G1            1
#
# [545 rows x 3 columns]

# %% [markdown]
# Now we are also going to drop the non Intel or AMD models. This is a limitation of our work.
#
# We don't have a lot of non Intel/AMD options, and comparability is often poor without them due to them being historically dominant and only recently having alternatives (i.e. ARM desktop options).

# %%
subs = ["AMD", "Intel"]
pattern = "|".join(re.escape(s) for s in subs)
model_comparisons_keep = model_comparisons[model_comparisons["Models"].str.contains(pattern, case=False, na=False, regex=True)]
model_comparisons_keep.reset_index(inplace=True)
model_comparisons_keep
# Out:
#      index                     Models                Cleaned  Multipliers
# 0        0  AMD Ryzen 9 9950X 16-Core      AMD Ryzen 9 9950X            1
# 1        1      AMD RYZEN AI MAX+ 395  AMD RYZEN AI MAX+ 395            1
# 2        2       Intel Core i9-13900K   Intel Core i9-13900K            1
# 3        3   AMD Ryzen 7 7700X 8-Core      AMD Ryzen 7 7700X            1
# 4        4  AMD Ryzen 9 7950X 16-Core      AMD Ryzen 9 7950X            1
# ..     ...                        ...                    ...          ...
# 484    540  2 x Intel Xeon E5-2687W 0  Intel Xeon E5-2687W 0            2
# 485    541      Intel Core i7-12700KF  Intel Core i7-12700KF            1
# 486    542   2 x Intel Xeon Gold 6144   Intel Xeon Gold 6144            2
# 487    543      Intel Core i7-1185G7E  Intel Core i7-1185G7E            1
# 488    544       Intel Core i3-1005G1   Intel Core i3-1005G1            1
#
# [489 rows x 4 columns]

# %%
list(model_comparisons_keep["Cleaned"])
# Out:
# ['AMD Ryzen 9 9950X',
#  'AMD RYZEN AI MAX+ 395',
#  'Intel Core i9-13900K',
#  'AMD Ryzen 7 7700X',
#  'AMD Ryzen 9 7950X',
#  'Intel Core i9-14900K',
#  'AMD EPYC 4364P',
#  'AMD Ryzen 9 7900X',
#  'Intel Core i9-12900K',
#  'AMD EPYC 4564P',
#  'AMD EPYC 4464P',
#  'AMD EPYC 4584PX',
#  'AMD EPYC 4484PX',
#  'AMD Ryzen 9 5900X',
#  'AMD Ryzen 5 7600X',
#  'Intel Core i9-11900K',
#  'AMD Ryzen 9 5950X',
#  'AMD Ryzen 7 5800X',
#  'AMD Ryzen 7 5800X3D',
#  'Intel Core i9-10900K',
#  'Intel Core i5-13600K',
#  'AMD EPYC 4124P',
#  'AMD Ryzen Threadripper 3970X',
#  'AMD Ryzen Threadripper 3990X',
#  'AMD Ryzen 9 3900XT',
#  'Intel Core i5-12600K',
#  'Intel Core i7-7900X',
#  'Intel Core i5-11600K',
#  'Intel Core i9-7980XE',
#  'Intel Core i5-13400',
#  'AMD Ryzen 7 PRO 5850U',
#  'AMD Ryzen Threadripper 2990WX',
#  'AMD Ryzen 7 PRO 6850U',
#  'AMD Ryzen 5 3600XT',
#  'AMD EPYC 73F3',
#  'AMD EPYC 75F3',
#  'AMD Ryzen Threadripper 3960X',
#  'AMD EPYC 74F3',
#  'AMD EPYC 73F3',
#  'Intel Xeon E-2278GEL',
#  'AMD Ryzen 7 1700 Eight-Core',
#  'AMD EPYC 7713',
#  'Intel Core i9-9900KS',
#  'AMD EPYC 7F52',
#  'Intel Core i9-9900K',
#  'AMD EPYC 7513',
#  'AMD EPYC 7713',
#  'AMD EPYC 7F52',
#  'AMD EPYC 7763',
#  'AMD Ryzen 5 4500U',
#  'Intel Xeon Gold 6248R',
#  'Intel Core i7-1280P',
#  'AMD EPYC 7542',
#  'AMD EPYC 7742',
#  'Intel Core i7-6700',
#  'AMD EPYC 7502P',
#  'AMD EPYC 7402P',
#  'Intel Xeon Gold 6258R',
#  'AMD EPYC 7742',
#  'Intel Core i7-6800K',
#  'AMD EPYC 7302P',
#  'AMD EPYC 7532',
#  'Intel Xeon Platinum 8280',
#  'AMD EPYC 7552',
#  'AMD EPYC 7642',
#  'AMD EPYC 7662',
#  'Intel Xeon E-2388G',
#  'AMD EPYC 7272',
#  'AMD EPYC 7232P',
#  'Intel Xeon Gold 5220R',
#  'AMD EPYC 7282',
#  'Intel Xeon Gold 6226R',
#  'Intel Xeon Gold 5220R',
#  'AMD Ryzen 7 3800XT',
#  'Intel Core i7-8700K',
#  'AMD Ryzen 7 PRO 3700',
#  'AMD Ryzen 9 PRO 3900',
#  'Intel Xeon E5-1680 v3',
#  'Intel Core i7-7700K',
#  'Intel Xeon E-2278G',
#  'Intel Core i7-1165G7',
#  'AMD Ryzen 7 2700 Eight-Core',
#  'AMD Ryzen Threadripper 2970WX',
#  'Intel Xeon E5-2687W v3',
#  'Intel Core i5-9400F',
#  'AMD Ryzen Threadripper 2950X',
#  'Intel Xeon E3-1275 v6',
#  'AMD EPYC 7601',
#  'Intel Core i7-9750H',
#  'Intel Core i7-8565U',
#  'AMD EPYC 7601',
#  'Intel Xeon E3-1245 v5',
#  'Intel Xeon E3-1280 v5',
#  'Intel Core i7-1065G7',
#  'Intel Core i7-4790K',
#  'AMD Ryzen 5 3400G',
#  'Intel Xeon Silver 4216',
#  'AMD EPYC 7551',
#  'Intel Celeron G6900',
#  'Intel Core i7-',
#  'Intel Xeon E5-2609 v4',
#  'Intel Core i7-4600U',
#  'Intel Xeon 6980P',
#  'AMD EPYC 9755',
#  'AMD EPYC 9575F',
#  'AMD EPYC 9655',
#  'AMD EPYC 9965',
#  'AMD EPYC 9684X',
#  'AMD EPYC 9374F',
#  'AMD EPYC 9554',
#  'AMD EPYC 9384X',
#  'Intel Xeon 6980P',
#  'AMD EPYC 9184X',
#  'INTEL XEON PLATINUM 8592+',
#  'AMD EPYC 9755',
#  'AMD EPYC 9575F',
#  'Intel Xeon Platinum 8490H',
#  'Intel Xeon Platinum 8468',
#  'AMD EPYC 9655',
#  'AMD EPYC 9965',
#  'Intel Xeon Platinum 8462Y+',
#  'AMD EPYC 9655P',
#  'Intel Xeon Gold 6442Y',
#  'AMD EPYC 9845',
#  'AMD EPYC 9684X',
#  'AMD EPYC 9374F',
#  'AMD EPYC 9554',
#  'AMD EPYC 9654',
#  'AMD EPYC 9754',
#  'Intel Xeon Platinum 8380',
#  'Intel Xeon Platinum 8362',
#  'AMD EPYC 7773X',
#  'AMD EPYC 7573X',
#  'AMD EPYC 7663',
#  'AMD EPYC 74F3',
#  'Intel Xeon Gold 6342',
#  'AMD EPYC 7543',
#  'AMD EPYC 7373X',
#  'INTEL XEON PLATINUM 8592+',
#  'AMD EPYC 75F3',
#  'AMD Ryzen Threadripper PRO 7995WX',
#  'AMD EPYC 7443',
#  'AMD EPYC 7343',
#  'Intel Xeon Gold 6346',
#  'AMD EPYC 7551',
#  'Intel Xeon Platinum 8468',
#  'Intel Xeon Platinum 8490H',
#  'Intel Xeon Max 9480',
#  'AMD EPYC 9534',
#  'Intel Xeon Platinum 8471N',
#  'Intel Xeon Platinum 8462Y+',
#  'Intel Xeon Gold 6442Y',
#  'AMD EPYC 7F72',
#  'Intel Xeon Platinum 8280',
#  'AMD Ryzen Threadripper PRO 9995WX',
#  'AMD EPYC 8534P',
#  'AMD EPYC 8534PN',
#  'AMD Ryzen Threadripper 9970X',
#  'AMD EPYC 7573X',
#  'Intel Xeon Platinum 8362',
#  'AMD EPYC 7773X',
#  'Intel Xeon Platinum 8380',
#  'Intel Xeon Gold 6342',
#  'AMD EPYC 7543',
#  'AMD EPYC 7763',
#  'AMD EPYC 7343',
#  'AMD EPYC 7443',
#  'Intel Xeon Gold 6346',
#  'AMD Ryzen Threadripper 7970X',
#  'AMD Ryzen Threadripper 7980X',
#  'AMD EPYC 7702',
#  'Intel Xeon E5-2699 v4',
#  'Intel Xeon E5-2696 v4',
#  'Intel Core Ultra 9 285K',
#  'Intel Xeon Gold 5218',
#  'AMD Ryzen 9 9900X3D',
#  'Intel Core i9-7960X',
#  'AMD Ryzen 9 9950X3D',
#  'Intel Core i3-14100',
#  'AMD Ryzen 7 9800X3D',
#  'Intel Core i9-10980XE',
#  'AMD Ryzen 5 8600G',
#  'AMD Ryzen 5 8500G',
#  'AMD Ryzen 7 7800X3D',
#  'AMD Ryzen 9 7900X3D',
#  'AMD Ryzen 9 7950X3D',
#  'AMD Ryzen 9 7900',
#  'AMD Ryzen 5 7600',
#  'AMD Ryzen 7 7700',
#  'Intel Core i5-14500',
#  'AMD Ryzen 9 6900HX',
#  'Intel Core i9-12900H',
#  'Intel Core i7-12700K',
#  'Intel Core i9-11980HK',
#  'Intel Core i7-11700K',
#  'Intel Core i7-11700B',
#  'AMD Ryzen 7 1800X Eight-Core',
#  'Intel Core i5-10600K',
#  'Intel Core i7-8086K',
#  'Intel Core i5-8400',
#  'AMD Ryzen 5 5600G',
#  'AMD Ryzen 5 5600X',
#  'Intel Core i7-7740K',
#  'AMD Ryzen 3 1300X',
#  'AMD Ryzen 3 3300X',
#  'AMD Ryzen 5 PRO 6650U',
#  'AMD Ryzen 9 3900X',
#  'Intel Core i7-8809G',
#  'AMD Ryzen 7 2700X Eight-Core',
#  'AMD Ryzen 7 3700X',
#  'Intel Core i7-10700T',
#  'Intel Xeon E-2288G',
#  'AMD Ryzen 3 2200G',
#  'Intel Core i9-10885H',
#  'AMD Ryzen 9 3950X',
#  'AMD Ryzen 5 2400G',
#  'Intel Core i7-7700',
#  'Intel Xeon E-2336',
#  'Intel Core i7-5960X',
#  'Intel Xeon E3-1260L v5',
#  'Intel Core i5-6500',
#  'Intel Core i3-10100',
#  'AMD Custom APU 0405',
#  'Intel Core i5-6260U',
#  'Intel Xeon E3-1235L v5',
#  'Intel Xeon E3-1240 v5',
#  'Intel Core i7-8550U',
#  'Intel Xeon E3-1270 v5',
#  'Intel Xeon E3-1231 v3',
#  'Intel Core i7-4790',
#  'Intel Core i5-3470',
#  'Intel Core i7-4770K',
#  'Intel Core i5-4670',
#  'Intel Core i7-4960X',
#  'Intel Core i7-5600U',
#  'AMD FX-8370 Eight-Core',
#  'Intel Core i5-7600K',
#  'AMD Ryzen 3 3200U',
#  'Intel Core i5-5200U',
#  'Intel Core i7-3770K',
#  'Intel Xeon Max 9480',
#  'AMD EPYC 9754',
#  'Intel Xeon Gold 6444Y',
#  'AMD RYZEN AI MAX PRO 390',
#  'AMD Ryzen Threadripper PRO 5965WX',
#  'AMD EPYC 7F32',
#  'Intel Core Ultra 5 245K',
#  'AMD Ryzen 9 9900X',
#  'Intel Core i5-14600K',
#  'AMD Ryzen 7 9700X',
#  'AMD Ryzen 5 9600X',
#  'AMD Ryzen 7 PRO 7840U',
#  'AMD Ryzen Z1 Extreme',
#  'AMD Ryzen 7 7840U',
#  'Intel Core i7-1185G7',
#  'AMD Ryzen 5 5500U',
#  'AMD Ryzen 9 5900HX',
#  'AMD EPYC 9654',
#  'AMD EPYC 9634',
#  'AMD EPYC 9634',
#  'AMD EPYC 7643',
#  'AMD EPYC 7643',
#  'Intel Xeon Platinum 8260',
#  'AMD Ryzen 7 7840HS',
#  'AMD EPYC 72F3',
#  'AMD Ryzen 7 7735HS',
#  'AMD Ryzen 5 5560U',
#  'AMD Ryzen 7 4700U',
#  'Intel Xeon L5640',
#  'Intel Core i3-12100',
#  'Intel Core i5-8250U',
#  'Intel Core i3-7100',
#  'AMD EPYC 9384X',
#  'Intel Xeon 6780E',
#  'Intel Xeon 6766E',
#  'AMD EPYC 7313',
#  'AMD Ryzen Threadripper 9980X',
#  'AMD EPYC 7373X',
#  'Intel Xeon Max 9468',
#  'AMD EPYC 7313',
#  'Intel Xeon Max 9468',
#  'AMD EPYC 7642',
#  'Intel Xeon Silver 4108',
#  'AMD Ryzen 7 5800H',
#  'AMD Ryzen 5 3600X',
#  'Intel Core i7 990X',
#  'AMD EPYC 7453',
#  'AMD Ryzen Threadripper PRO 3975WX',
#  'AMD EPYC 7453',
#  'AMD EPYC 7502',
#  'AMD EPYC 7452',
#  'Intel Xeon Gold 6138',
#  'AMD EPYC 7F72',
#  'Intel Xeon Gold 6140',
#  'AMD EPYC 7352',
#  'Intel Xeon E5-2683 v4',
#  'Intel Xeon E5-4620 v4',
#  'AMD Ryzen Threadripper 1950X',
#  'Intel Xeon E5-2680 v2',
#  'AMD Ryzen Threadripper 2920X',
#  'Intel Xeon Silver 4210',
#  'AMD EPYC 7351P',
#  'Intel Xeon Gold 5218',
#  'Intel Xeon E5-2643 v3',
#  'AMD Ryzen 7 PRO 4750G',
#  'AMD Ryzen 7 5700G',
#  'Intel Xeon Silver 4214R',
#  'AMD Ryzen 7 3800X',
#  'AMD Ryzen 7 5700X',
#  'AMD EPYC 7262',
#  'AMD Ryzen 7 1700X Eight-Core',
#  'Intel Xeon X5675',
#  'AMD EPYC 7252',
#  'Intel Xeon Silver 4215R',
#  'Intel Xeon Gold 5217',
#  'Intel Xeon E5-2620 v2',
#  'AMD Ryzen 5 3600',
#  'AMD Ryzen 5 2600X Six-Core',
#  'AMD Ryzen 5 5500',
#  'AMD Ryzen 5 1600X Six-Core',
#  'Intel Core i5-12400',
#  'AMD EPYC 7251',
#  'AMD Ryzen 5 2600 Six-Core',
#  'AMD Ryzen 5 1600 Six-Core',
#  'Intel Xeon Gold 5215',
#  'AMD Ryzen 5 2400G with Radeon Vega',
#  'Intel Core i5-10210U',
#  'AMD Ryzen 5 1500X',
#  'Intel Core i7-6700K',
#  'Intel Core i5-8400H',
#  'AMD FX-8350 Eight-Core',
#  'AMD EPYC 7601',
#  'Intel Core i7-2700K',
#  'Intel Core i5-1135G7',
#  'Intel Core i3-8100',
#  'Intel Core i7-3632QM',
#  'Intel Core i5-4460',
#  'Intel Core i5-2400',
#  'Intel Core i7-5557U',
#  'AMD Phenom 9650',
#  'AMD Phenom II X3 720',
#  'Intel Core i5-3320M',
#  'Intel Core i5-7200U',
#  'Intel Core i5-6300U',
#  'Intel Core i7-6500U',
#  'Intel Core i5-4210U',
#  'Intel Core i3-7020U',
#  'Intel Core 2 Duo T9500',
#  'AMD Ryzen 7 4800U',
#  'Intel Core i7-9700TE',
#  'Intel Pentium Gold G6400',
#  'Intel Celeron G5900',
#  'AMD EPYC 4585PX',
#  'AMD EPYC 4565P',
#  'AMD EPYC 4345P',
#  'AMD EPYC 4465P',
#  'AMD EPYC 4545P',
#  'AMD EPYC 4245P',
#  'AMD EPYC 4344P',
#  'AMD EPYC 4244P',
#  'Intel Xeon 6369P',
#  'AMD Ryzen 7 8700G',
#  'Intel Xeon E E-2488',
#  'AMD Ryzen 5 8400F',
#  'Intel Core Ultra 7 155H',
#  'Intel Core i5-14400F',
#  'Intel Xeon W-1370P',
#  'Intel Core i9-10900KF',
#  'AMD Ryzen AI 9 HX 370',
#  'AMD EPYC 72F3',
#  'Intel Xeon Gold 5412U',
#  'AMD EPYC 7313P',
#  'AMD EPYC 7K83',
#  'Intel Core i9-9900',
#  'AMD EPYC 7663',
#  'Intel Core i7-8700B',
#  'Intel Xeon W-2295',
#  'AMD EPYC 7F32',
#  'AMD Ryzen 3 3100',
#  'Intel Xeon Platinum 8272CL',
#  'Intel Xeon Platinum 8259L',
#  'Intel Xeon Gold 6226R',
#  'Intel Xeon Gold 6254',
#  'Intel Xeon Platinum 8253',
#  'Intel Core i7-6700HQ',
#  'Intel Xeon Gold 6254',
#  'AMD Athlon 3000G',
#  'AMD Ryzen 3 3200G',
#  'Intel Xeon E5-2678 v3',
#  'Intel Core i5-5300U',
#  'Intel Core i7-5500U',
#  'Intel Core i7-3517U',
#  'Intel Core i3-4130',
#  'Intel Xeon E5-2650 0',
#  'AMD A10-7870K Radeon R7 12 Compute Cores 4C+8G',
#  'AMD FX-8150 Eight-Core',
#  'AMD A10-7850K APU',
#  'AMD EPYC 7713P',
#  'Intel Xeon Gold 6338',
#  'AMD EPYC 7513',
#  'AMD EPYC 7413',
#  'Intel Xeon Gold 6338',
#  'Intel Xeon 6728P',
#  'Intel Xeon Platinum',
#  'AMD EPYC 7K62',
#  'AMD EPYC 7473X',
#  'AMD EPYC 7663P',
#  'Intel Xeon E5-2690 v4',
#  'Intel Xeon E5-2670 0',
#  'AMD RYZEN AI MAX+ PRO 395',
#  'AMD Ryzen AI MAX+ PRO 395',
#  'AMD Ryzen AI 9 365',
#  'Intel Core Ultra 7 256V',
#  'Intel Core Ultra 7 258V',
#  'AMD Ryzen AI 5 340',
#  'AMD Ryzen AI 7 PRO 360',
#  'Intel Core i5-1334U',
#  'Intel Core i5-12600',
#  'AMD Ryzen 7 8845HS',
#  'Intel Xeon Platinum 8480+',
#  'Intel Core Ultra 7 165U',
#  'AMD Ryzen 7 5800U',
#  'Intel Core i9-10850K',
#  'AMD Ryzen 5 PRO 4650G',
#  'Intel N150',
#  'AMD Ryzen 5 3500X',
#  'AMD Ryzen Threadripper 1900X',
#  'AMD Ryzen 7 PRO 3700U',
#  'Intel Core i7-8700',
#  'Intel Core i5-1035G1',
#  'Intel Core i5-8300H',
#  'Intel Core i5-8600K',
#  'AMD EPYC 7402',
#  'AMD EPYC 7302',
#  'Intel Pentium G4400',
#  'AMD EPYC 7502',
#  'Intel Core i7-8559U',
#  'Intel Core i7-9850H',
#  'AMD Ryzen 5 3500U',
#  'Intel Core i5-3550',
#  'Intel Core i5-3570K',
#  'Intel Core i5-6500T',
#  'Intel Core i7-5820K',
#  'Intel Core i5-4300M',
#  'Intel Core i5-4430',
#  'Intel Xeon Gold 6130',
#  'Intel Xeon Gold 6142',
#  'Intel Xeon W-2123',
#  'Intel Core i5-2500S',
#  'Intel Core i5-6200U',
#  'Intel Core i3-8100T',
#  'Intel Core i7-4558U',
#  'Intel Core m3-7Y30',
#  'Intel Core i3-2120',
#  'Intel Core i7-3770',
#  'Intel Core i7-2600',
#  'Intel Core i5-3427U',
#  'AMD FX-6300 Six-Core',
#  'Intel Core i5-4278U',
#  'AMD A12-9720P RADEON R7 12 COMPUTE CORES 4C+8G',
#  'Intel Core i5',
#  'Intel Xeon Silver 4214',
#  'Intel Core i5-2410M',
#  'Intel Core 2 Duo E8500',
#  'Intel Core i5-2520M',
#  'Intel Core i7-3630QM',
#  'Intel Core i7 920',
#  'Intel Core m3-6Y30',
#  'Intel Core 2 Duo T7700',
#  'Intel Xeon E3-12xx v2',
#  'Intel Core i3-3110M',
#  'Intel Celeron N3350',
#  'Intel Core 2 Duo T7100',
#  'Intel Pentium N4200',
#  'Intel Celeron J3455',
#  'Intel Core 2 Duo P7350',
#  'Intel Celeron N2830',
#  'AMD A6-3410MX APU',
#  'Intel Core i5 460M',
#  'Intel Atom x5-Z8350',
#  'AMD EPYC 7303',
#  'Intel Xeon Gold 6414U',
#  'Intel Xeon 6766E',
#  'Intel Xeon Gold 5416S',
#  'Intel Xeon E5-2687W 0',
#  'Intel Core i7-12700KF',
#  'Intel Xeon Gold 6144',
#  'Intel Core i7-1185G7E',
#  'Intel Core i3-1005G1']

# %%
"""
models = [
    "AMD EPYC 4364P 24-Core",
    "AMD Ryzen Threadripper 3970X 32-Core",
    "2 x AMD EPYC 73F3 16-Core",
    "Core Ultra 3 205",
]
"""
import time
models_to_search = list(model_comparisons_keep["Cleaned"])

start = time.time()
model_to_url, unresolved = build_model_url_map_via_search(models_to_search, min_score=86)
end = time.time()
print("\n")
print(f"Time taken {end-start}")

print("Resolved:", len(model_to_url), "Unresolved:", len(unresolved))
for m, u in model_to_url.items():
    print(m, "->", u)
if unresolved:
    print("\nUnresolved examples:")
    for m, info in list(unresolved.items())[:5]:
        print(" -", m, "simple_query=", info["simple_query"], "candidates=", info["candidates"])
# Out:
# [1/489] AMD Ryzen 9 9950X
# Iteration taken: 92.46497225761414
# [2/489] AMD RYZEN AI MAX+ 395
# Iteration taken: 159.85004591941833
# [3/489] Intel Core i9-13900K
# Iteration taken: 119.96439981460571
# [4/489] AMD Ryzen 7 7700X
# Iteration taken: 177.1497790813446
# [5/489] AMD Ryzen 9 7950X
# Iteration taken: 118.70965123176575
# [6/489] Intel Core i9-14900K
# Iteration taken: 138.84054517745972
# [7/489] AMD EPYC 4364P
# Iteration taken: 133.9334352016449
# [8/489] AMD Ryzen 9 7900X
# Iteration taken: 150.58465218544006
# [9/489] Intel Core i9-12900K
# Iteration taken: 119.9066858291626
# [10/489] AMD EPYC 4564P
# Iteration taken: 111.08674573898315
# [11/489] AMD EPYC 4464P
# Iteration taken: 116.29876804351807
# [12/489] AMD EPYC 4584PX
# Iteration taken: 239.3287489414215
# [13/489] AMD EPYC 4484PX
# Iteration taken: 165.8674328327179
# [14/489] AMD Ryzen 9 5900X
# Iteration taken: 182.4122109413147
# [15/489] AMD Ryzen 5 7600X
# Iteration taken: 179.9790620803833
# [16/489] Intel Core i9-11900K
# Iteration taken: 62.650043964385986
# [17/489] AMD Ryzen 9 5950X
# Iteration taken: 75.54699087142944
# [18/489] AMD Ryzen 7 5800X
# Iteration taken: 190.13881182670593
# [19/489] AMD Ryzen 7 5800X3D
# Iteration taken: 143.59927797317505
# [20/489] Intel Core i9-10900K
# Iteration taken: 189.06049704551697
# [21/489] Intel Core i5-13600K
# Iteration taken: 101.3486258983612
# [22/489] AMD EPYC 4124P
# Iteration taken: 191.61873626708984
# [23/489] AMD Ryzen Threadripper 3970X
# Iteration taken: 165.33346796035767
# [24/489] AMD Ryzen Threadripper 3990X
# Iteration taken: 154.45342683792114
# [25/489] AMD Ryzen 9 3900XT
# Iteration taken: 139.7383177280426
# [26/489] Intel Core i5-12600K
# Iteration taken: 151.21988487243652
# [27/489] Intel Core i7-7900X
# Iteration taken: 95.55906987190247
# [28/489] Intel Core i5-11600K
# Iteration taken: 173.85642504692078
# [29/489] Intel Core i9-7980XE
# Iteration taken: 162.90018320083618
# [30/489] Intel Core i5-13400
# Iteration taken: 110.26684188842773
# [31/489] AMD Ryzen 7 PRO 5850U
# Iteration taken: 126.45747494697571
# [32/489] AMD Ryzen Threadripper 2990WX
# Iteration taken: 111.59054589271545
# [33/489] AMD Ryzen 7 PRO 6850U
# Iteration taken: 100.31075406074524
# [34/489] AMD Ryzen 5 3600XT
# Iteration taken: 138.90930581092834
# [35/489] AMD EPYC 73F3
# Iteration taken: 123.64845180511475
# [36/489] AMD EPYC 75F3
# Iteration taken: 154.6751868724823
# [37/489] AMD Ryzen Threadripper 3960X
# Iteration taken: 110.26946687698364
# [38/489] AMD EPYC 74F3
# Iteration taken: 118.3603868484497
# [39/489] AMD EPYC 73F3
# Iteration taken: 62.21858787536621
# [40/489] Intel Xeon E-2278GEL
# Iteration taken: 179.04101467132568
# [41/489] AMD Ryzen 7 1700 Eight-Core
# Iteration taken: 131.79407906532288
# [42/489] AMD EPYC 7713
# Iteration taken: 151.11326909065247
# [43/489] Intel Core i9-9900KS
# Iteration taken: 151.06128406524658
# [44/489] AMD EPYC 7F52
# Iteration taken: 179.87623810768127
# [45/489] Intel Core i9-9900K
# Iteration taken: 215.22865676879883
# [46/489] AMD EPYC 7513
# Iteration taken: 141.43541598320007
# [47/489] AMD EPYC 7713
# Iteration taken: 79.55605030059814
# [48/489] AMD EPYC 7F52
# Iteration taken: 68.7833731174469
# [49/489] AMD EPYC 7763
# Iteration taken: 209.5200970172882
# [50/489] AMD Ryzen 5 4500U
# Iteration taken: 90.15471696853638
# [51/489] Intel Xeon Gold 6248R
# Iteration taken: 123.57606983184814
# [52/489] Intel Core i7-1280P
# Iteration taken: 114.52207899093628
# [53/489] AMD EPYC 7542
# Iteration taken: 130.24188613891602
# [54/489] AMD EPYC 7742
# Iteration taken: 108.74646234512329
# [55/489] Intel Core i7-6700
# Iteration taken: 146.699805021286
# [56/489] AMD EPYC 7502P
# Iteration taken: 98.61667776107788
# [57/489] AMD EPYC 7402P
# Iteration taken: 130.02393698692322
# [58/489] Intel Xeon Gold 6258R
# Iteration taken: 163.4225618839264
# [59/489] AMD EPYC 7742
# Iteration taken: 39.934340953826904
# [60/489] Intel Core i7-6800K
# Iteration taken: 155.1656370162964
# [61/489] AMD EPYC 7302P
# Iteration taken: 193.11452507972717
# [62/489] AMD EPYC 7532
# Iteration taken: 114.78818893432617
# [63/489] Intel Xeon Platinum 8280
# Iteration taken: 126.8070809841156
# [64/489] AMD EPYC 7552
# Iteration taken: 194.47199416160583
# [65/489] AMD EPYC 7642
# Iteration taken: 174.61524319648743
# [66/489] AMD EPYC 7662
# Iteration taken: 147.13829922676086
# [67/489] Intel Xeon E-2388G
# Iteration taken: 159.49274325370789
# [68/489] AMD EPYC 7272
# Iteration taken: 177.85970997810364
# [69/489] AMD EPYC 7232P
# Iteration taken: 180.21962714195251
# [70/489] Intel Xeon Gold 5220R
# Iteration taken: 226.8747410774231
# [71/489] AMD EPYC 7282
# Iteration taken: 149.1071560382843
# [72/489] Intel Xeon Gold 6226R
# Iteration taken: 158.66884779930115
# [73/489] Intel Xeon Gold 5220R
# Iteration taken: 94.31855583190918
# [74/489] AMD Ryzen 7 3800XT
# Iteration taken: 120.54462194442749
# [75/489] Intel Core i7-8700K
# Iteration taken: 93.40857529640198
# [76/489] AMD Ryzen 7 PRO 3700
# Iteration taken: 153.5201621055603
# [77/489] AMD Ryzen 9 PRO 3900
# Iteration taken: 99.45245003700256
# [78/489] Intel Xeon E5-1680 v3
# Iteration taken: 146.92531299591064
# [79/489] Intel Core i7-7700K
# Iteration taken: 119.40375089645386
# [80/489] Intel Xeon E-2278G
# Iteration taken: 153.8531939983368
# [81/489] Intel Core i7-1165G7
# Iteration taken: 209.69852805137634
# [82/489] AMD Ryzen 7 2700 Eight-Core
# Iteration taken: 131.80014276504517
# [83/489] AMD Ryzen Threadripper 2970WX
# Iteration taken: 93.21472787857056
# [84/489] Intel Xeon E5-2687W v3
# Iteration taken: 142.38071298599243
# [85/489] Intel Core i5-9400F
# Iteration taken: 211.06771397590637
# [86/489] AMD Ryzen Threadripper 2950X
# Iteration taken: 82.51676797866821
# [87/489] Intel Xeon E3-1275 v6
# Iteration taken: 158.46823382377625
# [88/489] AMD EPYC 7601
# Iteration taken: 146.03005409240723
# [89/489] Intel Core i7-9750H
# Iteration taken: 145.62772822380066
# [90/489] Intel Core i7-8565U
# Iteration taken: 236.29358792304993
# [91/489] AMD EPYC 7601
# Iteration taken: 53.729219913482666
# [92/489] Intel Xeon E3-1245 v5
# Iteration taken: 108.34615397453308
# [93/489] Intel Xeon E3-1280 v5
# Iteration taken: 129.5784227848053
# [94/489] Intel Core i7-1065G7
# Iteration taken: 184.27852702140808
# [95/489] Intel Core i7-4790K
# Iteration taken: 165.71067190170288
# [96/489] AMD Ryzen 5 3400G
# Iteration taken: 162.98587703704834
# [97/489] Intel Xeon Silver 4216
# Iteration taken: 163.9842450618744
# [98/489] AMD EPYC 7551
# Iteration taken: 178.8643217086792
# [99/489] Intel Celeron G6900
# Iteration taken: 151.28603386878967
# [100/489] Intel Core i7-
# Iteration taken: 174.72032403945923
# [101/489] Intel Xeon E5-2609 v4
# Iteration taken: 157.26490998268127
# [102/489] Intel Core i7-4600U
# Iteration taken: 233.43930411338806
# [103/489] Intel Xeon 6980P
# Iteration taken: 97.86145091056824
# [104/489] AMD EPYC 9755
# Iteration taken: 168.0471649169922
# [105/489] AMD EPYC 9575F
# Iteration taken: 133.8962779045105
# [106/489] AMD EPYC 9655
# Iteration taken: 141.60739398002625
# [107/489] AMD EPYC 9965
# Iteration taken: 147.62699913978577
# [108/489] AMD EPYC 9684X
# Iteration taken: 176.34497785568237
# [109/489] AMD EPYC 9374F
# Iteration taken: 116.67285394668579
# [110/489] AMD EPYC 9554
# Iteration taken: 164.74686193466187
# [111/489] AMD EPYC 9384X
# Iteration taken: 98.2387261390686
# [112/489] Intel Xeon 6980P
# Iteration taken: 104.15306305885315
# [113/489] AMD EPYC 9184X
# Iteration taken: 165.1768238544464
# [114/489] INTEL XEON PLATINUM 8592+
# Iteration taken: 166.09539008140564
# [115/489] AMD EPYC 9755
# Iteration taken: 90.4613561630249
# [116/489] AMD EPYC 9575F
# Iteration taken: 79.59556484222412
# [117/489] Intel Xeon Platinum 8490H
# Iteration taken: 121.18243527412415
# [118/489] Intel Xeon Platinum 8468
# Iteration taken: 134.50932693481445
# [119/489] AMD EPYC 9655
# Iteration taken: 113.52215576171875
# [120/489] AMD EPYC 9965
# Iteration taken: 64.42542004585266
# [121/489] Intel Xeon Platinum 8462Y+
# Iteration taken: 175.42965698242188
# [122/489] AMD EPYC 9655P
# Iteration taken: 131.35168385505676
# [123/489] Intel Xeon Gold 6442Y
# Iteration taken: 150.277822971344
# [124/489] AMD EPYC 9845
# Iteration taken: 141.98948192596436
# [125/489] AMD EPYC 9684X
# Iteration taken: 119.10718512535095
# [126/489] AMD EPYC 9374F
# Iteration taken: 99.09797191619873
# [127/489] AMD EPYC 9554
# Iteration taken: 107.99611592292786
# [128/489] AMD EPYC 9654
# Iteration taken: 163.26301383972168
# [129/489] AMD EPYC 9754
# Iteration taken: 135.30782914161682
# [130/489] Intel Xeon Platinum 8380
# Iteration taken: 197.83266615867615
# [131/489] Intel Xeon Platinum 8362
# Iteration taken: 133.31337881088257
# [132/489] AMD EPYC 7773X
# Iteration taken: 131.97902584075928
# [133/489] AMD EPYC 7573X
# Iteration taken: 220.3289132118225
# [134/489] AMD EPYC 7663
# Iteration taken: 229.18829798698425
# [135/489] AMD EPYC 74F3
# Iteration taken: 117.58768320083618
# [136/489] Intel Xeon Gold 6342
# Iteration taken: 198.27431392669678
# [137/489] AMD EPYC 7543
# Iteration taken: 117.34012579917908
# [138/489] AMD EPYC 7373X
# Iteration taken: 92.62046217918396
# [139/489] INTEL XEON PLATINUM 8592+
# Iteration taken: 102.12449312210083
# [140/489] AMD EPYC 75F3
# Iteration taken: 54.798583984375
# [141/489] AMD Ryzen Threadripper PRO 7995WX
# Iteration taken: 127.85456109046936
# [142/489] AMD EPYC 7443
# Iteration taken: 114.66029119491577
# [143/489] AMD EPYC 7343
# Iteration taken: 98.81221985816956
# [144/489] Intel Xeon Gold 6346
# Iteration taken: 85.89807724952698
# [145/489] AMD EPYC 7551
# Iteration taken: 116.33122110366821
# [146/489] Intel Xeon Platinum 8468
# Iteration taken: 60.3873450756073
# [147/489] Intel Xeon Platinum 8490H
# Iteration taken: 85.10790181159973
# [148/489] Intel Xeon Max 9480
# Iteration taken: 155.74164819717407
# [149/489] AMD EPYC 9534
# Iteration taken: 174.30739092826843
# [150/489] Intel Xeon Platinum 8471N
# Iteration taken: 150.7944462299347
# [151/489] Intel Xeon Platinum 8462Y+
# Iteration taken: 42.150153160095215
# [152/489] Intel Xeon Gold 6442Y
# Iteration taken: 108.96674418449402
# [153/489] AMD EPYC 7F72
# Iteration taken: 163.5380358695984
# [154/489] Intel Xeon Platinum 8280
# Iteration taken: 41.75578308105469
# [155/489] AMD Ryzen Threadripper PRO 9995WX
# Iteration taken: 113.80801320075989
# [156/489] AMD EPYC 8534P
# Iteration taken: 122.21096920967102
# [157/489] AMD EPYC 8534PN
# Iteration taken: 159.10900616645813
# [158/489] AMD Ryzen Threadripper 9970X
# Iteration taken: 165.34172797203064
# [159/489] AMD EPYC 7573X
# Iteration taken: 56.34936189651489
# [160/489] Intel Xeon Platinum 8362
# Iteration taken: 64.53214001655579
# [161/489] AMD EPYC 7773X
# Iteration taken: 67.28620219230652
# [162/489] Intel Xeon Platinum 8380
# Iteration taken: 36.1894690990448
# [163/489] Intel Xeon Gold 6342
# Iteration taken: 39.35880088806152
# [164/489] AMD EPYC 7543
# Iteration taken: 80.47871732711792
# [165/489] AMD EPYC 7763
# Iteration taken: 106.90287399291992
# [166/489] AMD EPYC 7343
# Iteration taken: 35.9575309753418
# [167/489] AMD EPYC 7443
# Iteration taken: 90.97333598136902
# [168/489] Intel Xeon Gold 6346
# Iteration taken: 74.22923183441162
# [169/489] AMD Ryzen Threadripper 7970X
# Iteration taken: 98.59428095817566
# [170/489] AMD Ryzen Threadripper 7980X
# Iteration taken: 145.06827521324158
# [171/489] AMD EPYC 7702
# Iteration taken: 146.75223016738892
# [172/489] Intel Xeon E5-2699 v4
# Iteration taken: 105.61557722091675
# [173/489] Intel Xeon E5-2696 v4
# Iteration taken: 115.86644983291626
# [174/489] Intel Core Ultra 9 285K
# Iteration taken: 77.85749387741089
# [175/489] Intel Xeon Gold 5218
# Iteration taken: 92.92601680755615
# [176/489] AMD Ryzen 9 9900X3D
# Iteration taken: 112.11636710166931
# [177/489] Intel Core i9-7960X
# Iteration taken: 99.13286519050598
# [178/489] AMD Ryzen 9 9950X3D
# Iteration taken: 144.31053805351257
# [179/489] Intel Core i3-14100
# Iteration taken: 127.44916296005249
# [180/489] AMD Ryzen 7 9800X3D
# Iteration taken: 168.21198892593384
# [181/489] Intel Core i9-10980XE
# Iteration taken: 113.82126688957214
# [182/489] AMD Ryzen 5 8600G
# Iteration taken: 132.91593194007874
# [183/489] AMD Ryzen 5 8500G
# Iteration taken: 183.27627801895142
# [184/489] AMD Ryzen 7 7800X3D
# Iteration taken: 143.02822494506836
# [185/489] AMD Ryzen 9 7900X3D
# Iteration taken: 178.71443700790405
# [186/489] AMD Ryzen 9 7950X3D
# Iteration taken: 188.0069990158081
# [187/489] AMD Ryzen 9 7900
# Iteration taken: 201.4758219718933
# [188/489] AMD Ryzen 5 7600
# Iteration taken: 132.63289189338684
# [189/489] AMD Ryzen 7 7700
# Iteration taken: 103.37672090530396
# [190/489] Intel Core i5-14500
# Iteration taken: 123.28820180892944
# [191/489] AMD Ryzen 9 6900HX
# Iteration taken: 98.65486097335815
# [192/489] Intel Core i9-12900H
# Iteration taken: 158.3100941181183
# [193/489] Intel Core i7-12700K
# Iteration taken: 205.60011100769043
# [194/489] Intel Core i9-11980HK
# Iteration taken: 135.3100459575653
# [195/489] Intel Core i7-11700K
# Iteration taken: 216.9584481716156
# [196/489] Intel Core i7-11700B
# Iteration taken: 150.34756803512573
# [197/489] AMD Ryzen 7 1800X Eight-Core
# Iteration taken: 172.55983066558838
# [198/489] Intel Core i5-10600K
# Iteration taken: 157.73047614097595
# [199/489] Intel Core i7-8086K
# Iteration taken: 174.6119122505188
# [200/489] Intel Core i5-8400
# Iteration taken: 136.0165638923645
# [201/489] AMD Ryzen 5 5600G
# Iteration taken: 147.14897799491882
# [202/489] AMD Ryzen 5 5600X
# Iteration taken: 161.70233392715454
# [203/489] Intel Core i7-7740K
# Iteration taken: 191.2619137763977
# [204/489] AMD Ryzen 3 1300X
# Iteration taken: 160.988872051239
# [205/489] AMD Ryzen 3 3300X
# Iteration taken: 173.00108003616333
# [206/489] AMD Ryzen 5 PRO 6650U
# Iteration taken: 87.14500999450684
# [207/489] AMD Ryzen 9 3900X
# Iteration taken: 166.71978402137756
# [208/489] Intel Core i7-8809G
# Iteration taken: 150.77485489845276
# [209/489] AMD Ryzen 7 2700X Eight-Core
# Iteration taken: 114.74998593330383
# [210/489] AMD Ryzen 7 3700X
# Iteration taken: 190.20052814483643
# [211/489] Intel Core i7-10700T
# Iteration taken: 184.0972239971161
# [212/489] Intel Xeon E-2288G
# Iteration taken: 84.62258791923523
# [213/489] AMD Ryzen 3 2200G
# Iteration taken: 116.1132709980011
# [214/489] Intel Core i9-10885H
# Iteration taken: 149.0308449268341
# [215/489] AMD Ryzen 9 3950X
# Iteration taken: 156.47836232185364
# [216/489] AMD Ryzen 5 2400G
# Iteration taken: 139.18521809577942
# [217/489] Intel Core i7-7700
# Iteration taken: 118.08315706253052
# [218/489] Intel Xeon E-2336
# Iteration taken: 108.29020380973816
# [219/489] Intel Core i7-5960X
# Iteration taken: 145.56777167320251
# [220/489] Intel Xeon E3-1260L v5
# Iteration taken: 159.94871282577515
# [221/489] Intel Core i5-6500
# Iteration taken: 197.97057509422302
# [222/489] Intel Core i3-10100
# Iteration taken: 140.76050996780396
# [223/489] AMD Custom APU 0405
# Iteration taken: 187.72995615005493
# [224/489] Intel Core i5-6260U
# Iteration taken: 148.2594029903412
# [225/489] Intel Xeon E3-1235L v5
# Iteration taken: 150.21932435035706
# [226/489] Intel Xeon E3-1240 v5
# Iteration taken: 148.22555708885193
# [227/489] Intel Core i7-8550U
# Iteration taken: 205.24217867851257
# [228/489] Intel Xeon E3-1270 v5
# Iteration taken: 194.92067217826843
# [229/489] Intel Xeon E3-1231 v3
# Iteration taken: 130.13162994384766
# [230/489] Intel Core i7-4790
# Iteration taken: 200.22150206565857
# [231/489] Intel Core i5-3470
# Iteration taken: 169.2965497970581
# [232/489] Intel Core i7-4770K
# Iteration taken: 172.2241508960724
# [233/489] Intel Core i5-4670
# Iteration taken: 202.18868923187256
# [234/489] Intel Core i7-4960X
# Iteration taken: 149.9185197353363
# [235/489] Intel Core i7-5600U
# Iteration taken: 89.1293089389801
# [236/489] AMD FX-8370 Eight-Core
# Iteration taken: 88.68652105331421
# [237/489] Intel Core i5-7600K
# Iteration taken: 95.14350986480713
# [238/489] AMD Ryzen 3 3200U
# Iteration taken: 214.6670548915863
# [239/489] Intel Core i5-5200U
# Iteration taken: 83.92401480674744
# [240/489] Intel Core i7-3770K
# Iteration taken: 115.05333185195923
# [241/489] Intel Xeon Max 9480
# Iteration taken: 55.38052010536194
# [242/489] AMD EPYC 9754
# Iteration taken: 99.70925402641296
# [243/489] Intel Xeon Gold 6444Y
# Iteration taken: 147.04271388053894
# [244/489] AMD RYZEN AI MAX PRO 390
# Iteration taken: 129.78515100479126
# [245/489] AMD Ryzen Threadripper PRO 5965WX
# Iteration taken: 178.09345269203186
# [246/489] AMD EPYC 7F32
# Iteration taken: 150.88052320480347
# [247/489] Intel Core Ultra 5 245K
# Iteration taken: 153.26642298698425
# [248/489] AMD Ryzen 9 9900X
# Iteration taken: 176.7541801929474
# [249/489] Intel Core i5-14600K
# Iteration taken: 165.23918414115906
# [250/489] AMD Ryzen 7 9700X
# Iteration taken: 206.3931701183319
# [251/489] AMD Ryzen 5 9600X
# Iteration taken: 146.18145489692688
# [252/489] AMD Ryzen 7 PRO 7840U
# Iteration taken: 151.30928683280945
# [253/489] AMD Ryzen Z1 Extreme
# Iteration taken: 194.84994792938232
# [254/489] AMD Ryzen 7 7840U
# Iteration taken: 111.44307208061218
# [255/489] Intel Core i7-1185G7
# Iteration taken: 137.0215721130371
# [256/489] AMD Ryzen 5 5500U
# Iteration taken: 166.96630096435547
# [257/489] AMD Ryzen 9 5900HX
# Iteration taken: 175.3027970790863
# [258/489] AMD EPYC 9654
# Iteration taken: 117.84482097625732
# [259/489] AMD EPYC 9634
# Iteration taken: 210.77366995811462
# [260/489] AMD EPYC 9634
# Iteration taken: 45.25308585166931
# [261/489] AMD EPYC 7643
# Iteration taken: 104.5797119140625
# [262/489] AMD EPYC 7643
# Iteration taken: 115.97713112831116
# [263/489] Intel Xeon Platinum 8260
# Iteration taken: 231.51398396492004
# [264/489] AMD Ryzen 7 7840HS
# Iteration taken: 124.42514395713806
# [265/489] AMD EPYC 72F3
# Iteration taken: 170.74369287490845
# [266/489] AMD Ryzen 7 7735HS
# Iteration taken: 188.18478989601135
# [267/489] AMD Ryzen 5 5560U
# Iteration taken: 118.44666814804077
# [268/489] AMD Ryzen 7 4700U
# Iteration taken: 160.3413610458374
# [269/489] Intel Xeon L5640
# Iteration taken: 120.7920970916748
# [270/489] Intel Core i3-12100
# Iteration taken: 181.9425826072693
# [271/489] Intel Core i5-8250U
# Iteration taken: 124.56874704360962
# [272/489] Intel Core i3-7100
# Iteration taken: 94.27761816978455
# [273/489] AMD EPYC 9384X
# Iteration taken: 118.84695172309875
# [274/489] Intel Xeon 6780E
# Iteration taken: 115.33701181411743
# [275/489] Intel Xeon 6766E
# Iteration taken: 129.6967327594757
# [276/489] AMD EPYC 7313
# Iteration taken: 216.1052541732788
# [277/489] AMD Ryzen Threadripper 9980X
# Iteration taken: 123.97976493835449
# [278/489] AMD EPYC 7373X
# Iteration taken: 65.8044958114624
# [279/489] Intel Xeon Max 9468
# Iteration taken: 168.91129398345947
# [280/489] AMD EPYC 7313
# Iteration taken: 67.64658808708191
# [281/489] Intel Xeon Max 9468
# Iteration taken: 31.07015609741211
# [282/489] AMD EPYC 7642
# Iteration taken: 77.057785987854
# [283/489] Intel Xeon Silver 4108
# Iteration taken: 193.11097407341003
# [284/489] AMD Ryzen 7 5800H
# Iteration taken: 125.26904773712158
# [285/489] AMD Ryzen 5 3600X
# Iteration taken: 200.43748378753662
# [286/489] Intel Core i7 990X
# Iteration taken: 126.90680599212646
# [287/489] AMD EPYC 7453
# Iteration taken: 147.77338123321533
# [288/489] AMD Ryzen Threadripper PRO 3975WX
# Iteration taken: 84.94691181182861
# [289/489] AMD EPYC 7453
# Iteration taken: 90.72234869003296
# [290/489] AMD EPYC 7502
# Iteration taken: 174.9009108543396
# [291/489] AMD EPYC 7452
# Iteration taken: 131.35361194610596
# [292/489] Intel Xeon Gold 6138
# Iteration taken: 121.44036412239075
# [293/489] AMD EPYC 7F72
# Iteration taken: 82.58244013786316
# [294/489] Intel Xeon Gold 6140
# Iteration taken: 163.16642308235168
# [295/489] AMD EPYC 7352
# Iteration taken: 137.78446006774902
# [296/489] Intel Xeon E5-2683 v4
# Iteration taken: 141.96736693382263
# [297/489] Intel Xeon E5-4620 v4
# Iteration taken: 90.17987036705017
# [298/489] AMD Ryzen Threadripper 1950X
# Iteration taken: 180.38771104812622
# [299/489] Intel Xeon E5-2680 v2
# Iteration taken: 103.39660692214966
# [300/489] AMD Ryzen Threadripper 2920X
# Iteration taken: 107.00890707969666
# [301/489] Intel Xeon Silver 4210
# Iteration taken: 135.56687831878662
# [302/489] AMD EPYC 7351P
# Iteration taken: 184.95517325401306
# [303/489] Intel Xeon Gold 5218
# Iteration taken: 43.54906225204468
# [304/489] Intel Xeon E5-2643 v3
# Iteration taken: 132.46272492408752
# [305/489] AMD Ryzen 7 PRO 4750G
# Iteration taken: 114.43522310256958
# [306/489] AMD Ryzen 7 5700G
# Iteration taken: 128.04328608512878
# [307/489] Intel Xeon Silver 4214R
# Iteration taken: 139.1100299358368
# [308/489] AMD Ryzen 7 3800X
# Iteration taken: 161.0364921092987
# [309/489] AMD Ryzen 7 5700X
# Iteration taken: 120.68088603019714
# [310/489] AMD EPYC 7262
# Iteration taken: 120.43105101585388
# [311/489] AMD Ryzen 7 1700X Eight-Core
# Iteration taken: 154.07243275642395
# [312/489] Intel Xeon X5675
# Iteration taken: 84.92195701599121
# [313/489] AMD EPYC 7252
# Iteration taken: 186.56595516204834
# [314/489] Intel Xeon Silver 4215R
# Iteration taken: 228.08893513679504
# [315/489] Intel Xeon Gold 5217
# Iteration taken: 205.4375500679016
# [316/489] Intel Xeon E5-2620 v2
# Iteration taken: 131.43960905075073
# [317/489] AMD Ryzen 5 3600
# Iteration taken: 203.96020197868347
# [318/489] AMD Ryzen 5 2600X Six-Core
# Iteration taken: 178.60967302322388
# [319/489] AMD Ryzen 5 5500
# Iteration taken: 161.97576594352722
# [320/489] AMD Ryzen 5 1600X Six-Core
# Iteration taken: 75.30071091651917
# [321/489] Intel Core i5-12400
# Iteration taken: 177.62554287910461
# [322/489] AMD EPYC 7251
# Iteration taken: 128.66116404533386
# [323/489] AMD Ryzen 5 2600 Six-Core
# Iteration taken: 168.5492341518402
# [324/489] AMD Ryzen 5 1600 Six-Core
# Iteration taken: 189.01842522621155
# [325/489] Intel Xeon Gold 5215
# Iteration taken: 123.74672937393188
# [326/489] AMD Ryzen 5 2400G with Radeon Vega
# Iteration taken: 171.0298309326172
# [327/489] Intel Core i5-10210U
# Iteration taken: 131.67136406898499
# [328/489] AMD Ryzen 5 1500X
# Iteration taken: 176.35559105873108
# [329/489] Intel Core i7-6700K
# Iteration taken: 134.84012413024902
# [330/489] Intel Core i5-8400H
# Iteration taken: 172.30755805969238
# [331/489] AMD FX-8350 Eight-Core
# Iteration taken: 203.2879400253296
# [332/489] AMD EPYC 7601
# Iteration taken: 74.99594593048096
# [333/489] Intel Core i7-2700K
# Iteration taken: 107.69903492927551
# [334/489] Intel Core i5-1135G7
# Iteration taken: 202.19423007965088
# [335/489] Intel Core i3-8100
# Iteration taken: 153.22680187225342
# [336/489] Intel Core i7-3632QM
# Iteration taken: 170.9150378704071
# [337/489] Intel Core i5-4460
# Iteration taken: 109.58957123756409
# [338/489] Intel Core i5-2400
# Iteration taken: 170.80557703971863
# [339/489] Intel Core i7-5557U
# Iteration taken: 137.75152206420898
# [340/489] AMD Phenom 9650
# Iteration taken: 182.91488099098206
# [341/489] AMD Phenom II X3 720
# Iteration taken: 125.11102795600891
# [342/489] Intel Core i5-3320M
# Iteration taken: 178.98432302474976
# [343/489] Intel Core i5-7200U
# Iteration taken: 90.18639516830444
# [344/489] Intel Core i5-6300U
# Iteration taken: 131.4792878627777
# [345/489] Intel Core i7-6500U
# Iteration taken: 170.1619529724121
# [346/489] Intel Core i5-4210U
# Iteration taken: 172.69413304328918
# [347/489] Intel Core i3-7020U
# Iteration taken: 129.08087134361267
# [348/489] Intel Core 2 Duo T9500
# Iteration taken: 129.15622401237488
# [349/489] AMD Ryzen 7 4800U
# Iteration taken: 161.4130687713623
# [350/489] Intel Core i7-9700TE
# Iteration taken: 154.8616418838501
# [351/489] Intel Pentium Gold G6400
# Iteration taken: 207.17769408226013
# [352/489] Intel Celeron G5900
# Iteration taken: 110.22245573997498
# [353/489] AMD EPYC 4585PX
# Iteration taken: 132.85986614227295
# [354/489] AMD EPYC 4565P
# Iteration taken: 98.1761121749878
# [355/489] AMD EPYC 4345P
# Iteration taken: 126.62886023521423
# [356/489] AMD EPYC 4465P
# Iteration taken: 142.07171607017517
# [357/489] AMD EPYC 4545P
# Iteration taken: 181.62847185134888
# [358/489] AMD EPYC 4245P
# Iteration taken: 183.39826798439026
# [359/489] AMD EPYC 4344P
# Iteration taken: 122.59464621543884
# [360/489] AMD EPYC 4244P
# Iteration taken: 110.88684391975403
# [361/489] Intel Xeon 6369P
# Iteration taken: 141.754252910614
# [362/489] AMD Ryzen 7 8700G
# Iteration taken: 132.40556597709656
# [363/489] Intel Xeon E E-2488
# Iteration taken: 149.6185817718506
# [364/489] AMD Ryzen 5 8400F
# Iteration taken: 141.4479422569275
# [365/489] Intel Core Ultra 7 155H
# Iteration taken: 163.51823782920837
# [366/489] Intel Core i5-14400F
# Iteration taken: 171.71203207969666
# [367/489] Intel Xeon W-1370P
# Iteration taken: 109.30131506919861
# [368/489] Intel Core i9-10900KF
# Iteration taken: 88.52093482017517
# [369/489] AMD Ryzen AI 9 HX 370
# Iteration taken: 141.0556571483612
# [370/489] AMD EPYC 72F3
# Iteration taken: 72.75404214859009
# [371/489] Intel Xeon Gold 5412U
# Iteration taken: 145.9312059879303
# [372/489] AMD EPYC 7313P
# Iteration taken: 139.724839925766
# [373/489] AMD EPYC 7K83
# Iteration taken: 159.91332507133484
# [374/489] Intel Core i9-9900
# Iteration taken: 120.30441284179688
# [375/489] AMD EPYC 7663
# Iteration taken: 72.95618605613708
# [376/489] Intel Core i7-8700B
# Iteration taken: 128.0543007850647
# [377/489] Intel Xeon W-2295
# Iteration taken: 144.45471787452698
# [378/489] AMD EPYC 7F32
# Iteration taken: 77.1086118221283
# [379/489] AMD Ryzen 3 3100
# Iteration taken: 193.10750007629395
# [380/489] Intel Xeon Platinum 8272CL
# Iteration taken: 207.29441738128662
# [381/489] Intel Xeon Platinum 8259L
# Iteration taken: 211.32740926742554
# [382/489] Intel Xeon Gold 6226R
# Iteration taken: 56.688112020492554
# [383/489] Intel Xeon Gold 6254
# Iteration taken: 184.70480918884277
# [384/489] Intel Xeon Platinum 8253
# Iteration taken: 221.10245609283447
# [385/489] Intel Core i7-6700HQ
# Iteration taken: 138.69952416419983
# [386/489] Intel Xeon Gold 6254
# Iteration taken: 33.39904594421387
# [387/489] AMD Athlon 3000G
# Iteration taken: 117.4206748008728
# [388/489] AMD Ryzen 3 3200G
# Iteration taken: 167.24547910690308
# [389/489] Intel Xeon E5-2678 v3
# Iteration taken: 149.79081797599792
# [390/489] Intel Core i5-5300U
# Iteration taken: 147.23725008964539
# [391/489] Intel Core i7-5500U
# Iteration taken: 133.83970618247986
# [392/489] Intel Core i7-3517U
# Iteration taken: 101.53391718864441
# [393/489] Intel Core i3-4130
# Iteration taken: 109.70474600791931
# [394/489] Intel Xeon E5-2650 0
# Iteration taken: 169.4949119091034
# [395/489] AMD A10-7870K Radeon R7 12 Compute Cores 4C+8G
# Iteration taken: 204.59050297737122
# [396/489] AMD FX-8150 Eight-Core
# Iteration taken: 191.29547595977783
# [397/489] AMD A10-7850K APU
# Iteration taken: 150.13947701454163
# [398/489] AMD EPYC 7713P
# Iteration taken: 172.88944506645203
# [399/489] Intel Xeon Gold 6338
# Iteration taken: 121.47774314880371
# [400/489] AMD EPYC 7513
# Iteration taken: 109.4855318069458
# [401/489] AMD EPYC 7413
# Iteration taken: 101.88260293006897
# [402/489] Intel Xeon Gold 6338
# Iteration taken: 53.545665979385376
# [403/489] Intel Xeon 6728P
# Iteration taken: 143.51412796974182
# [404/489] Intel Xeon Platinum
# Iteration taken: 156.48380303382874
# [405/489] AMD EPYC 7K62
# Iteration taken: 105.96581816673279
# [406/489] AMD EPYC 7473X
# Iteration taken: 155.1472749710083
# [407/489] AMD EPYC 7663P
# Iteration taken: 174.91761088371277
# [408/489] Intel Xeon E5-2690 v4
# Iteration taken: 154.69318199157715
# [409/489] Intel Xeon E5-2670 0
# Iteration taken: 136.82175517082214
# [410/489] AMD RYZEN AI MAX+ PRO 395
# Iteration taken: 90.80314493179321
# [411/489] AMD Ryzen AI MAX+ PRO 395
# Iteration taken: 211.43816423416138
# [412/489] AMD Ryzen AI 9 365
# Iteration taken: 81.28936386108398
# [413/489] Intel Core Ultra 7 256V
# Iteration taken: 122.74173521995544
# [414/489] Intel Core Ultra 7 258V
# Iteration taken: 188.98887395858765
# [415/489] AMD Ryzen AI 5 340
# Iteration taken: 140.7304048538208
# [416/489] AMD Ryzen AI 7 PRO 360
# Iteration taken: 114.008220911026
# [417/489] Intel Core i5-1334U
# Iteration taken: 166.14608478546143
# [418/489] Intel Core i5-12600
# Iteration taken: 152.08527970314026
# [419/489] AMD Ryzen 7 8845HS
# Iteration taken: 122.66707801818848
# [420/489] Intel Xeon Platinum 8480+
# Iteration taken: 143.72042894363403
# [421/489] Intel Core Ultra 7 165U
# Iteration taken: 205.04909491539001
# [422/489] AMD Ryzen 7 5800U
# Iteration taken: 117.73312520980835
# [423/489] Intel Core i9-10850K
# Iteration taken: 150.20700597763062
# [424/489] AMD Ryzen 5 PRO 4650G
# Iteration taken: 202.8923659324646
# [425/489] Intel N150
# Iteration taken: 141.3675811290741
# [426/489] AMD Ryzen 5 3500X
# Iteration taken: 205.90445613861084
# [427/489] AMD Ryzen Threadripper 1900X
# Iteration taken: 170.72855019569397
# [428/489] AMD Ryzen 7 PRO 3700U
# Iteration taken: 121.90138697624207
# [429/489] Intel Core i7-8700
# Iteration taken: 204.78814005851746
# [430/489] Intel Core i5-1035G1
# Iteration taken: 163.70144724845886
# [431/489] Intel Core i5-8300H
# Iteration taken: 102.77977204322815
# [432/489] Intel Core i5-8600K
# Iteration taken: 140.90842485427856
# [433/489] AMD EPYC 7402
# Iteration taken: 143.46579575538635
# [434/489] AMD EPYC 7302
# Iteration taken: 135.79896998405457
# [435/489] Intel Pentium G4400
# Iteration taken: 80.10820627212524
# [436/489] AMD EPYC 7502
# Iteration taken: 46.07339811325073
# [437/489] Intel Core i7-8559U
# Iteration taken: 105.97102284431458
# [438/489] Intel Core i7-9850H
# Iteration taken: 132.44644689559937
# [439/489] AMD Ryzen 5 3500U
# Iteration taken: 146.47645688056946
# [440/489] Intel Core i5-3550
# Iteration taken: 107.36952018737793
# [441/489] Intel Core i5-3570K
# Iteration taken: 131.73137378692627
# [442/489] Intel Core i5-6500T
# Iteration taken: 157.0437581539154
# [443/489] Intel Core i7-5820K
# Iteration taken: 183.50961685180664
# [444/489] Intel Core i5-4300M
# Iteration taken: 159.25398802757263
# [445/489] Intel Core i5-4430
# Iteration taken: 214.52244305610657
# [446/489] Intel Xeon Gold 6130
# Iteration taken: 163.87257194519043
# [447/489] Intel Xeon Gold 6142
# Iteration taken: 77.39389491081238
# [448/489] Intel Xeon W-2123
# Iteration taken: 136.7614459991455
# [449/489] Intel Core i5-2500S
# Iteration taken: 202.66317796707153
# [450/489] Intel Core i5-6200U
# Iteration taken: 153.15745902061462
# [451/489] Intel Core i3-8100T
# Iteration taken: 137.11222314834595
# [452/489] Intel Core i7-4558U
# Iteration taken: 85.42197895050049
# [453/489] Intel Core m3-7Y30
# Iteration taken: 114.91070985794067
# [454/489] Intel Core i3-2120
# Iteration taken: 110.43047976493835
# [455/489] Intel Core i7-3770
# Iteration taken: 172.44366002082825
# [456/489] Intel Core i7-2600
# Iteration taken: 133.47666597366333
# [457/489] Intel Core i5-3427U
# Iteration taken: 142.70129013061523
# [458/489] AMD FX-6300 Six-Core
# Iteration taken: 180.05299615859985
# [459/489] Intel Core i5-4278U
# Iteration taken: 147.86803793907166
# [460/489] AMD A12-9720P RADEON R7 12 COMPUTE CORES 4C+8G
# Iteration taken: 187.78712606430054
# [461/489] Intel Core i5
# Iteration taken: 140.00774216651917
# [462/489] Intel Xeon Silver 4214
# Iteration taken: 146.05957102775574
# [463/489] Intel Core i5-2410M
# Iteration taken: 139.00023889541626
# [464/489] Intel Core 2 Duo E8500
# Iteration taken: 73.76411700248718
# [465/489] Intel Core i5-2520M
# Iteration taken: 123.62406826019287
# [466/489] Intel Core i7-3630QM
# Iteration taken: 137.16473007202148
# [467/489] Intel Core i7 920
# Iteration taken: 135.9529402256012
# [468/489] Intel Core m3-6Y30
# Iteration taken: 87.13973617553711
# [469/489] Intel Core 2 Duo T7700
# Iteration taken: 158.3907172679901
# [470/489] Intel Xeon E3-12xx v2
# Iteration taken: 196.3146469593048
# [471/489] Intel Core i3-3110M
# Iteration taken: 180.77518367767334
# [472/489] Intel Celeron N3350
# Iteration taken: 154.33309698104858
# [473/489] Intel Core 2 Duo T7100
# Iteration taken: 162.93165683746338
# [474/489] Intel Pentium N4200
# Iteration taken: 259.48258686065674
# [475/489] Intel Celeron J3455
# Iteration taken: 105.21059012413025
# [476/489] Intel Core 2 Duo P7350
# Iteration taken: 185.35692310333252
# [477/489] Intel Celeron N2830
# Iteration taken: 109.53782677650452
# [478/489] AMD A6-3410MX APU
# Iteration taken: 154.63833713531494
# [479/489] Intel Core i5 460M
# Iteration taken: 152.89996099472046
# [480/489] Intel Atom x5-Z8350
# Iteration taken: 257.8979251384735
# [481/489] AMD EPYC 7303
# Iteration taken: 175.6537148952484
# [482/489] Intel Xeon Gold 6414U
# Iteration taken: 215.18574404716492
# [483/489] Intel Xeon 6766E
# Iteration taken: 35.13521909713745
# [484/489] Intel Xeon Gold 5416S
# Iteration taken: 188.5478641986847
# [485/489] Intel Xeon E5-2687W 0
# Iteration taken: 199.99297714233398
# [486/489] Intel Core i7-12700KF
# Iteration taken: 193.04491114616394
# [487/489] Intel Xeon Gold 6144
# Iteration taken: 141.05274319648743
# [488/489] Intel Core i7-1185G7E
# Iteration taken: 115.62637186050415
# [489/489] Intel Core i3-1005G1
# Iteration taken: 210.55748391151428
#
#
# Time taken 68620.01694202423
# Resolved: 429 Unresolved: 4
# AMD Ryzen 9 9950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-9950x.c3649
# AMD RYZEN AI MAX+ 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-395.c3994
# Intel Core i9-13900K -> https://www.techpowerup.com/cpu-specs/core-i9-13900k.c2817
# AMD Ryzen 7 7700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-7700x.c2848
# AMD Ryzen 9 7950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-7950x.c2846
# Intel Core i9-14900K -> https://www.techpowerup.com/cpu-specs/core-i9-14900k.c3269
# AMD EPYC 4364P -> https://www.techpowerup.com/cpu-specs/epyc-4364p.c3611
# AMD Ryzen 9 7900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900x.c2847
# Intel Core i9-12900K -> https://www.techpowerup.com/cpu-specs/core-i9-12900k.c2505
# AMD EPYC 4564P -> https://www.techpowerup.com/cpu-specs/epyc-4564p.c3613
# AMD EPYC 4464P -> https://www.techpowerup.com/cpu-specs/epyc-4464p.c3612
# AMD EPYC 4584PX -> https://www.techpowerup.com/cpu-specs/epyc-4584px.c3607
# AMD EPYC 4484PX -> https://www.techpowerup.com/cpu-specs/epyc-4484px.c3606
# AMD Ryzen 9 5900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-5900x.c2363
# AMD Ryzen 5 7600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-7600x.c2849
# Intel Core i9-11900K -> https://www.techpowerup.com/cpu-specs/core-i9-11900k.c2366
# AMD Ryzen 9 5950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-5950x.c2364
# AMD Ryzen 7 5800X -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800x.c2362
# AMD Ryzen 7 5800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800x3d.c2532
# Intel Core i9-10900K -> https://www.techpowerup.com/cpu-specs/core-i9-10900k.c2266
# Intel Core i5-13600K -> https://www.techpowerup.com/cpu-specs/core-i5-13600k.c2829
# AMD EPYC 4124P -> https://www.techpowerup.com/cpu-specs/epyc-4124p.c3610
# AMD Ryzen Threadripper 3970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3970x.c2269
# AMD Ryzen Threadripper 3990X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3990x.c2271
# AMD Ryzen 9 3900XT -> https://www.techpowerup.com/cpu-specs/ryzen-9-3900xt.c2308
# Intel Core i5-12600K -> https://www.techpowerup.com/cpu-specs/core-i5-12600k.c2509
# Intel Core i7-7900X -> https://www.techpowerup.com/cpu-specs/core-i7-7800x.c1905
# Intel Core i5-11600K -> https://www.techpowerup.com/cpu-specs/core-i5-11600k.c2400
# Intel Core i9-7980XE -> https://www.techpowerup.com/cpu-specs/core-i9-7980xe.c1952
# Intel Core i5-13400 -> https://www.techpowerup.com/cpu-specs/core-i5-13400.c2994
# AMD Ryzen 7 PRO 5850U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-5850u.c2774
# AMD Ryzen Threadripper 2990WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2990wx.c2069
# AMD Ryzen 7 PRO 6850U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-6850u.c2768
# AMD Ryzen 5 3600XT -> https://www.techpowerup.com/cpu-specs/ryzen-5-3600xt.c2313
# AMD EPYC 73F3 -> https://www.techpowerup.com/cpu-specs/epyc-73f3.c2387
# AMD EPYC 75F3 -> https://www.techpowerup.com/cpu-specs/epyc-75f3.c2378
# AMD Ryzen Threadripper 3960X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3960x.c2268
# AMD EPYC 74F3 -> https://www.techpowerup.com/cpu-specs/epyc-74f3.c2383
# Intel Xeon E-2278GEL -> https://www.techpowerup.com/cpu-specs/xeon-e-2278gel.c3487
# AMD Ryzen 7 1700 Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-1700.c1893
# AMD EPYC 7713 -> https://www.techpowerup.com/cpu-specs/epyc-7713.c2374
# Intel Core i9-9900KS -> https://www.techpowerup.com/cpu-specs/core-i9-9900ks.c2242
# AMD EPYC 7F52 -> https://www.techpowerup.com/cpu-specs/epyc-7f52.c2301
# Intel Core i9-9900K -> https://www.techpowerup.com/cpu-specs/core-i9-9900k.c2098
# AMD EPYC 7513 -> https://www.techpowerup.com/cpu-specs/epyc-7513.c2381
# AMD EPYC 7763 -> https://www.techpowerup.com/cpu-specs/epyc-7763.c2373
# AMD Ryzen 5 4500U -> https://www.techpowerup.com/cpu-specs/ryzen-5-4500u.c2285
# Intel Xeon Gold 6248R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6348.c2432
# Intel Core i7-1280P -> https://www.techpowerup.com/cpu-specs/core-i7-1280p.c2579
# AMD EPYC 7542 -> https://www.techpowerup.com/cpu-specs/epyc-7542.c2249
# AMD EPYC 7742 -> https://www.techpowerup.com/cpu-specs/epyc-7742.c2245
# Intel Core i7-6700 -> https://www.techpowerup.com/cpu-specs/core-i7-6700.c1827
# AMD EPYC 7502P -> https://www.techpowerup.com/cpu-specs/epyc-7502p.c2260
# AMD EPYC 7402P -> https://www.techpowerup.com/cpu-specs/epyc-7402p.c2261
# Intel Xeon Gold 6258R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439
# Intel Core i7-6800K -> https://www.techpowerup.com/cpu-specs/core-i7-6800k.c1844
# AMD EPYC 7302P -> https://www.techpowerup.com/cpu-specs/epyc-7302p.c2262
# AMD EPYC 7532 -> https://www.techpowerup.com/cpu-specs/epyc-7352.c2253
# Intel Xeon Platinum 8280 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8280.c2170
# AMD EPYC 7552 -> https://www.techpowerup.com/cpu-specs/epyc-7552.c2248
# AMD EPYC 7642 -> https://www.techpowerup.com/cpu-specs/epyc-7642.c2247
# AMD EPYC 7662 -> https://www.techpowerup.com/cpu-specs/epyc-7663.c2376
# Intel Xeon E-2388G -> https://www.techpowerup.com/cpu-specs/xeon-e-2388g.c2492
# AMD EPYC 7272 -> https://www.techpowerup.com/cpu-specs/epyc-7272.c2256
# AMD EPYC 7232P -> https://www.techpowerup.com/cpu-specs/epyc-7232p.c2263
# Intel Xeon Gold 5220R -> https://www.techpowerup.com/cpu-specs/xeon-gold-5320.c2449
# AMD EPYC 7282 -> https://www.techpowerup.com/cpu-specs/epyc-7282.c2255
# Intel Xeon Gold 6226R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439
# AMD Ryzen 7 3800XT -> https://www.techpowerup.com/cpu-specs/ryzen-7-3800xt.c2309
# Intel Core i7-8700K -> https://www.techpowerup.com/cpu-specs/core-i7-8700k.c1947
# AMD Ryzen 7 PRO 3700 -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700.c3703
# AMD Ryzen 9 PRO 3900 -> https://www.techpowerup.com/cpu-specs/ryzen-9-pro-6950h.c2765
# Intel Xeon E5-1680 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-1680-v3.c2664
# Intel Core i7-7700K -> https://www.techpowerup.com/cpu-specs/core-i7-7700k.c1842
# Intel Xeon E-2278G -> https://www.techpowerup.com/cpu-specs/xeon-e-2278g.c3537
# Intel Core i7-1165G7 -> https://www.techpowerup.com/cpu-specs/core-i7-1165g7.c2343
# AMD Ryzen 7 2700 Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-2700.c2013
# AMD Ryzen Threadripper 2970WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2970wx.c2068
# Intel Xeon E5-2687W v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2687w-v3.c2877
# Intel Core i5-9400F -> https://www.techpowerup.com/cpu-specs/core-i5-9400f.c2145
# AMD Ryzen Threadripper 2950X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2950x.c2067
# Intel Xeon E3-1275 v6 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1285-v6.c1999
# AMD EPYC 7601 -> https://www.techpowerup.com/cpu-specs/epyc-7601.c1920
# Intel Core i7-9750H -> https://www.techpowerup.com/cpu-specs/core-i7-9750h.c2290
# Intel Core i7-8565U -> https://www.techpowerup.com/cpu-specs/core-i7-8565u.c2103
# Intel Xeon E3-1245 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1245-v5.c3232
# Intel Xeon E3-1280 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1280-v5.c1841
# Intel Core i7-1065G7 -> https://www.techpowerup.com/cpu-specs/core-i7-1065g7.c2228
# Intel Core i7-4790K -> https://www.techpowerup.com/cpu-specs/core-i7-4790k.c1761
# AMD Ryzen 5 3400G -> https://www.techpowerup.com/cpu-specs/ryzen-5-3400g.c2204
# Intel Xeon Silver 4216 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4116.c2057
# AMD EPYC 7551 -> https://www.techpowerup.com/cpu-specs/epyc-7551.c1921
# Intel Celeron G6900 -> https://www.techpowerup.com/cpu-specs/celeron-g6900.c2570
# Intel Core i7- -> https://www.techpowerup.com/cpu-specs/core-i7-10510u.c2236
# Intel Xeon E5-2609 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2609.c966
# Intel Core i7-4600U -> https://www.techpowerup.com/cpu-specs/core-i7-4600u.c1717
# Intel Xeon 6980P -> https://www.techpowerup.com/cpu-specs/xeon-6980p.c3862
# AMD EPYC 9755 -> https://www.techpowerup.com/cpu-specs/epyc-9755.c3881
# AMD EPYC 9575F -> https://www.techpowerup.com/cpu-specs/epyc-9575f.c3885
# AMD EPYC 9655 -> https://www.techpowerup.com/cpu-specs/epyc-9655.c3882
# AMD EPYC 9965 -> https://www.techpowerup.com/cpu-specs/epyc-9965.c3904
# AMD EPYC 9684X -> https://www.techpowerup.com/cpu-specs/epyc-9684x.c3253
# AMD EPYC 9374F -> https://www.techpowerup.com/cpu-specs/epyc-9374f.c2925
# AMD EPYC 9554 -> https://www.techpowerup.com/cpu-specs/epyc-9554.c2930
# AMD EPYC 9384X -> https://www.techpowerup.com/cpu-specs/epyc-9384x.c3254
# AMD EPYC 9184X -> https://www.techpowerup.com/cpu-specs/epyc-9184x.c3255
# INTEL XEON PLATINUM 8592+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8592.c3408
# Intel Xeon Platinum 8490H -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8490h.c2942
# Intel Xeon Platinum 8468 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8468.c3094
# Intel Xeon Platinum 8462Y+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8462y.c3137
# AMD EPYC 9655P -> https://www.techpowerup.com/cpu-specs/epyc-9655p.c3883
# Intel Xeon Gold 6442Y -> https://www.techpowerup.com/cpu-specs/xeon-gold-6442y.c3157
# AMD EPYC 9845 -> https://www.techpowerup.com/cpu-specs/epyc-9845.c3905
# AMD EPYC 9654 -> https://www.techpowerup.com/cpu-specs/epyc-9654.c2933
# AMD EPYC 9754 -> https://www.techpowerup.com/cpu-specs/epyc-9754.c3257
# Intel Xeon Platinum 8380 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8380.c2421
# Intel Xeon Platinum 8362 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8362.c2426
# AMD EPYC 7773X -> https://www.techpowerup.com/cpu-specs/epyc-7773x.c2759
# AMD EPYC 7573X -> https://www.techpowerup.com/cpu-specs/epyc-7573x.c2760
# AMD EPYC 7663 -> https://www.techpowerup.com/cpu-specs/epyc-7663.c2376
# Intel Xeon Gold 6342 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440
# AMD EPYC 7543 -> https://www.techpowerup.com/cpu-specs/epyc-7543.c2379
# AMD EPYC 7373X -> https://www.techpowerup.com/cpu-specs/epyc-7373x.c2762
# AMD Ryzen Threadripper PRO 7995WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-7995wx.c3301
# AMD EPYC 7443 -> https://www.techpowerup.com/cpu-specs/epyc-7443.c2384
# AMD EPYC 7343 -> https://www.techpowerup.com/cpu-specs/epyc-7343.c2388
# Intel Xeon Gold 6346 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6346.c2433
# Intel Xeon Max 9480 -> https://www.techpowerup.com/cpu-specs/xeon-max-9480.c3084
# AMD EPYC 9534 -> https://www.techpowerup.com/cpu-specs/epyc-9534.c2929
# Intel Xeon Platinum 8471N -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8471n.c3092
# AMD EPYC 7F72 -> https://www.techpowerup.com/cpu-specs/epyc-7f72.c2302
# AMD Ryzen Threadripper PRO 9995WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-9995wx.c4163
# AMD EPYC 8534P -> https://www.techpowerup.com/cpu-specs/epyc-8534p.c3288
# AMD EPYC 8534PN -> https://www.techpowerup.com/cpu-specs/epyc-8534pn.c3289
# AMD Ryzen Threadripper 9970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-9970x.c4170
# AMD Ryzen Threadripper 7970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7970x.c3358
# AMD Ryzen Threadripper 7980X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7980x.c3357
# AMD EPYC 7702 -> https://www.techpowerup.com/cpu-specs/epyc-7702.c2246
# Intel Xeon E5-2699 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2699a-v4.c3227
# Intel Xeon E5-2696 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2696-v3.c2903
# Intel Core Ultra 9 285K -> https://www.techpowerup.com/cpu-specs/core-ultra-9-285k.c3773
# Intel Xeon Gold 5218 -> https://www.techpowerup.com/cpu-specs/xeon-gold-5318h.c2456
# AMD Ryzen 9 9900X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-9900x3d.c3997
# Intel Core i9-7960X -> https://www.techpowerup.com/cpu-specs/core-i9-7960x.c1950
# AMD Ryzen 9 9950X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-9950x3d.c3993
# Intel Core i3-14100 -> https://www.techpowerup.com/cpu-specs/core-i3-14100.c3450
# AMD Ryzen 7 9800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-9800x3d.c3891
# Intel Core i9-10980XE -> https://www.techpowerup.com/cpu-specs/core-i9-10980xe.c2238
# AMD Ryzen 5 8600G -> https://www.techpowerup.com/cpu-specs/ryzen-5-8600g.c3435
# AMD Ryzen 5 8500G -> https://www.techpowerup.com/cpu-specs/ryzen-5-8500g.c3436
# AMD Ryzen 7 7800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-7800x3d.c3022
# AMD Ryzen 9 7900X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900x3d.c3023
# AMD Ryzen 9 7950X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-7950x3d.c3024
# AMD Ryzen 9 7900 -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900.c2961
# AMD Ryzen 5 7600 -> https://www.techpowerup.com/cpu-specs/ryzen-5-7600.c2959
# AMD Ryzen 7 7700 -> https://www.techpowerup.com/cpu-specs/ryzen-7-7700.c2960
# Intel Core i5-14500 -> https://www.techpowerup.com/cpu-specs/core-i5-14500.c3448
# AMD Ryzen 9 6900HX -> https://www.techpowerup.com/cpu-specs/ryzen-9-6900hx.c2529
# Intel Core i9-12900H -> https://www.techpowerup.com/cpu-specs/core-i9-12900h.c2539
# Intel Core i7-12700K -> https://www.techpowerup.com/cpu-specs/core-i7-12700k.c2507
# Intel Core i9-11980HK -> https://www.techpowerup.com/cpu-specs/core-i9-11980hk.c2474
# Intel Core i7-11700K -> https://www.techpowerup.com/cpu-specs/core-i7-11700k.c2367
# Intel Core i7-11700B -> https://www.techpowerup.com/cpu-specs/core-i7-11700b.c4246
# AMD Ryzen 7 1800X Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-1800x.c1879
# Intel Core i5-10600K -> https://www.techpowerup.com/cpu-specs/core-i5-10600k.c2213
# Intel Core i7-8086K -> https://www.techpowerup.com/cpu-specs/core-i7-8086k.c2054
# Intel Core i5-8400 -> https://www.techpowerup.com/cpu-specs/core-i5-8400.c1964
# AMD Ryzen 5 5600G -> https://www.techpowerup.com/cpu-specs/ryzen-5-5600g.c2471
# AMD Ryzen 5 5600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-5600x.c2365
# Intel Core i7-7740K -> https://www.techpowerup.com/cpu-specs/core-i7-7740x.c1866
# AMD Ryzen 3 1300X -> https://www.techpowerup.com/cpu-specs/ryzen-3-1300x.c1898
# AMD Ryzen 3 3300X -> https://www.techpowerup.com/cpu-specs/ryzen-3-3300x.c2297
# AMD Ryzen 5 PRO 6650U -> https://www.techpowerup.com/cpu-specs/ryzen-5-pro-6650u.c2771
# AMD Ryzen 9 3900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-3900x.c2128
# Intel Core i7-8809G -> https://www.techpowerup.com/cpu-specs/core-i7-8809g.c1980
# AMD Ryzen 7 2700X Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-2700x.c2011
# AMD Ryzen 7 3700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-3700x.c2130
# Intel Core i7-10700T -> https://www.techpowerup.com/cpu-specs/core-i7-10700.c2214
# Intel Xeon E-2288G -> https://www.techpowerup.com/cpu-specs/xeon-e-2288g.c3534
# AMD Ryzen 3 2200G -> https://www.techpowerup.com/cpu-specs/ryzen-3-2200g.c1978
# Intel Core i9-10885H -> https://www.techpowerup.com/cpu-specs/core-i9-10885h.c2356
# AMD Ryzen 9 3950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-3950x.c2203
# AMD Ryzen 5 2400G -> https://www.techpowerup.com/cpu-specs/ryzen-5-2400g.c1976
# Intel Core i7-7700 -> https://www.techpowerup.com/cpu-specs/core-i7-7700.c1843
# Intel Xeon E-2336 -> https://www.techpowerup.com/cpu-specs/xeon-e-2336.c2497
# Intel Core i7-5960X -> https://www.techpowerup.com/cpu-specs/core-i7-5960x.c1765
# Intel Xeon E3-1260L v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1260l-v5.c3231
# Intel Core i5-6500 -> https://www.techpowerup.com/cpu-specs/core-i5-6500.c1829
# Intel Core i3-10100 -> https://www.techpowerup.com/cpu-specs/core-i3-10100.c2206
# Intel Core i5-6260U -> https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556
# Intel Xeon E3-1235L v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1235l-v5.c3235
# Intel Xeon E3-1240 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1240-v5.c3234
# Intel Core i7-8550U -> https://www.techpowerup.com/cpu-specs/core-i7-8550u.c1974
# Intel Xeon E3-1270 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1270-v5.c3229
# Intel Xeon E3-1231 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1231-v3.c3183
# Intel Core i7-4790 -> https://www.techpowerup.com/cpu-specs/core-i7-4790.c1747
# Intel Core i5-3470 -> https://www.techpowerup.com/cpu-specs/core-i5-3470.c1039
# Intel Core i7-4770K -> https://www.techpowerup.com/cpu-specs/core-i7-4770k.c1459
# Intel Core i5-4670 -> https://www.techpowerup.com/cpu-specs/core-i5-4670.c1477
# ...
# Intel Xeon E5-4620 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-1620-v4.c3172
# AMD Ryzen Threadripper 1950X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-1950x.c1904
# Intel Xeon E5-2680 v2 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2680-v2.c1666
# AMD Ryzen Threadripper 2920X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2920x.c2099
# Intel Xeon Silver 4210 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4310.c2454
# AMD EPYC 7351P -> https://www.techpowerup.com/cpu-specs/epyc-7351p.c1931
# Intel Xeon E5-2643 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2643-v3.c2862
# AMD Ryzen 7 PRO 4750G -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-4750g.c2324
# AMD Ryzen 7 5700G -> https://www.techpowerup.com/cpu-specs/ryzen-7-5700g.c2472
# Intel Xeon Silver 4214R -> https://www.techpowerup.com/cpu-specs/xeon-silver-4314.c2451
# AMD Ryzen 7 3800X -> https://www.techpowerup.com/cpu-specs/ryzen-7-3800x.c2129
# AMD Ryzen 7 5700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-5700x.c2755
# AMD EPYC 7262 -> https://www.techpowerup.com/cpu-specs/epyc-7262.c2257
# AMD Ryzen 7 1700X Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-1700x.c1892
# Intel Xeon X5675 -> https://www.techpowerup.com/cpu-specs/xeon-x5675.c949
# AMD EPYC 7252 -> https://www.techpowerup.com/cpu-specs/epyc-7252.c2258
# Intel Xeon Silver 4215R -> https://www.techpowerup.com/cpu-specs/xeon-silver-4116.c2057
# Intel Xeon Gold 5217 -> https://www.techpowerup.com/cpu-specs/xeon-gold-5317.c2446
# Intel Xeon E5-2620 v2 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2620-v2.c1656
# AMD Ryzen 5 3600 -> https://www.techpowerup.com/cpu-specs/ryzen-5-3600.c2132
# AMD Ryzen 5 2600X Six-Core -> https://www.techpowerup.com/cpu-specs/ryzen-5-7520c.c3918
# AMD Ryzen 5 5500 -> https://www.techpowerup.com/cpu-specs/ryzen-5-5500.c2756
# AMD Ryzen 5 1600X Six-Core -> https://www.techpowerup.com/cpu-specs/ryzen-5-7520c.c3918
# Intel Core i5-12400 -> https://www.techpowerup.com/cpu-specs/core-i5-12400.c2549
# AMD EPYC 7251 -> https://www.techpowerup.com/cpu-specs/epyc-7251.c1928
# AMD Ryzen 5 2600 Six-Core -> https://www.techpowerup.com/cpu-specs/ryzen-5-7520c.c3918
# AMD Ryzen 5 1600 Six-Core -> https://www.techpowerup.com/cpu-specs/ryzen-5-7520c.c3918
# Intel Xeon Gold 5215 -> https://www.techpowerup.com/cpu-specs/xeon-gold-5415.c3164
# AMD Ryzen 5 2400G with Radeon Vega -> https://www.techpowerup.com/cpu-specs/ryzen-5-7520c.c3918
# Intel Core i5-10210U -> https://www.techpowerup.com/cpu-specs/core-i5-10210u.c2235
# AMD Ryzen 5 1500X -> https://www.techpowerup.com/cpu-specs/ryzen-5-1500x.c1895
# Intel Core i7-6700K -> https://www.techpowerup.com/cpu-specs/core-i7-6700k.c1825
# Intel Core i5-8400H -> https://www.techpowerup.com/cpu-specs/core-i5-8400h.c1993
# AMD FX-8350 Eight-Core -> https://www.techpowerup.com/cpu-specs/fx-8350.c1099
# Intel Core i7-2700K -> https://www.techpowerup.com/cpu-specs/core-i7-2700k.c841
# Intel Core i5-1135G7 -> https://www.techpowerup.com/cpu-specs/core-i5-1135g7.c2346
# Intel Core i3-8100 -> https://www.techpowerup.com/cpu-specs/core-i3-8100.c1966
# Intel Core i7-3632QM -> https://www.techpowerup.com/cpu-specs/core-i7-3632qm.c1221
# Intel Core i5-4460 -> https://www.techpowerup.com/cpu-specs/core-i5-4460.c3505
# Intel Core i5-2400 -> https://www.techpowerup.com/cpu-specs/core-i5-2400.c734
# Intel Core i7-5557U -> https://www.techpowerup.com/cpu-specs/core-i7-5557u.c1806
# AMD Phenom 9650 -> https://www.techpowerup.com/cpu-specs/phenom-x4-9650.c499
# AMD Phenom II X3 720 -> https://www.techpowerup.com/cpu-specs/phenom-ii-x3-720.c756
# Intel Core i5-3320M -> https://www.techpowerup.com/cpu-specs/core-i5-3320m.c1066
# Intel Core i5-7200U -> https://www.techpowerup.com/cpu-specs/core-i5-4200u.c1602
# Intel Core i5-6300U -> https://www.techpowerup.com/cpu-specs/core-i5-5300u.c1808
# Intel Core i7-6500U -> https://www.techpowerup.com/cpu-specs/core-i7-4500u.c1592
# Intel Core i5-4210U -> https://www.techpowerup.com/cpu-specs/core-i5-4210u.c2028
# Intel Core i3-7020U -> https://www.techpowerup.com/cpu-specs/core-i3-5020u.c2691
# Intel Core 2 Duo T9500 -> https://www.techpowerup.com/cpu-specs/core-2-duo-t9500.c2737
# AMD Ryzen 7 4800U -> https://www.techpowerup.com/cpu-specs/ryzen-7-4800u.c2281
# Intel Core i7-9700TE -> https://www.techpowerup.com/cpu-specs/core-i7-9700t.c3121
# Intel Pentium Gold G6400 -> https://www.techpowerup.com/cpu-specs/pentium-gold-g6400.c2305
# Intel Celeron G5900 -> https://www.techpowerup.com/cpu-specs/celeron-g5900.c2307
# AMD EPYC 4585PX -> https://www.techpowerup.com/cpu-specs/epyc-4585px.c4172
# AMD EPYC 4565P -> https://www.techpowerup.com/cpu-specs/epyc-4565p.c4173
# AMD EPYC 4345P -> https://www.techpowerup.com/cpu-specs/epyc-4345p.c4176
# AMD EPYC 4465P -> https://www.techpowerup.com/cpu-specs/epyc-4465p.c4175
# AMD EPYC 4545P -> https://www.techpowerup.com/cpu-specs/epyc-4545p.c4174
# AMD EPYC 4245P -> https://www.techpowerup.com/cpu-specs/epyc-4245p.c4177
# AMD EPYC 4344P -> https://www.techpowerup.com/cpu-specs/epyc-4344p.c3608
# AMD EPYC 4244P -> https://www.techpowerup.com/cpu-specs/epyc-4244p.c3609
# Intel Xeon 6369P -> https://www.techpowerup.com/cpu-specs/xeon-6369p.c4094
# AMD Ryzen 7 8700G -> https://www.techpowerup.com/cpu-specs/ryzen-7-8700g.c3434
# Intel Xeon E E-2488 -> https://www.techpowerup.com/cpu-specs/xeon-e-2488.c3483
# AMD Ryzen 5 8400F -> https://www.techpowerup.com/cpu-specs/ryzen-5-8400f.c3568
# Intel Core Ultra 7 155H -> https://www.techpowerup.com/cpu-specs/core-ultra-7-155h.c3307
# Intel Core i5-14400F -> https://www.techpowerup.com/cpu-specs/core-i5-14400f.c3454
# Intel Xeon W-1370P -> https://www.techpowerup.com/cpu-specs/xeon-w-1370p.c3553
# Intel Core i9-10900KF -> https://www.techpowerup.com/cpu-specs/core-i9-10900kf.c2218
# AMD Ryzen AI 9 HX 370 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-9-hx-370.c3655
# Intel Xeon Gold 5412U -> https://www.techpowerup.com/cpu-specs/xeon-gold-5412u.c3153
# AMD EPYC 7313P -> https://www.techpowerup.com/cpu-specs/epyc-7313p.c2390
# AMD EPYC 7K83 -> https://www.techpowerup.com/cpu-specs/epyc-7301.c1926
# Intel Core i9-9900 -> https://www.techpowerup.com/cpu-specs/core-i9-9900.c2182
# Intel Core i7-8700B -> https://www.techpowerup.com/cpu-specs/core-i7-8700b.c2895
# Intel Xeon W-2295 -> https://www.techpowerup.com/cpu-specs/xeon-w-2195.c2059
# AMD Ryzen 3 3100 -> https://www.techpowerup.com/cpu-specs/ryzen-3-3100.c2298
# Intel Xeon Platinum 8272CL -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8481c.c3992
# Intel Xeon Platinum 8259L -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8481c.c3992
# Intel Xeon Gold 6254 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6154.c2056
# Intel Xeon Platinum 8253 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8253.c2181
# Intel Core i7-6700HQ -> https://www.techpowerup.com/cpu-specs/core-i7-4700hq.c1593
# AMD Athlon 3000G -> https://www.techpowerup.com/cpu-specs/athlon-3000g-fb.c4195
# AMD Ryzen 3 3200G -> https://www.techpowerup.com/cpu-specs/ryzen-3-3200g.c2205
# Intel Xeon E5-2678 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2678-v3.c2886
# Intel Core i5-5300U -> https://www.techpowerup.com/cpu-specs/core-i5-5300u.c1808
# Intel Core i7-5500U -> https://www.techpowerup.com/cpu-specs/core-i7-5500u.c1809
# Intel Core i7-3517U -> https://www.techpowerup.com/cpu-specs/core-i7-3517u.c1087
# Intel Core i3-4130 -> https://www.techpowerup.com/cpu-specs/core-i3-4130.c1632
# Intel Xeon E5-2650 0 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2650.c974
# AMD A10-7870K Radeon R7 12 Compute Cores 4C+8G -> https://www.techpowerup.com/cpu-specs/a10-7870k.c1833
# AMD FX-8150 Eight-Core -> https://www.techpowerup.com/cpu-specs/fx-8150.c825
# AMD A10-7850K APU -> https://www.techpowerup.com/cpu-specs/a10-7850k.c1744
# AMD EPYC 7713P -> https://www.techpowerup.com/cpu-specs/epyc-7713p.c2375
# Intel Xeon Gold 6338 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6338n.c2437
# AMD EPYC 7413 -> https://www.techpowerup.com/cpu-specs/epyc-7413.c2386
# Intel Xeon 6728P -> https://www.techpowerup.com/cpu-specs/xeon-6728p.c4054
# Intel Xeon Platinum -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8481c.c3992
# AMD EPYC 7K62 -> https://www.techpowerup.com/cpu-specs/epyc-7262.c2257
# AMD EPYC 7473X -> https://www.techpowerup.com/cpu-specs/epyc-7473x.c2761
# AMD EPYC 7663P -> https://www.techpowerup.com/cpu-specs/epyc-7663p.c3368
# Intel Xeon E5-2690 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2650-v4.c3791
# Intel Xeon E5-2670 0 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2670.c978
# AMD RYZEN AI MAX+ PRO 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998
# AMD Ryzen AI MAX+ PRO 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998
# AMD Ryzen AI 9 365 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-9-365.c3656
# Intel Core Ultra 7 256V -> https://www.techpowerup.com/cpu-specs/core-ultra-7-256v.c3796
# Intel Core Ultra 7 258V -> https://www.techpowerup.com/cpu-specs/core-ultra-7-258v.c3795
# AMD Ryzen AI 5 340 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-5-340.c4005
# AMD Ryzen AI 7 PRO 360 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-7-pro-360.c4006
# Intel Core i5-1334U -> https://www.techpowerup.com/cpu-specs/core-i5-1334u.c3064
# Intel Core i5-12600 -> https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556
# AMD Ryzen 7 8845HS -> https://www.techpowerup.com/cpu-specs/ryzen-7-8845hs.c3400
# Intel Xeon Platinum 8480+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8480.c2958
# Intel Core Ultra 7 165U -> https://www.techpowerup.com/cpu-specs/core-ultra-7-165u.c3523
# AMD Ryzen 7 5800U -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800u.c2746
# Intel Core i9-10850K -> https://www.techpowerup.com/cpu-specs/core-i9-10850k.c2336
# AMD Ryzen 5 PRO 4650G -> https://www.techpowerup.com/cpu-specs/ryzen-5-pro-4650g.c2325
# Intel N150 -> https://www.techpowerup.com/cpu-specs/processor-n150.c4109
# AMD Ryzen 5 3500X -> https://www.techpowerup.com/cpu-specs/ryzen-5-3500x.c2264
# AMD Ryzen Threadripper 1900X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-1900x.c1912
# AMD Ryzen 7 PRO 3700U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700u.c2173
# Intel Core i7-8700 -> https://www.techpowerup.com/cpu-specs/core-i7-8700.c1949
# Intel Core i5-1035G1 -> https://www.techpowerup.com/cpu-specs/core-i5-1035g1.c2225
# Intel Core i5-8300H -> https://www.techpowerup.com/cpu-specs/core-i5-8300h.c1994
# Intel Core i5-8600K -> https://www.techpowerup.com/cpu-specs/core-i5-8600k.c1948
# AMD EPYC 7402 -> https://www.techpowerup.com/cpu-specs/epyc-7402.c2252
# AMD EPYC 7302 -> https://www.techpowerup.com/cpu-specs/epyc-7302.c2254
# Intel Pentium G4400 -> https://www.techpowerup.com/cpu-specs/pentium-g4400.c1839
# Intel Core i7-8559U -> https://www.techpowerup.com/cpu-specs/core-i7-8559u.c2026
# Intel Core i7-9850H -> https://www.techpowerup.com/cpu-specs/core-i7-9850h.c2292
# AMD Ryzen 5 3500U -> https://www.techpowerup.com/cpu-specs/ryzen-5-3500u.c2138
# Intel Core i5-3550 -> https://www.techpowerup.com/cpu-specs/core-i5-3550.c1006
# Intel Core i5-3570K -> https://www.techpowerup.com/cpu-specs/core-i5-3570k.c1005
# Intel Core i5-6500T -> https://www.techpowerup.com/cpu-specs/core-i5-6500t.c3515
# Intel Core i7-5820K -> https://www.techpowerup.com/cpu-specs/core-i7-5820k.c1763
# Intel Core i5-4300M -> https://www.techpowerup.com/cpu-specs/core-i5-4300m.c1721
# Intel Core i5-4430 -> https://www.techpowerup.com/cpu-specs/core-i5-4430.c1470
# Intel Xeon Gold 6130 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6330.c2434
# Intel Xeon Gold 6142 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440
# Intel Xeon W-2123 -> https://www.techpowerup.com/cpu-specs/xeon-w-2123.c2950
# Intel Core i5-2500S -> https://www.techpowerup.com/cpu-specs/core-i5-2500s.c727
# Intel Core i5-6200U -> https://www.techpowerup.com/cpu-specs/core-i5-4200u.c1602
# Intel Core i3-8100T -> https://www.techpowerup.com/cpu-specs/core-i3-8100t.c2016
# Intel Core i7-4558U -> https://www.techpowerup.com/cpu-specs/core-i7-4558u.c1600
# Intel Core m3-7Y30 -> https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586
# Intel Core i3-2120 -> https://www.techpowerup.com/cpu-specs/core-i3-2120.c739
# Intel Core i7-3770 -> https://www.techpowerup.com/cpu-specs/core-i7-3770.c1002
# Intel Core i7-2600 -> https://www.techpowerup.com/cpu-specs/core-i7-2600.c724
# Intel Core i5-3427U -> https://www.techpowerup.com/cpu-specs/core-i5-3427u.c1075
# AMD FX-6300 Six-Core -> https://www.techpowerup.com/cpu-specs/fx-6300.c1210
# Intel Core i5-4278U -> https://www.techpowerup.com/cpu-specs/core-i5-4258u.c1604
# Intel Core i5 -> https://www.techpowerup.com/cpu-specs/core-i5-10200h.c2354
# Intel Xeon Silver 4214 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4314.c2451
# Intel Core i5-2410M -> https://www.techpowerup.com/cpu-specs/core-i5-2410m.c1372
# Intel Core 2 Duo E8500 -> https://www.techpowerup.com/cpu-specs/core-2-duo-e8500.c469
# Intel Core i5-2520M -> https://www.techpowerup.com/cpu-specs/core-i5-2520m.c1307
# Intel Core i7-3630QM -> https://www.techpowerup.com/cpu-specs/core-i7-3630qm.c1218
# Intel Core i7 920 -> https://www.techpowerup.com/cpu-specs/core-i7-920.c646
# Intel Core m3-6Y30 -> https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586
# Intel Core 2 Duo T7700 -> https://www.techpowerup.com/cpu-specs/core-2-duo-t7700.c1535
# Intel Xeon E3-12xx v2 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1105c.c1702
# Intel Core i3-3110M -> https://www.techpowerup.com/cpu-specs/core-i3-3110m.c1059
# Intel Celeron N3350 -> https://www.techpowerup.com/cpu-specs/celeron-725c.c1582
# Intel Core 2 Duo T7100 -> https://www.techpowerup.com/cpu-specs/core-2-duo-t7100.c1537
# Intel Celeron J3455 -> https://www.techpowerup.com/cpu-specs/celeron-725c.c1582
# Intel Core 2 Duo P7350 -> https://www.techpowerup.com/cpu-specs/core-2-duo-e7300.c518
# Intel Celeron N2830 -> https://www.techpowerup.com/cpu-specs/celeron-n2830.c1880
# AMD A6-3410MX APU -> https://www.techpowerup.com/cpu-specs/a6-3410mx.c891
# Intel Core i5 460M -> https://www.techpowerup.com/cpu-specs/core-i5-460m.c1872
# AMD EPYC 7303 -> https://www.techpowerup.com/cpu-specs/epyc-7303.c3371
# Intel Xeon Gold 6414U -> https://www.techpowerup.com/cpu-specs/xeon-gold-6414u.c3140
# Intel Xeon Gold 5416S -> https://www.techpowerup.com/cpu-specs/xeon-gold-5416s.c3161
# Intel Xeon E5-2687W 0 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2687w.c981
# Intel Core i7-12700KF -> https://www.techpowerup.com/cpu-specs/core-i7-12700kf.c2508
# Intel Xeon Gold 6144 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6154.c2056
# Intel Core i7-1185G7E -> https://www.techpowerup.com/cpu-specs/core-i7-1185g7e.c4213
# Intel Core i3-1005G1 -> https://www.techpowerup.com/cpu-specs/core-i3-1005g1.c2224
#
# Unresolved examples:
#  - AMD Custom APU 0405 simple_query= amd custom apu 0405 candidates= [('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('EPYC 7D12', 'https://www.techpowerup.com/cpu-specs/epyc-7d12.c2300')]
#  - AMD A12-9720P RADEON R7 12 COMPUTE CORES 4C+8G simple_query= amd a12 9720p radeon r7 12 compute cores 4c 8g candidates= [('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('EPYC 7D12', 'https://www.techpowerup.com/cpu-specs/epyc-7d12.c2300')]
#  - Intel Pentium N4200 simple_query= intel pentium n4200 candidates= [('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('EPYC 7D12', 'https://www.techpowerup.com/cpu-specs/epyc-7d12.c2300')]
#  - Intel Atom x5-Z8350 simple_query= intel atom x5 z8350 candidates= [('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('Core Ultra 9 285H', 'https://www.techpowerup.com/cpu-specs/core-ultra-9-285h.c4264'), ('EPYC 7D12', 'https://www.techpowerup.com/cpu-specs/epyc-7d12.c2300')]

# %%
model_to_url

with open("model_url_association.pkl", "wb") as f:
    pickle.dump(model_to_url, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open("model_url_association.pkl", "rb") as f:
    model_url_association = pickle.load(f)
    print(model_url_association)
# Out:
# {'AMD Ryzen 9 9950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-9950x.c3649', 'AMD RYZEN AI MAX+ 395': 'https://www.techpowerup.com/cpu-specs/ryzen-ai-max-395.c3994', 'Intel Core i9-13900K': 'https://www.techpowerup.com/cpu-specs/core-i9-13900k.c2817', 'AMD Ryzen 7 7700X': 'https://www.techpowerup.com/cpu-specs/ryzen-7-7700x.c2848', 'AMD Ryzen 9 7950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-7950x.c2846', 'Intel Core i9-14900K': 'https://www.techpowerup.com/cpu-specs/core-i9-14900k.c3269', 'AMD EPYC 4364P': 'https://www.techpowerup.com/cpu-specs/epyc-4364p.c3611', 'AMD Ryzen 9 7900X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-7900x.c2847', 'Intel Core i9-12900K': 'https://www.techpowerup.com/cpu-specs/core-i9-12900k.c2505', 'AMD EPYC 4564P': 'https://www.techpowerup.com/cpu-specs/epyc-4564p.c3613', 'AMD EPYC 4464P': 'https://www.techpowerup.com/cpu-specs/epyc-4464p.c3612', 'AMD EPYC 4584PX': 'https://www.techpowerup.com/cpu-specs/epyc-4584px.c3607', 'AMD EPYC 4484PX': 'https://www.techpowerup.com/cpu-specs/epyc-4484px.c3606', 'AMD Ryzen 9 5900X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-5900x.c2363', 'AMD Ryzen 5 7600X': 'https://www.techpowerup.com/cpu-specs/ryzen-5-7600x.c2849', 'Intel Core i9-11900K': 'https://www.techpowerup.com/cpu-specs/core-i9-11900k.c2366', 'AMD Ryzen 9 5950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-5950x.c2364', 'AMD Ryzen 7 5800X': 'https://www.techpowerup.com/cpu-specs/ryzen-7-5800x.c2362', 'AMD Ryzen 7 5800X3D': 'https://www.techpowerup.com/cpu-specs/ryzen-7-5800x3d.c2532', 'Intel Core i9-10900K': 'https://www.techpowerup.com/cpu-specs/core-i9-10900k.c2266', 'Intel Core i5-13600K': 'https://www.techpowerup.com/cpu-specs/core-i5-13600k.c2829', 'AMD EPYC 4124P': 'https://www.techpowerup.com/cpu-specs/epyc-4124p.c3610', 'AMD Ryzen Threadripper 3970X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3970x.c2269', 'AMD Ryzen Threadripper 3990X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3990x.c2271', 'AMD Ryzen 9 3900XT': 'https://www.techpowerup.com/cpu-specs/ryzen-9-3900xt.c2308', 'Intel Core i5-12600K': 'https://www.techpowerup.com/cpu-specs/core-i5-12600k.c2509', 'Intel Core i7-7900X': 'https://www.techpowerup.com/cpu-specs/core-i7-7800x.c1905', 'Intel Core i5-11600K': 'https://www.techpowerup.com/cpu-specs/core-i5-11600k.c2400', 'Intel Core i9-7980XE': 'https://www.techpowerup.com/cpu-specs/core-i9-7980xe.c1952', 'Intel Core i5-13400': 'https://www.techpowerup.com/cpu-specs/core-i5-13400.c2994', 'AMD Ryzen 7 PRO 5850U': 'https://www.techpowerup.com/cpu-specs/ryzen-7-pro-5850u.c2774', 'AMD Ryzen Threadripper 2990WX': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2990wx.c2069', 'AMD Ryzen 7 PRO 6850U': 'https://www.techpowerup.com/cpu-specs/ryzen-7-pro-6850u.c2768', 'AMD Ryzen 5 3600XT': 'https://www.techpowerup.com/cpu-specs/ryzen-5-3600xt.c2313', 'AMD EPYC 73F3': 'https://www.techpowerup.com/cpu-specs/epyc-73f3.c2387', 'AMD EPYC 75F3': 'https://www.techpowerup.com/cpu-specs/epyc-75f3.c2378', 'AMD Ryzen Threadripper 3960X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3960x.c2268', 'AMD EPYC 74F3': 'https://www.techpowerup.com/cpu-specs/epyc-74f3.c2383', 'Intel Xeon E-2278GEL': 'https://www.techpowerup.com/cpu-specs/xeon-e-2278gel.c3487', 'AMD Ryzen 7 1700 Eight-Core': 'https://www.techpowerup.com/cpu-specs/ryzen-7-1700.c1893', 'AMD EPYC 7713': 'https://www.techpowerup.com/cpu-specs/epyc-7713.c2374', 'Intel Core i9-9900KS': 'https://www.techpowerup.com/cpu-specs/core-i9-9900ks.c2242', 'AMD EPYC 7F52': 'https://www.techpowerup.com/cpu-specs/epyc-7f52.c2301', 'Intel Core i9-9900K': 'https://www.techpowerup.com/cpu-specs/core-i9-9900k.c2098', 'AMD EPYC 7513': 'https://www.techpowerup.com/cpu-specs/epyc-7513.c2381', 'AMD EPYC 7763': 'https://www.techpowerup.com/cpu-specs/epyc-7763.c2373', 'AMD Ryzen 5 4500U': 'https://www.techpowerup.com/cpu-specs/ryzen-5-4500u.c2285', 'Intel Xeon Gold 6248R': 'https://www.techpowerup.com ...

# %%
# Build {model: list_of_DataFrames} by parsing the resolved URLs
model_to_tables = {}
errors = {}

for model, url in model_url_association.items():
    start = time.time()
    try:
        html = fetch_html(url)
        print(f"Fetched {url}")
        # read all tables so you can decide later; keep as list[DataFrame]
        tables = pd.read_html(StringIO(html), flavor="lxml")
        model_to_tables[model] = tables
        print(f"OK: {model} -> {url} (tables: {len(tables)})")
        # extra politeness between detail pages
        time.sleep(random.uniform(30, 120))
    except Exception as e:
        errors[model] = {"url": url, "error": repr(e)}
        print(f"ERR: {model} -> {url} :: {e}")
        time.sleep(random.uniform(30, 120))

    end = time.time()
    print(f"Iteration time: {end-start}")

# Package payload and serialize using dill via pickle API
payload = {
    "tables": model_to_tables,   # {model: list[pd.DataFrame]}
    "errors": errors,            # {model: {url, error}}
    "resolved": model_to_url,    # {model: url}
    "unresolved": unresolved,    # {model: {best_guess, score}}
}

out_path = "cpu_specs_raw_tables.pkl"
with open(out_path, "wb") as f:
    pickle.dump(payload, f, protocol=pickle.HIGHEST_PROTOCOL)

print(f"\nSaved {len(model_to_tables)} models to {out_path}. Errors: {len(errors)}")
# Out:
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-9950x.c3649
# OK: AMD Ryzen 9 9950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-9950x.c3649 (tables: 8)
# Iteration time: 169.2925090789795
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-max-395.c3994
# OK: AMD RYZEN AI MAX+ 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-395.c3994 (tables: 8)
# Iteration time: 128.40356612205505
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-13900k.c2817
# OK: Intel Core i9-13900K -> https://www.techpowerup.com/cpu-specs/core-i9-13900k.c2817 (tables: 8)
# Iteration time: 78.40647411346436
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7700x.c2848
# OK: AMD Ryzen 7 7700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-7700x.c2848 (tables: 7)
# Iteration time: 130.9573380947113
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-7950x.c2846
# OK: AMD Ryzen 9 7950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-7950x.c2846 (tables: 8)
# Iteration time: 122.90166401863098
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-14900k.c3269
# OK: Intel Core i9-14900K -> https://www.techpowerup.com/cpu-specs/core-i9-14900k.c3269 (tables: 8)
# Iteration time: 204.01311683654785
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4364p.c3611
# OK: AMD EPYC 4364P -> https://www.techpowerup.com/cpu-specs/epyc-4364p.c3611 (tables: 8)
# Iteration time: 114.65000486373901
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-7900x.c2847
# OK: AMD Ryzen 9 7900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900x.c2847 (tables: 8)
# Iteration time: 162.6740550994873
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-12900k.c2505
# OK: Intel Core i9-12900K -> https://www.techpowerup.com/cpu-specs/core-i9-12900k.c2505 (tables: 8)
# Iteration time: 182.06332683563232
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4564p.c3613
# OK: AMD EPYC 4564P -> https://www.techpowerup.com/cpu-specs/epyc-4564p.c3613 (tables: 8)
# Iteration time: 133.10626697540283
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4464p.c3612
# OK: AMD EPYC 4464P -> https://www.techpowerup.com/cpu-specs/epyc-4464p.c3612 (tables: 8)
# Iteration time: 223.0839512348175
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4584px.c3607
# OK: AMD EPYC 4584PX -> https://www.techpowerup.com/cpu-specs/epyc-4584px.c3607 (tables: 8)
# Iteration time: 146.7495768070221
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4484px.c3606
# OK: AMD EPYC 4484PX -> https://www.techpowerup.com/cpu-specs/epyc-4484px.c3606 (tables: 8)
# Iteration time: 116.53568696975708
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-5900x.c2363
# OK: AMD Ryzen 9 5900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-5900x.c2363 (tables: 8)
# Iteration time: 122.75740694999695
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-7600x.c2849
# OK: AMD Ryzen 5 7600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-7600x.c2849 (tables: 8)
# Iteration time: 153.9913740158081
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-11900k.c2366
# OK: Intel Core i9-11900K -> https://www.techpowerup.com/cpu-specs/core-i9-11900k.c2366 (tables: 8)
# Iteration time: 191.6989312171936
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-5950x.c2364
# OK: AMD Ryzen 9 5950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-5950x.c2364 (tables: 8)
# Iteration time: 120.96532106399536
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-5800x.c2362
# OK: AMD Ryzen 7 5800X -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800x.c2362 (tables: 8)
# Iteration time: 213.57088899612427
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-5800x3d.c2532
# OK: AMD Ryzen 7 5800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800x3d.c2532 (tables: 8)
# Iteration time: 89.50755596160889
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-10900k.c2266
# OK: Intel Core i9-10900K -> https://www.techpowerup.com/cpu-specs/core-i9-10900k.c2266 (tables: 7)
# Iteration time: 156.94362092018127
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-13600k.c2829
# OK: Intel Core i5-13600K -> https://www.techpowerup.com/cpu-specs/core-i5-13600k.c2829 (tables: 8)
# Iteration time: 136.45191597938538
# Fetched https://www.techpowerup.com/cpu-specs/epyc-4124p.c3610
# OK: AMD EPYC 4124P -> https://www.techpowerup.com/cpu-specs/epyc-4124p.c3610 (tables: 8)
# Iteration time: 214.40534496307373
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3970x.c2269
# OK: AMD Ryzen Threadripper 3970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3970x.c2269 (tables: 7)
# Iteration time: 93.26633620262146
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3990x.c2271
# OK: AMD Ryzen Threadripper 3990X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3990x.c2271 (tables: 7)
# Iteration time: 179.48252391815186
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-3900xt.c2308
# OK: AMD Ryzen 9 3900XT -> https://www.techpowerup.com/cpu-specs/ryzen-9-3900xt.c2308 (tables: 7)
# Iteration time: 131.4355731010437
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-12600k.c2509
# OK: Intel Core i5-12600K -> https://www.techpowerup.com/cpu-specs/core-i5-12600k.c2509 (tables: 8)
# Iteration time: 178.84939575195312
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-7800x.c1905
# OK: Intel Core i7-7900X -> https://www.techpowerup.com/cpu-specs/core-i7-7800x.c1905 (tables: 8)
# Iteration time: 157.76650285720825
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-11600k.c2400
# OK: Intel Core i5-11600K -> https://www.techpowerup.com/cpu-specs/core-i5-11600k.c2400 (tables: 8)
# Iteration time: 174.1858468055725
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-7980xe.c1952
# OK: Intel Core i9-7980XE -> https://www.techpowerup.com/cpu-specs/core-i9-7980xe.c1952 (tables: 8)
# Iteration time: 196.1919801235199
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-13400.c2994
# OK: Intel Core i5-13400 -> https://www.techpowerup.com/cpu-specs/core-i5-13400.c2994 (tables: 8)
# Iteration time: 156.2683539390564
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-pro-5850u.c2774
# OK: AMD Ryzen 7 PRO 5850U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-5850u.c2774 (tables: 8)
# Iteration time: 76.55075311660767
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2990wx.c2069
# OK: AMD Ryzen Threadripper 2990WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2990wx.c2069 (tables: 7)
# Iteration time: 203.3640649318695
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-pro-6850u.c2768
# OK: AMD Ryzen 7 PRO 6850U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-6850u.c2768 (tables: 8)
# Iteration time: 158.06916403770447
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-3600xt.c2313
# OK: AMD Ryzen 5 3600XT -> https://www.techpowerup.com/cpu-specs/ryzen-5-3600xt.c2313 (tables: 7)
# Iteration time: 97.22820997238159
# Fetched https://www.techpowerup.com/cpu-specs/epyc-73f3.c2387
# OK: AMD EPYC 73F3 -> https://www.techpowerup.com/cpu-specs/epyc-73f3.c2387 (tables: 7)
# Iteration time: 178.1172399520874
# Fetched https://www.techpowerup.com/cpu-specs/epyc-75f3.c2378
# OK: AMD EPYC 75F3 -> https://www.techpowerup.com/cpu-specs/epyc-75f3.c2378 (tables: 7)
# Iteration time: 214.09838795661926
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3960x.c2268
# OK: AMD Ryzen Threadripper 3960X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3960x.c2268 (tables: 7)
# Iteration time: 160.6640248298645
# Fetched https://www.techpowerup.com/cpu-specs/epyc-74f3.c2383
# OK: AMD EPYC 74F3 -> https://www.techpowerup.com/cpu-specs/epyc-74f3.c2383 (tables: 7)
# Iteration time: 153.87064814567566
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e-2278gel.c3487
# OK: Intel Xeon E-2278GEL -> https://www.techpowerup.com/cpu-specs/xeon-e-2278gel.c3487 (tables: 8)
# Iteration time: 153.2862057685852
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-1700.c1893
# OK: AMD Ryzen 7 1700 Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-1700.c1893 (tables: 7)
# Iteration time: 134.00463581085205
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7713.c2374
# OK: AMD EPYC 7713 -> https://www.techpowerup.com/cpu-specs/epyc-7713.c2374 (tables: 7)
# Iteration time: 180.23422288894653
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-9900ks.c2242
# OK: Intel Core i9-9900KS -> https://www.techpowerup.com/cpu-specs/core-i9-9900ks.c2242 (tables: 8)
# Iteration time: 149.84055876731873
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7f52.c2301
# OK: AMD EPYC 7F52 -> https://www.techpowerup.com/cpu-specs/epyc-7f52.c2301 (tables: 7)
# Iteration time: 215.23152995109558
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-9900k.c2098
# OK: Intel Core i9-9900K -> https://www.techpowerup.com/cpu-specs/core-i9-9900k.c2098 (tables: 8)
# Iteration time: 137.9598388671875
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7513.c2381
# OK: AMD EPYC 7513 -> https://www.techpowerup.com/cpu-specs/epyc-7513.c2381 (tables: 7)
# Iteration time: 152.6492190361023
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7763.c2373
# OK: AMD EPYC 7763 -> https://www.techpowerup.com/cpu-specs/epyc-7763.c2373 (tables: 7)
# Iteration time: 141.36976385116577
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-4500u.c2285
# OK: AMD Ryzen 5 4500U -> https://www.techpowerup.com/cpu-specs/ryzen-5-4500u.c2285 (tables: 8)
# Iteration time: 190.19920182228088
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6348.c2432
# OK: Intel Xeon Gold 6248R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6348.c2432 (tables: 7)
# Iteration time: 148.62396597862244
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-1280p.c2579
# OK: Intel Core i7-1280P -> https://www.techpowerup.com/cpu-specs/core-i7-1280p.c2579 (tables: 8)
# Iteration time: 161.21765089035034
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7542.c2249
# OK: AMD EPYC 7542 -> https://www.techpowerup.com/cpu-specs/epyc-7542.c2249 (tables: 7)
# Iteration time: 158.3268539905548
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7742.c2245
# OK: AMD EPYC 7742 -> https://www.techpowerup.com/cpu-specs/epyc-7742.c2245 (tables: 7)
# Iteration time: 104.1888632774353
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-6700.c1827
# OK: Intel Core i7-6700 -> https://www.techpowerup.com/cpu-specs/core-i7-6700.c1827 (tables: 8)
# Iteration time: 155.391361951828
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7502p.c2260
# OK: AMD EPYC 7502P -> https://www.techpowerup.com/cpu-specs/epyc-7502p.c2260 (tables: 7)
# Iteration time: 136.7104880809784
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7402p.c2261
# OK: AMD EPYC 7402P -> https://www.techpowerup.com/cpu-specs/epyc-7402p.c2261 (tables: 7)
# Iteration time: 124.88093733787537
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439
# OK: Intel Xeon Gold 6258R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439 (tables: 7)
# Iteration time: 160.32640504837036
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-6800k.c1844
# OK: Intel Core i7-6800K -> https://www.techpowerup.com/cpu-specs/core-i7-6800k.c1844 (tables: 7)
# Iteration time: 204.66990995407104
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7302p.c2262
# OK: AMD EPYC 7302P -> https://www.techpowerup.com/cpu-specs/epyc-7302p.c2262 (tables: 8)
# Iteration time: 195.19284105300903
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7352.c2253
# OK: AMD EPYC 7532 -> https://www.techpowerup.com/cpu-specs/epyc-7352.c2253 (tables: 8)
# Iteration time: 214.88593292236328
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8280.c2170
# OK: Intel Xeon Platinum 8280 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8280.c2170 (tables: 7)
# Iteration time: 157.8286259174347
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7552.c2248
# OK: AMD EPYC 7552 -> https://www.techpowerup.com/cpu-specs/epyc-7552.c2248 (tables: 7)
# Iteration time: 202.46819615364075
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7642.c2247
# OK: AMD EPYC 7642 -> https://www.techpowerup.com/cpu-specs/epyc-7642.c2247 (tables: 7)
# Iteration time: 227.81304621696472
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7663.c2376
# OK: AMD EPYC 7662 -> https://www.techpowerup.com/cpu-specs/epyc-7663.c2376 (tables: 7)
# Iteration time: 110.39602494239807
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e-2388g.c2492
# OK: Intel Xeon E-2388G -> https://www.techpowerup.com/cpu-specs/xeon-e-2388g.c2492 (tables: 8)
# Iteration time: 66.03311896324158
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7272.c2256
# OK: AMD EPYC 7272 -> https://www.techpowerup.com/cpu-specs/epyc-7272.c2256 (tables: 8)
# Iteration time: 212.71359634399414
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7232p.c2263
# OK: AMD EPYC 7232P -> https://www.techpowerup.com/cpu-specs/epyc-7232p.c2263 (tables: 8)
# Iteration time: 145.8772919178009
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-5320.c2449
# OK: Intel Xeon Gold 5220R -> https://www.techpowerup.com/cpu-specs/xeon-gold-5320.c2449 (tables: 7)
# Iteration time: 167.2466368675232
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7282.c2255
# OK: AMD EPYC 7282 -> https://www.techpowerup.com/cpu-specs/epyc-7282.c2255 (tables: 8)
# Iteration time: 87.31518507003784
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439
# OK: Intel Xeon Gold 6226R -> https://www.techpowerup.com/cpu-specs/xeon-gold-6326.c2439 (tables: 7)
# Iteration time: 125.14071893692017
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-3800xt.c2309
# OK: AMD Ryzen 7 3800XT -> https://www.techpowerup.com/cpu-specs/ryzen-7-3800xt.c2309 (tables: 7)
# Iteration time: 124.63961911201477
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8700k.c1947
# OK: Intel Core i7-8700K -> https://www.techpowerup.com/cpu-specs/core-i7-8700k.c1947 (tables: 7)
# Iteration time: 208.69862294197083
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700.c3703
# OK: AMD Ryzen 7 PRO 3700 -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700.c3703 (tables: 8)
# Iteration time: 174.0792579650879
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-pro-6950h.c2765
# OK: AMD Ryzen 9 PRO 3900 -> https://www.techpowerup.com/cpu-specs/ryzen-9-pro-6950h.c2765 (tables: 8)
# Iteration time: 128.6066188812256
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-1680-v3.c2664
# OK: Intel Xeon E5-1680 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-1680-v3.c2664 (tables: 8)
# Iteration time: 89.22787094116211
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-7700k.c1842
# OK: Intel Core i7-7700K -> https://www.techpowerup.com/cpu-specs/core-i7-7700k.c1842 (tables: 8)
# Iteration time: 206.07537293434143
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e-2278g.c3537
# OK: Intel Xeon E-2278G -> https://www.techpowerup.com/cpu-specs/xeon-e-2278g.c3537 (tables: 8)
# Iteration time: 125.28514194488525
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-1165g7.c2343
# OK: Intel Core i7-1165G7 -> https://www.techpowerup.com/cpu-specs/core-i7-1165g7.c2343 (tables: 8)
# Iteration time: 145.07371997833252
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-2700.c2013
# OK: AMD Ryzen 7 2700 Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-2700.c2013 (tables: 7)
# Iteration time: 132.17385721206665
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2970wx.c2068
# OK: AMD Ryzen Threadripper 2970WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2970wx.c2068 (tables: 7)
# Iteration time: 144.65373587608337
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2687w-v3.c2877
# OK: Intel Xeon E5-2687W v3 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2687w-v3.c2877 (tables: 7)
# Iteration time: 139.89129972457886
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-9400f.c2145
# OK: Intel Core i5-9400F -> https://www.techpowerup.com/cpu-specs/core-i5-9400f.c2145 (tables: 7)
# Iteration time: 193.8838620185852
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2950x.c2067
# OK: AMD Ryzen Threadripper 2950X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2950x.c2067 (tables: 7)
# Iteration time: 149.41761994361877
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1285-v6.c1999
# OK: Intel Xeon E3-1275 v6 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1285-v6.c1999 (tables: 7)
# Iteration time: 192.59542202949524
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7601.c1920
# OK: AMD EPYC 7601 -> https://www.techpowerup.com/cpu-specs/epyc-7601.c1920 (tables: 7)
# Iteration time: 206.71557092666626
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-9750h.c2290
# OK: Intel Core i7-9750H -> https://www.techpowerup.com/cpu-specs/core-i7-9750h.c2290 (tables: 7)
# Iteration time: 113.55630278587341
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8565u.c2103
# OK: Intel Core i7-8565U -> https://www.techpowerup.com/cpu-specs/core-i7-8565u.c2103 (tables: 8)
# Iteration time: 159.99423599243164
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1245-v5.c3232
# OK: Intel Xeon E3-1245 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1245-v5.c3232 (tables: 8)
# Iteration time: 201.94237995147705
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1280-v5.c1841
# OK: Intel Xeon E3-1280 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1280-v5.c1841 (tables: 7)
# Iteration time: 197.1622519493103
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-1065g7.c2228
# OK: Intel Core i7-1065G7 -> https://www.techpowerup.com/cpu-specs/core-i7-1065g7.c2228 (tables: 8)
# Iteration time: 151.63883590698242
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4790k.c1761
# OK: Intel Core i7-4790K -> https://www.techpowerup.com/cpu-specs/core-i7-4790k.c1761 (tables: 8)
# Iteration time: 158.02393293380737
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-3400g.c2204
# OK: AMD Ryzen 5 3400G -> https://www.techpowerup.com/cpu-specs/ryzen-5-3400g.c2204 (tables: 8)
# Iteration time: 157.66990399360657
# Fetched https://www.techpowerup.com/cpu-specs/xeon-silver-4116.c2057
# OK: Intel Xeon Silver 4216 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4116.c2057 (tables: 7)
# Iteration time: 105.48920488357544
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7551.c1921
# OK: AMD EPYC 7551 -> https://www.techpowerup.com/cpu-specs/epyc-7551.c1921 (tables: 7)
# Iteration time: 113.53093695640564
# Fetched https://www.techpowerup.com/cpu-specs/celeron-g6900.c2570
# OK: Intel Celeron G6900 -> https://www.techpowerup.com/cpu-specs/celeron-g6900.c2570 (tables: 8)
# Iteration time: 173.15805578231812
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-10510u.c2236
# OK: Intel Core i7- -> https://www.techpowerup.com/cpu-specs/core-i7-10510u.c2236 (tables: 7)
# Iteration time: 118.06286072731018
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2609.c966
# OK: Intel Xeon E5-2609 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2609.c966 (tables: 7)
# Iteration time: 232.4022181034088
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4600u.c1717
# OK: Intel Core i7-4600U -> https://www.techpowerup.com/cpu-specs/core-i7-4600u.c1717 (tables: 7)
# Iteration time: 192.65970492362976
# Fetched https://www.techpowerup.com/cpu-specs/xeon-6980p.c3862
# OK: Intel Xeon 6980P -> https://www.techpowerup.com/cpu-specs/xeon-6980p.c3862 (tables: 8)
# Iteration time: 208.20729184150696
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9755.c3881
# OK: AMD EPYC 9755 -> https://www.techpowerup.com/cpu-specs/epyc-9755.c3881 (tables: 8)
# Iteration time: 170.0180263519287
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9575f.c3885
# OK: AMD EPYC 9575F -> https://www.techpowerup.com/cpu-specs/epyc-9575f.c3885 (tables: 8)
# Iteration time: 121.7846360206604
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9655.c3882
# OK: AMD EPYC 9655 -> https://www.techpowerup.com/cpu-specs/epyc-9655.c3882 (tables: 8)
# Iteration time: 114.78367829322815
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9965.c3904
# OK: AMD EPYC 9965 -> https://www.techpowerup.com/cpu-specs/epyc-9965.c3904 (tables: 8)
# Iteration time: 97.25208306312561
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9684x.c3253
# OK: AMD EPYC 9684X -> https://www.techpowerup.com/cpu-specs/epyc-9684x.c3253 (tables: 8)
# Iteration time: 138.35277485847473
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9374f.c2925
# OK: AMD EPYC 9374F -> https://www.techpowerup.com/cpu-specs/epyc-9374f.c2925 (tables: 7)
# Iteration time: 197.34291982650757
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9554.c2930
# OK: AMD EPYC 9554 -> https://www.techpowerup.com/cpu-specs/epyc-9554.c2930 (tables: 7)
# Iteration time: 139.521390914917
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9384x.c3254
# OK: AMD EPYC 9384X -> https://www.techpowerup.com/cpu-specs/epyc-9384x.c3254 (tables: 8)
# Iteration time: 177.5510802268982
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9184x.c3255
# OK: AMD EPYC 9184X -> https://www.techpowerup.com/cpu-specs/epyc-9184x.c3255 (tables: 8)
# Iteration time: 117.01289010047913
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8592.c3408
# OK: INTEL XEON PLATINUM 8592+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8592.c3408 (tables: 7)
# Iteration time: 145.5575611591339
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8490h.c2942
# OK: Intel Xeon Platinum 8490H -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8490h.c2942 (tables: 8)
# Iteration time: 163.6440670490265
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8468.c3094
# OK: Intel Xeon Platinum 8468 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8468.c3094 (tables: 8)
# Iteration time: 149.11185812950134
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8462y.c3137
# OK: Intel Xeon Platinum 8462Y+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8462y.c3137 (tables: 8)
# Iteration time: 80.62602758407593
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9655p.c3883
# OK: AMD EPYC 9655P -> https://www.techpowerup.com/cpu-specs/epyc-9655p.c3883 (tables: 8)
# Iteration time: 140.19522619247437
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6442y.c3157
# OK: Intel Xeon Gold 6442Y -> https://www.techpowerup.com/cpu-specs/xeon-gold-6442y.c3157 (tables: 8)
# Iteration time: 188.0819959640503
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9845.c3905
# OK: AMD EPYC 9845 -> https://www.techpowerup.com/cpu-specs/epyc-9845.c3905 (tables: 8)
# Iteration time: 122.70138788223267
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9654.c2933
# OK: AMD EPYC 9654 -> https://www.techpowerup.com/cpu-specs/epyc-9654.c2933 (tables: 7)
# Iteration time: 147.53509092330933
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9754.c3257
# OK: AMD EPYC 9754 -> https://www.techpowerup.com/cpu-specs/epyc-9754.c3257 (tables: 7)
# Iteration time: 117.84672498703003
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8380.c2421
# OK: Intel Xeon Platinum 8380 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8380.c2421 (tables: 7)
# Iteration time: 95.57551312446594
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8362.c2426
# OK: Intel Xeon Platinum 8362 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8362.c2426 (tables: 7)
# Iteration time: 192.31837797164917
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7773x.c2759
# OK: AMD EPYC 7773X -> https://www.techpowerup.com/cpu-specs/epyc-7773x.c2759 (tables: 8)
# Iteration time: 203.7439901828766
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7573x.c2760
# OK: AMD EPYC 7573X -> https://www.techpowerup.com/cpu-specs/epyc-7573x.c2760 (tables: 8)
# Iteration time: 172.91635704040527
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7663.c2376
# OK: AMD EPYC 7663 -> https://www.techpowerup.com/cpu-specs/epyc-7663.c2376 (tables: 7)
# Iteration time: 158.30837297439575
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440
# OK: Intel Xeon Gold 6342 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440 (tables: 7)
# Iteration time: 112.61842131614685
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7543.c2379
# OK: AMD EPYC 7543 -> https://www.techpowerup.com/cpu-specs/epyc-7543.c2379 (tables: 7)
# Iteration time: 93.92054224014282
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7373x.c2762
# OK: AMD EPYC 7373X -> https://www.techpowerup.com/cpu-specs/epyc-7373x.c2762 (tables: 8)
# Iteration time: 113.5913758277893
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-7995wx.c3301
# OK: AMD Ryzen Threadripper PRO 7995WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-7995wx.c3301 (tables: 8)
# Iteration time: 218.64385509490967
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7443.c2384
# OK: AMD EPYC 7443 -> https://www.techpowerup.com/cpu-specs/epyc-7443.c2384 (tables: 7)
# Iteration time: 135.35902881622314
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7343.c2388
# OK: AMD EPYC 7343 -> https://www.techpowerup.com/cpu-specs/epyc-7343.c2388 (tables: 7)
# Iteration time: 95.14328789710999
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6346.c2433
# OK: Intel Xeon Gold 6346 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6346.c2433 (tables: 7)
# Iteration time: 147.24228596687317
# Fetched https://www.techpowerup.com/cpu-specs/xeon-max-9480.c3084
# OK: Intel Xeon Max 9480 -> https://www.techpowerup.com/cpu-specs/xeon-max-9480.c3084 (tables: 8)
# Iteration time: 177.88082599639893
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9534.c2929
# OK: AMD EPYC 9534 -> https://www.techpowerup.com/cpu-specs/epyc-9534.c2929 (tables: 7)
# Iteration time: 170.04988598823547
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8471n.c3092
# OK: Intel Xeon Platinum 8471N -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8471n.c3092 (tables: 8)
# Iteration time: 126.85192489624023
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7f72.c2302
# OK: AMD EPYC 7F72 -> https://www.techpowerup.com/cpu-specs/epyc-7f72.c2302 (tables: 7)
# Iteration time: 154.86416101455688
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-9995wx.c4163
# OK: AMD Ryzen Threadripper PRO 9995WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-9995wx.c4163 (tables: 8)
# Iteration time: 152.49008989334106
# Fetched https://www.techpowerup.com/cpu-specs/epyc-8534p.c3288
# OK: AMD EPYC 8534P -> https://www.techpowerup.com/cpu-specs/epyc-8534p.c3288 (tables: 7)
# Iteration time: 151.46544528007507
# Fetched https://www.techpowerup.com/cpu-specs/epyc-8534pn.c3289
# OK: AMD EPYC 8534PN -> https://www.techpowerup.com/cpu-specs/epyc-8534pn.c3289 (tables: 7)
# Iteration time: 131.18444728851318
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-9970x.c4170
# OK: AMD Ryzen Threadripper 9970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-9970x.c4170 (tables: 7)
# Iteration time: 141.8042390346527
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7970x.c3358
# OK: AMD Ryzen Threadripper 7970X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7970x.c3358 (tables: 7)
# Iteration time: 110.34639811515808
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7980x.c3357
# OK: AMD Ryzen Threadripper 7980X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-7980x.c3357 (tables: 7)
# Iteration time: 174.18917989730835
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7702.c2246
# OK: AMD EPYC 7702 -> https://www.techpowerup.com/cpu-specs/epyc-7702.c2246 (tables: 7)
# Iteration time: 216.31311321258545
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2699a-v4.c3227
# OK: Intel Xeon E5-2699 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2699a-v4.c3227 (tables: 7)
# Iteration time: 136.56367111206055
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2696-v3.c2903
# OK: Intel Xeon E5-2696 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2696-v3.c2903 (tables: 8)
# Iteration time: 164.2903597354889
# Fetched https://www.techpowerup.com/cpu-specs/core-ultra-9-285k.c3773
# OK: Intel Core Ultra 9 285K -> https://www.techpowerup.com/cpu-specs/core-ultra-9-285k.c3773 (tables: 8)
# Iteration time: 83.46711301803589
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-5318h.c2456
# OK: Intel Xeon Gold 5218 -> https://www.techpowerup.com/cpu-specs/xeon-gold-5318h.c2456 (tables: 7)
# Iteration time: 107.50413417816162
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-9900x3d.c3997
# OK: AMD Ryzen 9 9900X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-9900x3d.c3997 (tables: 8)
# Iteration time: 86.23709535598755
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-7960x.c1950
# OK: Intel Core i9-7960X -> https://www.techpowerup.com/cpu-specs/core-i9-7960x.c1950 (tables: 8)
# Iteration time: 146.36149501800537
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-9950x3d.c3993
# OK: AMD Ryzen 9 9950X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-9950x3d.c3993 (tables: 8)
# Iteration time: 74.30996704101562
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-14100.c3450
# OK: Intel Core i3-14100 -> https://www.techpowerup.com/cpu-specs/core-i3-14100.c3450 (tables: 8)
# Iteration time: 86.31035494804382
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-9800x3d.c3891
# OK: AMD Ryzen 7 9800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-9800x3d.c3891 (tables: 8)
# Iteration time: 107.85828018188477
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-10980xe.c2238
# OK: Intel Core i9-10980XE -> https://www.techpowerup.com/cpu-specs/core-i9-10980xe.c2238 (tables: 8)
# Iteration time: 196.3370177745819
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-8600g.c3435
# OK: AMD Ryzen 5 8600G -> https://www.techpowerup.com/cpu-specs/ryzen-5-8600g.c3435 (tables: 8)
# Iteration time: 149.43159818649292
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-8500g.c3436
# OK: AMD Ryzen 5 8500G -> https://www.techpowerup.com/cpu-specs/ryzen-5-8500g.c3436 (tables: 8)
# Iteration time: 138.79117488861084
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7800x3d.c3022
# OK: AMD Ryzen 7 7800X3D -> https://www.techpowerup.com/cpu-specs/ryzen-7-7800x3d.c3022 (tables: 8)
# Iteration time: 91.68706583976746
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-7900x3d.c3023
# OK: AMD Ryzen 9 7900X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900x3d.c3023 (tables: 8)
# Iteration time: 122.31099009513855
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-7950x3d.c3024
# OK: AMD Ryzen 9 7950X3D -> https://www.techpowerup.com/cpu-specs/ryzen-9-7950x3d.c3024 (tables: 8)
# Iteration time: 155.176851272583
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-7900.c2961
# OK: AMD Ryzen 9 7900 -> https://www.techpowerup.com/cpu-specs/ryzen-9-7900.c2961 (tables: 8)
# Iteration time: 204.78490900993347
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-7600.c2959
# OK: AMD Ryzen 5 7600 -> https://www.techpowerup.com/cpu-specs/ryzen-5-7600.c2959 (tables: 8)
# Iteration time: 156.86180686950684
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7700.c2960
# OK: AMD Ryzen 7 7700 -> https://www.techpowerup.com/cpu-specs/ryzen-7-7700.c2960 (tables: 8)
# Iteration time: 108.49949908256531
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-14500.c3448
# OK: Intel Core i5-14500 -> https://www.techpowerup.com/cpu-specs/core-i5-14500.c3448 (tables: 8)
# Iteration time: 162.8089542388916
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-6900hx.c2529
# OK: AMD Ryzen 9 6900HX -> https://www.techpowerup.com/cpu-specs/ryzen-9-6900hx.c2529 (tables: 8)
# Iteration time: 228.48916292190552
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-12900h.c2539
# OK: Intel Core i9-12900H -> https://www.techpowerup.com/cpu-specs/core-i9-12900h.c2539 (tables: 8)
# Iteration time: 189.1808979511261
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-12700k.c2507
# OK: Intel Core i7-12700K -> https://www.techpowerup.com/cpu-specs/core-i7-12700k.c2507 (tables: 8)
# Iteration time: 120.63704895973206
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-11980hk.c2474
# OK: Intel Core i9-11980HK -> https://www.techpowerup.com/cpu-specs/core-i9-11980hk.c2474 (tables: 8)
# Iteration time: 139.8064980506897
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-11700k.c2367
# OK: Intel Core i7-11700K -> https://www.techpowerup.com/cpu-specs/core-i7-11700k.c2367 (tables: 8)
# Iteration time: 148.97769498825073
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-11700b.c4246
# OK: Intel Core i7-11700B -> https://www.techpowerup.com/cpu-specs/core-i7-11700b.c4246 (tables: 8)
# Iteration time: 152.4734981060028
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-1800x.c1879
# OK: AMD Ryzen 7 1800X Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-1800x.c1879 (tables: 7)
# Iteration time: 229.55278515815735
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-10600k.c2213
# OK: Intel Core i5-10600K -> https://www.techpowerup.com/cpu-specs/core-i5-10600k.c2213 (tables: 7)
# Iteration time: 88.56004190444946
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8086k.c2054
# OK: Intel Core i7-8086K -> https://www.techpowerup.com/cpu-specs/core-i7-8086k.c2054 (tables: 8)
# Iteration time: 128.8494610786438
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-8400.c1964
# OK: Intel Core i5-8400 -> https://www.techpowerup.com/cpu-specs/core-i5-8400.c1964 (tables: 8)
# Iteration time: 109.46777606010437
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-5600g.c2471
# OK: AMD Ryzen 5 5600G -> https://www.techpowerup.com/cpu-specs/ryzen-5-5600g.c2471 (tables: 8)
# Iteration time: 149.11745524406433
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-5600x.c2365
# OK: AMD Ryzen 5 5600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-5600x.c2365 (tables: 8)
# Iteration time: 146.7803919315338
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-7740x.c1866
# OK: Intel Core i7-7740K -> https://www.techpowerup.com/cpu-specs/core-i7-7740x.c1866 (tables: 8)
# Iteration time: 191.70578289031982
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-3-1300x.c1898
# OK: AMD Ryzen 3 1300X -> https://www.techpowerup.com/cpu-specs/ryzen-3-1300x.c1898 (tables: 7)
# Iteration time: 123.73890805244446
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-3-3300x.c2297
# OK: AMD Ryzen 3 3300X -> https://www.techpowerup.com/cpu-specs/ryzen-3-3300x.c2297 (tables: 7)
# Iteration time: 147.4523069858551
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-pro-6650u.c2771
# OK: AMD Ryzen 5 PRO 6650U -> https://www.techpowerup.com/cpu-specs/ryzen-5-pro-6650u.c2771 (tables: 8)
# Iteration time: 163.44529724121094
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-3900x.c2128
# OK: AMD Ryzen 9 3900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-3900x.c2128 (tables: 7)
# Iteration time: 175.2635200023651
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8809g.c1980
# OK: Intel Core i7-8809G -> https://www.techpowerup.com/cpu-specs/core-i7-8809g.c1980 (tables: 7)
# Iteration time: 166.05695629119873
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-2700x.c2011
# OK: AMD Ryzen 7 2700X Eight-Core -> https://www.techpowerup.com/cpu-specs/ryzen-7-2700x.c2011 (tables: 7)
# Iteration time: 159.09102964401245
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-3700x.c2130
# OK: AMD Ryzen 7 3700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-3700x.c2130 (tables: 7)
# Iteration time: 153.42266082763672
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-10700.c2214
# OK: Intel Core i7-10700T -> https://www.techpowerup.com/cpu-specs/core-i7-10700.c2214 (tables: 7)
# Iteration time: 69.94773292541504
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e-2288g.c3534
# OK: Intel Xeon E-2288G -> https://www.techpowerup.com/cpu-specs/xeon-e-2288g.c3534 (tables: 8)
# Iteration time: 115.76994585990906
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-3-2200g.c1978
# OK: AMD Ryzen 3 2200G -> https://www.techpowerup.com/cpu-specs/ryzen-3-2200g.c1978 (tables: 8)
# Iteration time: 142.70177602767944
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-10885h.c2356
# OK: Intel Core i9-10885H -> https://www.techpowerup.com/cpu-specs/core-i9-10885h.c2356 (tables: 8)
# Iteration time: 146.17216610908508
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-3950x.c2203
# OK: AMD Ryzen 9 3950X -> https://www.techpowerup.com/cpu-specs/ryzen-9-3950x.c2203 (tables: 7)
# Iteration time: 129.29068613052368
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-2400g.c1976
# OK: AMD Ryzen 5 2400G -> https://www.techpowerup.com/cpu-specs/ryzen-5-2400g.c1976 (tables: 8)
# Iteration time: 128.77010321617126
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-7700.c1843
# OK: Intel Core i7-7700 -> https://www.techpowerup.com/cpu-specs/core-i7-7700.c1843 (tables: 7)
# Iteration time: 91.49331569671631
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e-2336.c2497
# OK: Intel Xeon E-2336 -> https://www.techpowerup.com/cpu-specs/xeon-e-2336.c2497 (tables: 7)
# Iteration time: 166.1306939125061
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-5960x.c1765
# OK: Intel Core i7-5960X -> https://www.techpowerup.com/cpu-specs/core-i7-5960x.c1765 (tables: 7)
# Iteration time: 116.86049795150757
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1260l-v5.c3231
# OK: Intel Xeon E3-1260L v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1260l-v5.c3231 (tables: 7)
# Iteration time: 154.99150204658508
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-6500.c1829
# OK: Intel Core i5-6500 -> https://www.techpowerup.com/cpu-specs/core-i5-6500.c1829 (tables: 7)
# Iteration time: 168.86112904548645
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-10100.c2206
# OK: Intel Core i3-10100 -> https://www.techpowerup.com/cpu-specs/core-i3-10100.c2206 (tables: 7)
# Iteration time: 175.01698112487793
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556
# OK: Intel Core i5-6260U -> https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556 (tables: 8)
# Iteration time: 126.82947301864624
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1235l-v5.c3235
# OK: Intel Xeon E3-1235L v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1235l-v5.c3235 (tables: 8)
# Iteration time: 175.24779510498047
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1240-v5.c3234
# OK: Intel Xeon E3-1240 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1240-v5.c3234 (tables: 7)
# Iteration time: 180.18245601654053
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8550u.c1974
# OK: Intel Core i7-8550U -> https://www.techpowerup.com/cpu-specs/core-i7-8550u.c1974 (tables: 7)
# Iteration time: 233.08933401107788
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1270-v5.c3229
# OK: Intel Xeon E3-1270 v5 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1270-v5.c3229 (tables: 7)
# Iteration time: 198.18712401390076
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1231-v3.c3183
# OK: Intel Xeon E3-1231 v3 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1231-v3.c3183 (tables: 7)
# Iteration time: 114.3607017993927
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4790.c1747
# OK: Intel Core i7-4790 -> https://www.techpowerup.com/cpu-specs/core-i7-4790.c1747 (tables: 8)
# Iteration time: 150.3945426940918
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-3470.c1039
# OK: Intel Core i5-3470 -> https://www.techpowerup.com/cpu-specs/core-i5-3470.c1039 (tables: 8)
# Iteration time: 164.04906177520752
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4770k.c1459
# OK: Intel Core i7-4770K -> https://www.techpowerup.com/cpu-specs/core-i7-4770k.c1459 (tables: 8)
# Iteration time: 231.5560519695282
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-4670.c1477
# OK: Intel Core i5-4670 -> https://www.techpowerup.com/cpu-specs/core-i5-4670.c1477 (tables: 7)
# Iteration time: 170.07201409339905
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4960x.c1569
# OK: Intel Core i7-4960X -> https://www.techpowerup.com/cpu-specs/core-i7-4960x.c1569 (tables: 8)
# Iteration time: 164.44779682159424
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-5600u.c1810
# OK: Intel Core i7-5600U -> https://www.techpowerup.com/cpu-specs/core-i7-5600u.c1810 (tables: 8)
# Iteration time: 133.69928097724915
# Fetched https://www.techpowerup.com/cpu-specs/fx-8370.c1785
# OK: AMD FX-8370 Eight-Core -> https://www.techpowerup.com/cpu-specs/fx-8370.c1785 (tables: 8)
# Iteration time: 81.64573383331299
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-7600k.c1848
# OK: Intel Core i5-7600K -> https://www.techpowerup.com/cpu-specs/core-i5-7600k.c1848 (tables: 8)
# Iteration time: 132.33937096595764
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-3-3200u.c2136
# OK: AMD Ryzen 3 3200U -> https://www.techpowerup.com/cpu-specs/ryzen-3-3200u.c2136 (tables: 8)
# Iteration time: 160.68337607383728
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-5200u.c1807
# OK: Intel Core i5-5200U -> https://www.techpowerup.com/cpu-specs/core-i5-5200u.c1807 (tables: 8)
# Iteration time: 73.79547476768494
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-3770k.c1001
# OK: Intel Core i7-3770K -> https://www.techpowerup.com/cpu-specs/core-i7-3770k.c1001 (tables: 8)
# Iteration time: 167.34025478363037
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6444y.c3163
# OK: Intel Xeon Gold 6444Y -> https://www.techpowerup.com/cpu-specs/xeon-gold-6444y.c3163 (tables: 8)
# Iteration time: 159.98287105560303
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-390.c3999
# OK: AMD RYZEN AI MAX PRO 390 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-390.c3999 (tables: 8)
# Iteration time: 149.24319195747375
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-5965wx.c2721
# OK: AMD Ryzen Threadripper PRO 5965WX -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-pro-5965wx.c2721 (tables: 8)
# Iteration time: 168.7193992137909
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7f32.c4263
# OK: AMD EPYC 7F32 -> https://www.techpowerup.com/cpu-specs/epyc-7f32.c4263 (tables: 8)
# Iteration time: 129.48429012298584
# Fetched https://www.techpowerup.com/cpu-specs/core-ultra-5-245k.c3781
# OK: Intel Core Ultra 5 245K -> https://www.techpowerup.com/cpu-specs/core-ultra-5-245k.c3781 (tables: 8)
# Iteration time: 158.8895800113678
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-9900x.c3650
# OK: AMD Ryzen 9 9900X -> https://www.techpowerup.com/cpu-specs/ryzen-9-9900x.c3650 (tables: 8)
# Iteration time: 122.49380302429199
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-14600k.c3266
# OK: Intel Core i5-14600K -> https://www.techpowerup.com/cpu-specs/core-i5-14600k.c3266 (tables: 8)
# Iteration time: 149.10555291175842
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-9700x.c3651
# OK: AMD Ryzen 7 9700X -> https://www.techpowerup.com/cpu-specs/ryzen-7-9700x.c3651 (tables: 8)
# Iteration time: 160.9581048488617
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-9600x.c3652
# OK: AMD Ryzen 5 9600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-9600x.c3652 (tables: 8)
# Iteration time: 202.31314206123352
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-pro-8840u.c3572
# OK: AMD Ryzen 7 PRO 7840U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-8840u.c3572 (tables: 8)
# Iteration time: 164.66140484809875
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-z1-extreme.c3276
# OK: AMD Ryzen Z1 Extreme -> https://www.techpowerup.com/cpu-specs/ryzen-z1-extreme.c3276 (tables: 8)
# Iteration time: 104.33884716033936
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7840u.c3212
# OK: AMD Ryzen 7 7840U -> https://www.techpowerup.com/cpu-specs/ryzen-7-7840u.c3212 (tables: 8)
# Iteration time: 127.00293612480164
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-1185g7.c2344
# OK: Intel Core i7-1185G7 -> https://www.techpowerup.com/cpu-specs/core-i7-1185g7.c2344 (tables: 8)
# Iteration time: 155.58033418655396
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-5500u.c2372
# OK: AMD Ryzen 5 5500U -> https://www.techpowerup.com/cpu-specs/ryzen-5-5500u.c2372 (tables: 8)
# Iteration time: 202.09140825271606
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-9-5900hx.c2371
# OK: AMD Ryzen 9 5900HX -> https://www.techpowerup.com/cpu-specs/ryzen-9-5900hx.c2371 (tables: 8)
# Iteration time: 168.07329034805298
# Fetched https://www.techpowerup.com/cpu-specs/epyc-9634.c2932
# OK: AMD EPYC 9634 -> https://www.techpowerup.com/cpu-specs/epyc-9634.c2932 (tables: 7)
# Iteration time: 138.74351620674133
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7643.c2377
# OK: AMD EPYC 7643 -> https://www.techpowerup.com/cpu-specs/epyc-7643.c2377 (tables: 7)
# Iteration time: 124.78983998298645
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8260.c2179
# OK: Intel Xeon Platinum 8260 -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8260.c2179 (tables: 7)
# Iteration time: 104.56480002403259
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7840hs.c3033
# OK: AMD Ryzen 7 7840HS -> https://www.techpowerup.com/cpu-specs/ryzen-7-7840hs.c3033 (tables: 8)
# Iteration time: 140.7363781929016
# Fetched https://www.techpowerup.com/cpu-specs/epyc-72f3.c2391
# OK: AMD EPYC 72F3 -> https://www.techpowerup.com/cpu-specs/epyc-72f3.c2391 (tables: 7)
# Iteration time: 149.47919988632202
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-7735hs.c3041
# OK: AMD Ryzen 7 7735HS -> https://www.techpowerup.com/cpu-specs/ryzen-7-7735hs.c3041 (tables: 8)
# Iteration time: 173.62487888336182
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-5560u.c3265
# OK: AMD Ryzen 5 5560U -> https://www.techpowerup.com/cpu-specs/ryzen-5-5560u.c3265 (tables: 8)
# Iteration time: 168.22583317756653
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-4700u.c2282
# OK: AMD Ryzen 7 4700U -> https://www.techpowerup.com/cpu-specs/ryzen-7-4700u.c2282 (tables: 8)
# Iteration time: 174.1784520149231
# Fetched https://www.techpowerup.com/cpu-specs/xeon-l5640.c953
# OK: Intel Xeon L5640 -> https://www.techpowerup.com/cpu-specs/xeon-l5640.c953 (tables: 7)
# Iteration time: 171.2627398967743
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-12100.c2541
# OK: Intel Core i3-12100 -> https://www.techpowerup.com/cpu-specs/core-i3-12100.c2541 (tables: 8)
# Iteration time: 140.1084542274475
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-8250u.c1972
# OK: Intel Core i5-8250U -> https://www.techpowerup.com/cpu-specs/core-i5-8250u.c1972 (tables: 7)
# Iteration time: 136.68187499046326
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-7100.c1865
# OK: Intel Core i3-7100 -> https://www.techpowerup.com/cpu-specs/core-i3-7100.c1865 (tables: 7)
# Iteration time: 166.92701601982117
# Fetched https://www.techpowerup.com/cpu-specs/xeon-6780e.c3664
# OK: Intel Xeon 6780E -> https://www.techpowerup.com/cpu-specs/xeon-6780e.c3664 (tables: 8)
# Iteration time: 109.79079389572144
# Fetched https://www.techpowerup.com/cpu-specs/xeon-6766e.c3663
# OK: Intel Xeon 6766E -> https://www.techpowerup.com/cpu-specs/xeon-6766e.c3663 (tables: 8)
# Iteration time: 235.081955909729
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7313.c2389
# OK: AMD EPYC 7313 -> https://www.techpowerup.com/cpu-specs/epyc-7313.c2389 (tables: 7)
# Iteration time: 157.75071096420288
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-9980x.c4169
# OK: AMD Ryzen Threadripper 9980X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-9980x.c4169 (tables: 7)
# Iteration time: 130.71921277046204
# Fetched https://www.techpowerup.com/cpu-specs/xeon-max-9468.c3086
# OK: Intel Xeon Max 9468 -> https://www.techpowerup.com/cpu-specs/xeon-max-9468.c3086 (tables: 8)
# Iteration time: 159.84921002388
# Fetched https://www.techpowerup.com/cpu-specs/xeon-silver-4310.c2454
# OK: Intel Xeon Silver 4108 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4310.c2454 (tables: 7)
# Iteration time: 228.0305140018463
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-5800h.c2368
# OK: AMD Ryzen 7 5800H -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800h.c2368 (tables: 7)
# Iteration time: 120.97991180419922
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-3600x.c2131
# OK: AMD Ryzen 5 3600X -> https://www.techpowerup.com/cpu-specs/ryzen-5-3600x.c2131 (tables: 7)
# Iteration time: 185.8688099384308
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-990x.c721
# OK: Intel Core i7 990X -> https://www.techpowerup.com/cpu-specs/core-i7-990x.c721 (tables: 8)
# Iteration time: 148.64829015731812
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7453.c2382
# ...
# Iteration time: 179.72592210769653
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7262.c2257
# OK: AMD EPYC 7K62 -> https://www.techpowerup.com/cpu-specs/epyc-7262.c2257 (tables: 8)
# Iteration time: 119.77054810523987
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7473x.c2761
# OK: AMD EPYC 7473X -> https://www.techpowerup.com/cpu-specs/epyc-7473x.c2761 (tables: 8)
# Iteration time: 108.62531518936157
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7663p.c3368
# OK: AMD EPYC 7663P -> https://www.techpowerup.com/cpu-specs/epyc-7663p.c3368 (tables: 7)
# Iteration time: 137.23314499855042
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2650-v4.c3791
# OK: Intel Xeon E5-2690 v4 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2650-v4.c3791 (tables: 7)
# Iteration time: 96.86575984954834
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2670.c978
# OK: Intel Xeon E5-2670 0 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2670.c978 (tables: 7)
# Iteration time: 221.54904794692993
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998
# OK: AMD RYZEN AI MAX+ PRO 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998 (tables: 8)
# Iteration time: 214.8894557952881
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998
# OK: AMD Ryzen AI MAX+ PRO 395 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-max-pro-395.c3998 (tables: 8)
# Iteration time: 142.9285068511963
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-9-365.c3656
# OK: AMD Ryzen AI 9 365 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-9-365.c3656 (tables: 8)
# Iteration time: 183.674546957016
# Fetched https://www.techpowerup.com/cpu-specs/core-ultra-7-256v.c3796
# OK: Intel Core Ultra 7 256V -> https://www.techpowerup.com/cpu-specs/core-ultra-7-256v.c3796 (tables: 8)
# Iteration time: 160.2298858165741
# Fetched https://www.techpowerup.com/cpu-specs/core-ultra-7-258v.c3795
# OK: Intel Core Ultra 7 258V -> https://www.techpowerup.com/cpu-specs/core-ultra-7-258v.c3795 (tables: 8)
# Iteration time: 207.76388001441956
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-5-340.c4005
# OK: AMD Ryzen AI 5 340 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-5-340.c4005 (tables: 8)
# Iteration time: 130.16059708595276
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-ai-7-pro-360.c4006
# OK: AMD Ryzen AI 7 PRO 360 -> https://www.techpowerup.com/cpu-specs/ryzen-ai-7-pro-360.c4006 (tables: 8)
# Iteration time: 150.30355095863342
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-1334u.c3064
# OK: Intel Core i5-1334U -> https://www.techpowerup.com/cpu-specs/core-i5-1334u.c3064 (tables: 8)
# Iteration time: 202.8201460838318
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556
# OK: Intel Core i5-12600 -> https://www.techpowerup.com/cpu-specs/core-i5-12600.c2556 (tables: 8)
# Iteration time: 174.7672860622406
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-8845hs.c3400
# OK: AMD Ryzen 7 8845HS -> https://www.techpowerup.com/cpu-specs/ryzen-7-8845hs.c3400 (tables: 8)
# Iteration time: 215.01375889778137
# Fetched https://www.techpowerup.com/cpu-specs/xeon-platinum-8480.c2958
# OK: Intel Xeon Platinum 8480+ -> https://www.techpowerup.com/cpu-specs/xeon-platinum-8480.c2958 (tables: 8)
# Iteration time: 169.16937494277954
# Fetched https://www.techpowerup.com/cpu-specs/core-ultra-7-165u.c3523
# OK: Intel Core Ultra 7 165U -> https://www.techpowerup.com/cpu-specs/core-ultra-7-165u.c3523 (tables: 8)
# Iteration time: 148.62317323684692
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-5800u.c2746
# OK: AMD Ryzen 7 5800U -> https://www.techpowerup.com/cpu-specs/ryzen-7-5800u.c2746 (tables: 8)
# Iteration time: 148.57191395759583
# Fetched https://www.techpowerup.com/cpu-specs/core-i9-10850k.c2336
# OK: Intel Core i9-10850K -> https://www.techpowerup.com/cpu-specs/core-i9-10850k.c2336 (tables: 7)
# Iteration time: 111.6375880241394
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-pro-4650g.c2325
# OK: AMD Ryzen 5 PRO 4650G -> https://www.techpowerup.com/cpu-specs/ryzen-5-pro-4650g.c2325 (tables: 8)
# Iteration time: 206.7560577392578
# Fetched https://www.techpowerup.com/cpu-specs/processor-n150.c4109
# OK: Intel N150 -> https://www.techpowerup.com/cpu-specs/processor-n150.c4109 (tables: 8)
# Iteration time: 154.93116903305054
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-3500x.c2264
# OK: AMD Ryzen 5 3500X -> https://www.techpowerup.com/cpu-specs/ryzen-5-3500x.c2264 (tables: 8)
# Iteration time: 161.63952589035034
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-threadripper-1900x.c1912
# OK: AMD Ryzen Threadripper 1900X -> https://www.techpowerup.com/cpu-specs/ryzen-threadripper-1900x.c1912 (tables: 7)
# Iteration time: 192.40601301193237
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700u.c2173
# OK: AMD Ryzen 7 PRO 3700U -> https://www.techpowerup.com/cpu-specs/ryzen-7-pro-3700u.c2173 (tables: 7)
# Iteration time: 142.1806058883667
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8700.c1949
# OK: Intel Core i7-8700 -> https://www.techpowerup.com/cpu-specs/core-i7-8700.c1949 (tables: 8)
# Iteration time: 141.12064266204834
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-1035g1.c2225
# OK: Intel Core i5-1035G1 -> https://www.techpowerup.com/cpu-specs/core-i5-1035g1.c2225 (tables: 8)
# Iteration time: 65.56093215942383
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-8300h.c1994
# OK: Intel Core i5-8300H -> https://www.techpowerup.com/cpu-specs/core-i5-8300h.c1994 (tables: 7)
# Iteration time: 154.39254093170166
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-8600k.c1948
# OK: Intel Core i5-8600K -> https://www.techpowerup.com/cpu-specs/core-i5-8600k.c1948 (tables: 8)
# Iteration time: 117.94993495941162
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7402.c2252
# OK: AMD EPYC 7402 -> https://www.techpowerup.com/cpu-specs/epyc-7402.c2252 (tables: 8)
# Iteration time: 132.46111488342285
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7302.c2254
# OK: AMD EPYC 7302 -> https://www.techpowerup.com/cpu-specs/epyc-7302.c2254 (tables: 8)
# Iteration time: 137.83208394050598
# Fetched https://www.techpowerup.com/cpu-specs/pentium-g4400.c1839
# OK: Intel Pentium G4400 -> https://www.techpowerup.com/cpu-specs/pentium-g4400.c1839 (tables: 7)
# Iteration time: 176.4409499168396
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-8559u.c2026
# OK: Intel Core i7-8559U -> https://www.techpowerup.com/cpu-specs/core-i7-8559u.c2026 (tables: 7)
# Iteration time: 144.31739711761475
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-9850h.c2292
# OK: Intel Core i7-9850H -> https://www.techpowerup.com/cpu-specs/core-i7-9850h.c2292 (tables: 7)
# Iteration time: 187.226300239563
# Fetched https://www.techpowerup.com/cpu-specs/ryzen-5-3500u.c2138
# OK: AMD Ryzen 5 3500U -> https://www.techpowerup.com/cpu-specs/ryzen-5-3500u.c2138 (tables: 8)
# Iteration time: 77.92277717590332
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-3550.c1006
# OK: Intel Core i5-3550 -> https://www.techpowerup.com/cpu-specs/core-i5-3550.c1006 (tables: 8)
# Iteration time: 196.4975550174713
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-3570k.c1005
# OK: Intel Core i5-3570K -> https://www.techpowerup.com/cpu-specs/core-i5-3570k.c1005 (tables: 8)
# Iteration time: 170.328959941864
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-6500t.c3515
# OK: Intel Core i5-6500T -> https://www.techpowerup.com/cpu-specs/core-i5-6500t.c3515 (tables: 8)
# Iteration time: 153.58335328102112
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-5820k.c1763
# OK: Intel Core i7-5820K -> https://www.techpowerup.com/cpu-specs/core-i7-5820k.c1763 (tables: 7)
# Iteration time: 134.41083693504333
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-4300m.c1721
# OK: Intel Core i5-4300M -> https://www.techpowerup.com/cpu-specs/core-i5-4300m.c1721 (tables: 7)
# Iteration time: 114.19934797286987
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-4430.c1470
# OK: Intel Core i5-4430 -> https://www.techpowerup.com/cpu-specs/core-i5-4430.c1470 (tables: 7)
# Iteration time: 127.95223498344421
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6330.c2434
# OK: Intel Xeon Gold 6130 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6330.c2434 (tables: 7)
# Iteration time: 157.69631624221802
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440
# OK: Intel Xeon Gold 6142 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6342.c2440 (tables: 7)
# Iteration time: 150.12335896492004
# Fetched https://www.techpowerup.com/cpu-specs/xeon-w-2123.c2950
# OK: Intel Xeon W-2123 -> https://www.techpowerup.com/cpu-specs/xeon-w-2123.c2950 (tables: 7)
# Iteration time: 170.12745714187622
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-2500s.c727
# OK: Intel Core i5-2500S -> https://www.techpowerup.com/cpu-specs/core-i5-2500s.c727 (tables: 7)
# Iteration time: 165.8321180343628
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-4200u.c1602
# OK: Intel Core i5-6200U -> https://www.techpowerup.com/cpu-specs/core-i5-4200u.c1602 (tables: 7)
# Iteration time: 145.05809378623962
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-8100t.c2016
# OK: Intel Core i3-8100T -> https://www.techpowerup.com/cpu-specs/core-i3-8100t.c2016 (tables: 8)
# Iteration time: 150.1332700252533
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-4558u.c1600
# OK: Intel Core i7-4558U -> https://www.techpowerup.com/cpu-specs/core-i7-4558u.c1600 (tables: 7)
# Iteration time: 71.251868724823
# Fetched https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586
# OK: Intel Core m3-7Y30 -> https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586 (tables: 8)
# Iteration time: 163.83992099761963
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-2120.c739
# OK: Intel Core i3-2120 -> https://www.techpowerup.com/cpu-specs/core-i3-2120.c739 (tables: 8)
# Iteration time: 72.3349928855896
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-3770.c1002
# OK: Intel Core i7-3770 -> https://www.techpowerup.com/cpu-specs/core-i7-3770.c1002 (tables: 8)
# Iteration time: 111.12707495689392
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-2600.c724
# OK: Intel Core i7-2600 -> https://www.techpowerup.com/cpu-specs/core-i7-2600.c724 (tables: 7)
# Iteration time: 172.56115984916687
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-3427u.c1075
# OK: Intel Core i5-3427U -> https://www.techpowerup.com/cpu-specs/core-i5-3427u.c1075 (tables: 8)
# Iteration time: 188.23583316802979
# Fetched https://www.techpowerup.com/cpu-specs/fx-6300.c1210
# OK: AMD FX-6300 Six-Core -> https://www.techpowerup.com/cpu-specs/fx-6300.c1210 (tables: 8)
# Iteration time: 114.85261607170105
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-4258u.c1604
# OK: Intel Core i5-4278U -> https://www.techpowerup.com/cpu-specs/core-i5-4258u.c1604 (tables: 7)
# Iteration time: 186.524071931839
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-10200h.c2354
# OK: Intel Core i5 -> https://www.techpowerup.com/cpu-specs/core-i5-10200h.c2354 (tables: 7)
# Iteration time: 188.3809630870819
# Fetched https://www.techpowerup.com/cpu-specs/xeon-silver-4314.c2451
# OK: Intel Xeon Silver 4214 -> https://www.techpowerup.com/cpu-specs/xeon-silver-4314.c2451 (tables: 7)
# Iteration time: 175.0417468547821
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-2410m.c1372
# OK: Intel Core i5-2410M -> https://www.techpowerup.com/cpu-specs/core-i5-2410m.c1372 (tables: 7)
# Iteration time: 148.04625272750854
# Fetched https://www.techpowerup.com/cpu-specs/core-2-duo-e8500.c469
# OK: Intel Core 2 Duo E8500 -> https://www.techpowerup.com/cpu-specs/core-2-duo-e8500.c469 (tables: 8)
# Iteration time: 98.09979200363159
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-2520m.c1307
# OK: Intel Core i5-2520M -> https://www.techpowerup.com/cpu-specs/core-i5-2520m.c1307 (tables: 7)
# Iteration time: 139.32920384407043
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-3630qm.c1218
# OK: Intel Core i7-3630QM -> https://www.techpowerup.com/cpu-specs/core-i7-3630qm.c1218 (tables: 8)
# Iteration time: 220.42662692070007
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-920.c646
# OK: Intel Core i7 920 -> https://www.techpowerup.com/cpu-specs/core-i7-920.c646 (tables: 7)
# Iteration time: 142.0165557861328
# Fetched https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586
# OK: Intel Core m3-6Y30 -> https://www.techpowerup.com/cpu-specs/core-m3-6y30.c3586 (tables: 8)
# Iteration time: 143.9199960231781
# Fetched https://www.techpowerup.com/cpu-specs/core-2-duo-t7700.c1535
# OK: Intel Core 2 Duo T7700 -> https://www.techpowerup.com/cpu-specs/core-2-duo-t7700.c1535 (tables: 7)
# Iteration time: 222.63041615486145
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e3-1105c.c1702
# OK: Intel Xeon E3-12xx v2 -> https://www.techpowerup.com/cpu-specs/xeon-e3-1105c.c1702 (tables: 7)
# Iteration time: 99.46482682228088
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-3110m.c1059
# OK: Intel Core i3-3110M -> https://www.techpowerup.com/cpu-specs/core-i3-3110m.c1059 (tables: 8)
# Iteration time: 216.07963299751282
# Fetched https://www.techpowerup.com/cpu-specs/celeron-725c.c1582
# OK: Intel Celeron N3350 -> https://www.techpowerup.com/cpu-specs/celeron-725c.c1582 (tables: 7)
# Iteration time: 108.84926891326904
# Fetched https://www.techpowerup.com/cpu-specs/core-2-duo-t7100.c1537
# OK: Intel Core 2 Duo T7100 -> https://www.techpowerup.com/cpu-specs/core-2-duo-t7100.c1537 (tables: 7)
# Iteration time: 127.05836009979248
# Fetched https://www.techpowerup.com/cpu-specs/celeron-725c.c1582
# OK: Intel Celeron J3455 -> https://www.techpowerup.com/cpu-specs/celeron-725c.c1582 (tables: 7)
# Iteration time: 122.440438747406
# Fetched https://www.techpowerup.com/cpu-specs/core-2-duo-e7300.c518
# OK: Intel Core 2 Duo P7350 -> https://www.techpowerup.com/cpu-specs/core-2-duo-e7300.c518 (tables: 7)
# Iteration time: 152.55759501457214
# Fetched https://www.techpowerup.com/cpu-specs/celeron-n2830.c1880
# OK: Intel Celeron N2830 -> https://www.techpowerup.com/cpu-specs/celeron-n2830.c1880 (tables: 7)
# Iteration time: 193.89932703971863
# Fetched https://www.techpowerup.com/cpu-specs/a6-3410mx.c891
# OK: AMD A6-3410MX APU -> https://www.techpowerup.com/cpu-specs/a6-3410mx.c891 (tables: 8)
# Iteration time: 115.52934503555298
# Fetched https://www.techpowerup.com/cpu-specs/core-i5-460m.c1872
# OK: Intel Core i5 460M -> https://www.techpowerup.com/cpu-specs/core-i5-460m.c1872 (tables: 8)
# Iteration time: 107.19576001167297
# Fetched https://www.techpowerup.com/cpu-specs/epyc-7303.c3371
# OK: AMD EPYC 7303 -> https://www.techpowerup.com/cpu-specs/epyc-7303.c3371 (tables: 7)
# Iteration time: 117.27750611305237
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6414u.c3140
# OK: Intel Xeon Gold 6414U -> https://www.techpowerup.com/cpu-specs/xeon-gold-6414u.c3140 (tables: 8)
# Iteration time: 167.47986817359924
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-5416s.c3161
# OK: Intel Xeon Gold 5416S -> https://www.techpowerup.com/cpu-specs/xeon-gold-5416s.c3161 (tables: 8)
# Iteration time: 114.23018598556519
# Fetched https://www.techpowerup.com/cpu-specs/xeon-e5-2687w.c981
# OK: Intel Xeon E5-2687W 0 -> https://www.techpowerup.com/cpu-specs/xeon-e5-2687w.c981 (tables: 7)
# Iteration time: 136.57750010490417
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-12700kf.c2508
# OK: Intel Core i7-12700KF -> https://www.techpowerup.com/cpu-specs/core-i7-12700kf.c2508 (tables: 7)
# Iteration time: 144.31351613998413
# Fetched https://www.techpowerup.com/cpu-specs/xeon-gold-6154.c2056
# OK: Intel Xeon Gold 6144 -> https://www.techpowerup.com/cpu-specs/xeon-gold-6154.c2056 (tables: 7)
# Iteration time: 164.17208099365234
# Fetched https://www.techpowerup.com/cpu-specs/core-i7-1185g7e.c4213
# OK: Intel Core i7-1185G7E -> https://www.techpowerup.com/cpu-specs/core-i7-1185g7e.c4213 (tables: 8)
# Iteration time: 217.72056913375854
# Fetched https://www.techpowerup.com/cpu-specs/core-i3-1005g1.c2224
# OK: Intel Core i3-1005G1 -> https://www.techpowerup.com/cpu-specs/core-i3-1005g1.c2224 (tables: 8)
# Iteration time: 195.4734649658203
#
# Saved 429 models to cpu_specs_raw_tables.pkl. Errors: 0

# %%
with open("cpu_specs_raw_tables.pkl", "rb") as f:
    payload = pickle.load(f)
# Out:
# {'tables': {'AMD Ryzen 9 9950X': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            4 nm
# 3       Transistors:  16,630 million
# 4          Die Size:     2x 70.6 mm²
# 5  I/O Process Size:            6 nm
# 6   I/O Transistors:   3,400 million
# 7      I/O Die Size:         122 mm²
# 8           Package:      FC-LGA1718
# 9             tJMax:            95°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Aug 15th, 2024
# 3       Launch Price:            $649
# 4              Part#:   100-000001277
# 5     Bundled Cooler:             NaN,                       0              1
# 0            Frequency:        4.3 GHz
# 1          Turbo Clock:  up to 5.7 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          43.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          170 W
# 6                  PPT:          230 W,                    0                                                  1
# 0          Codename:                                      Granite Ridge
# 1        Generation:                   Ryzen 9  (Zen 5 (Granite Ridge))
# 2    Memory Support:                                               DDR5
# 3       Rated Speed:                                          5600 MT/s
# 4        Memory Bus:                                       Dual-channel
# 5  Memory Bandwidth:                                          89.6 GB/s
# 6        ECC Memory:                                                Yes
# 7       PCI-Express:                         Gen 5, 24 Lanes (CPU only)
# 8          Chipsets:  X870E, X870, B850, B840, X670E, X670, B650E, B...,                       0                1
# 0           # of Cores:               16
# 1         # of Threads:               32
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  80 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 400-2200MHz...], 'AMD RYZEN AI MAX+ 395': [               0                1
# 0        Socket:  AMD Socket FP11
# 1       Foundry:             TSMC
# 2  Process Size:             4 nm
# 3      Die Size:      2x 70.6 mm²
# 4  I/O Die Size:          308 mm²
# 5       Package:           FC-BGA
# 6         tJMax:            100°C,                     0              1
# 0             Market:         Mobile
# 1  Production Status:         Active
# 2       Release Date:  Jan 6th, 2025
# 3              Part#:  100-000001099,                       0               1
# 0            Frequency:           3 GHz
# 1          Turbo Clock:   up to 5.1 GHz
# 2           Base Clock:         100 MHz
# 3                  NPU:  Yes /  50 TOPS
# 4           Multiplier:           30.0x
# 5  Multiplier Unlocked:              No
# 6                  TDP:            55 W
# 7     Configurable TDP:        45-120 W,                    0                                   1
# 0          Codename:                          Strix Halo
# 1        Generation:  Ryzen AI Max  (Zen 5 (Strix Halo))
# 2    Memory Support:                             LPDDR5X
# 3       Rated Speed:                           8000 MT/s
# 4        Memory Bus:                        Quad-channel
# 5   Memory Capacity:                        up to 128 GB
# 6  Memory Bandwidth:                          256.0 GB/s
# 7        ECC Memory:                                 Yes
# 8       PCI-Express:          Gen 4, 16 Lanes (CPU only),                       0             1
# 0           # of Cores:            16
# 1         # of Threads:            32
# 2           SMP # CPUs:             1
# 3  Integrated Graphics:  Radeon 8060S,            0                 1
# 0  Cache L1:  80 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 2900 MHz In...], 'Intel Core i9-13900K': [               0                  1
# 0        Socket:  Intel Socket 1700
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3      Die Size:            257 mm²
# 4       Package:          FC-LGA16A
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3      Retail Launch:  Oct 20th, 2022
# 4       Launch Price:            $589
# 5              Part#:           SRMBH,                        0                       1
# 0             Frequency:                   3 GHz
# 1           Turbo Clock:           up to 5.8 GHz
# 2          P-Core Turbo:                 5.4 GHz
# 3      P-Core Boost 3.0:                 5.7 GHz
# 4      E-Core Frequency:  2.2 GHz  up to 4.3 GHz
# 5            Base Clock:                 100 MHz
# 6            Multiplier:                   30.0x
# 7   Multiplier Unlocked:                     Yes
# 8                   TDP:                   125 W
# 9                   PL1:                   253 W
# 10                  PL2:                   253 W
# 11        PL2 Tau Limit:               Unlimited,                  0                                                  1
# 0        Codename:                                      Raptor Lake-S
# 1      Generation:                             Core i9  (Raptor Lake)
# 2  Memory Support:                                         DDR4, DDR5
# 3      DDR4 Speed:                                          3200 MT/s
# 4      DDR5 Speed:                                          5600 MT/s
# 5      Memory Bus:                                       Dual-channel
# 6      ECC Memory:                                                Yes
# 7     PCI-Express:                         Gen 5, 16 Lanes (CPU only)
# 8  Secondary PCIe:                                     Gen 4, 4 Lanes
# 9        Chipsets:  H610, B660, H670, Q670, Z690, W680, B760, H770...,                       0                        1
# 0           # of Cores:                       24
# 1         # of Threads:                       32
# 2         Hybrid Cores:  P-Cores: 8  E-Cores: 16
# 3           SMP # CPUs:                        1
# 4  Integrated Graphics:         UHD Graphics 770,             0                  1
# 0   Cache L1:   80 KB (per core)
# 1   Cache L2:    2 MB (per core)
# 2   Cache L3:     36 MB (shared)
# 3  E-Core L1:   96 KB (per core)
# 4  E-Core L2:  4 MB (per module),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  Intel UHD Graphics Dynamic Frequency: 300-1650MHz], 'AMD Ryzen 7 7700X': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:   6,570 million
# 4          Die Size:          71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            61°C
# 9             tJMax:           100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3       Launch Price:            $399
# 4              Part#:   100-000000591,                       0              1
# 0            Frequency:        4.5 GHz
# 1          Turbo Clock:  up to 5.4 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          45.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                               1
# 0          Codename:                         Raphael
# 1        Generation:      Ryzen 7  (Zen 4 (Raphael))
# 2    Memory Support:                            DDR5
# 3       Rated Speed:                       5200 MT/s
# 4        Memory Bus:                    Dual-channel
# 5  Memory Bandwidth:                       83.2 GB/s
# 6        ECC Memory:                             Yes
# 7       PCI-Express:      Gen 5, 24 Lanes (CPU only)
# 8          Chipsets:  X670E, X670, B650E, B650, A620,                       0                1
# 0           # of Cores:                8
# 1         # of Threads:               16
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    32 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...], 'AMD Ryzen 9 7950X': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  13,140 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            47°C
# 9             tJMax:           100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3       Launch Price:            $699
# 4              Part#:   100-000000514,                       0              1
# 0            Frequency:        4.5 GHz
# 1          Turbo Clock:  up to 5.7 GHz
# 2                  XFR:       5.85 GHz
# 3           Base Clock:        100 MHz
# 4           Multiplier:          45.0x
# 5  Multiplier Unlocked:            Yes
# 6                  TDP:          170 W
# 7                  PPT:          230 W,                    0                               1
# 0          Codename:                         Raphael
# 1        Generation:      Ryzen 9  (Zen 4 (Raphael))
# 2    Memory Support:                            DDR5
# 3       Rated Speed:                       5200 MT/s
# 4        Memory Bus:                    Dual-channel
# 5  Memory Bandwidth:                       83.2 GB/s
# 6        ECC Memory:                             Yes
# 7       PCI-Express:      Gen 5, 24 Lanes (CPU only)
# 8          Chipsets:  X670E, X670, B650E, B650, A620,                       0                1
# 0           # of Cores:               16
# 1         # of Threads:               32
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 400-2200MHz...], 'Intel Core i9-14900K': [               0                  1
# 0        Socket:  Intel Socket 1700
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3      Die Size:            257 mm²
# 4       Package:          FC-LGA16A
# 5         tJMax:              100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Oct 17th, 2023
# 3       Launch Price:            $589
# 4              Part#:           SRN48
# 5     Bundled Cooler:             NaN,                        0                       1
# 0             Frequency:                 3.2 GHz
# 1           Turbo Clock:             up to 6 GHz
# 2          P-Core Turbo:                 5.6 GHz
# 3      P-Core Boost 3.0:                 5.8 GHz
# 4      E-Core Frequency:  2.4 GHz  up to 4.4 GHz
# 5            Base Clock:                 100 MHz
# 6            Multiplier:                   32.0x
# 7   Multiplier Unlocked:                     Yes
# 8                   TDP:                   125 W
# 9                   PL1:                   253 W
# 10                  PL2:                   253 W
# 11        PL2 Tau Limit:               Unlimited,                  0                                   1
# 0        Codename:                       Raptor Lake-R
# 1      Generation:      Core i9  (Raptor Lake Refresh)
# 2  Memory Support:                          DDR4, DDR5
# 3      DDR4 Speed:                           3200 MT/s
# 4      DDR5 Speed:                           5600 MT/s
# 5      Memory Bus:                        Dual-channel
# 6      ECC Memory:                                 Yes
# 7     PCI-Express:          Gen 5, 16 Lanes (CPU only)
# 8  Secondary PCIe:                      Gen 4, 4 Lanes
# 9        Chipsets:  Intel 600 Series, Intel 700 Series,                       0                        1
# 0           # of Cores:                       24
# 1         # of Threads:                       32
# 2         Hybrid Cores:  P-Cores: 8  E-Cores: 16
# 3           SMP # CPUs:                        1
# 4  Integrated Graphics:         UHD Graphics 770,             0                  1
# 0   Cache L1:   80 KB (per core)
# 1   Cache L2:    2 MB (per core)
# 2   Cache L3:     36 MB (shared)
# 3  E-Core L1:   96 KB (per core)
# 4  E-Core L2:  4 MB (per module),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  Intel UHD Graphics Dynamic Frequency: 300-1650MHz], 'AMD EPYC 4364P': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:   6,570 million
# 4          Die Size:          71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            61°C
# 9             tJMax:            95°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $399
# 4              Part#:       100-000001477,                       0              1
# 0            Frequency:        4.5 GHz
# 1          Turbo Clock:  up to 5.4 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          45.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:     EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 28 Lanes (CPU only),                       0                1
# 0           # of Cores:                8
# 1         # of Threads:               16
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    32 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                 0
# 0  Radeon Graphics dynamic frequency: 400-2200MHz], 'AMD Ryzen 9 7900X': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  13,140 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            47°C
# 9             tJMax:           100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3       Launch Price:            $549
# 4              Part#:   100-000000589,                       0              1
# 0            Frequency:        4.7 GHz
# 1          Turbo Clock:  up to 5.6 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          47.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          170 W
# 6                  PPT:          230 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:  Ryzen 9  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 24 Lanes (CPU only)
# 8          Chipsets:    X670E, X670, B650E, B650,                       0                1
# 0           # of Cores:               12
# 1         # of Threads:               24
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 400-2200 MH...], 'Intel Core i9-12900K': [               0                  1
# 0        Socket:  Intel Socket 1700
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3      Die Size:            215 mm²
# 4       Package:          FC-LGA16A
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0              1
# 0             Market:        Desktop
# 1  Production Status:         Active
# 2       Release Date:  Nov 4th, 2021
# 3       Launch Price:           $599
# 4              Part#:          SRL4H,                       0                       1
# 0            Frequency:                 3.2 GHz
# 1          Turbo Clock:           up to 5.2 GHz
# 2     E-Core Frequency:  2.4 GHz  up to 3.9 GHz
# 3           Base Clock:                 100 MHz
# 4           Multiplier:                   32.0x
# 5  Multiplier Unlocked:                     Yes
# 6                  TDP:                   125 W
# 7                  PL1:                   241 W
# 8                  PL2:                   241 W
# 9        PL2 Tau Limit:               Unlimited,                  0                           1
# 0        Codename:                Alder Lake-S
# 1      Generation:     Core i9  (Alder Lake-S)
# 2  Memory Support:                  DDR4, DDR5
# 3      DDR4 Speed:                   3200 MT/s
# 4      DDR5 Speed:                   4800 MT/s
# 5      Memory Bus:                Dual-channel
# 6      ECC Memory:                          No
# 7     PCI-Express:  Gen 5, 20 Lanes (CPU only)
# 8        Chipsets:      Z690, H670, B660, H610,                       0                       1
# 0           # of Cores:                      16
# 1         # of Threads:                      24
# 2         Hybrid Cores:  P-Cores: 8  E-Cores: 8
# 3           SMP # CPUs:                       1
# 4  Integrated Graphics:        UHD Graphics 770,            0                   1
# 0  Cache L1:    80 KB (per core)
# 1  Cache L2:  1.25 MB (per core)
# 2  Cache L3:      30 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                          0
# 0  UHD Graphics dynamic frequency: 1550MHz], 'AMD EPYC 4564P': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  13,140 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            47°C
# 9             tJMax:           100°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $699
# 4              Part#:       100-000001476,                       0              1
# 0            Frequency:        4.5 GHz
# 1          Turbo Clock:  up to 5.7 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          45.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          170 W
# 6                  PPT:          230 W,                    0                               1
# 0          Codename:                         Raphael
# 1        Generation:         EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                            DDR5
# 3       Rated Speed:                       5200 MT/s
# 4        Memory Bus:                    Dual-channel
# 5  Memory Bandwidth:                       83.2 GB/s
# 6        ECC Memory:                             Yes
# 7       PCI-Express:      Gen 5, 28 Lanes (CPU only)
# 8          Chipsets:  X670E, X670, B650E, B650, A620,                       0                1
# 0           # of Cores:               16
# 1         # of Threads:               32
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                 0
# 0  Radeon graphics dynamic frequency: 400-2200MHz], 'AMD EPYC 4464P': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  13,140 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            61°C
# 9             tJMax:            95°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $429
# 4              Part#:       100-000001478,                       0              1
# 0            Frequency:        3.7 GHz
# 1          Turbo Clock:  up to 5.4 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          37.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:           65 W
# 6                  PPT:           88 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:     EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 28 Lanes (CPU only),                       0                1
# 0           # of Cores:               12
# 1         # of Threads:               24
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    64 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                 0
# 0  Radeon Graphics dynamic frequency: 400-2200MHz], 'AMD EPYC 4584PX': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  17,840 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            47°C
# 9             tJMax:            89°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $699
# 4              Part#:       100-000001481
# 5     Bundled Cooler:                 NaN,                       0              1
# 0            Frequency:        4.2 GHz
# 1          Turbo Clock:  up to 5.7 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          42.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          120 W
# 6                  PPT:          162 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:     EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 28 Lanes (CPU only),                       0                1
# 0           # of Cores:               16
# 1         # of Threads:               32
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,              0                 1
# 0    Cache L1:  64 KB (per core)
# 1    Cache L2:   1 MB (per core)
# 2    Cache L3:   128 MB (shared)
# 3  3D V-Cache:     1x 64MB Slice,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 400-2200MHz...], 'AMD EPYC 4484PX': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:  17,840 million
# 4          Die Size:       2x 71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            47°C
# 9             tJMax:            89°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $599
# 4              Part#:       100-000001482
# 5     Bundled Cooler:                 NaN,                       0              1
# 0            Frequency:        4.4 GHz
# 1          Turbo Clock:  up to 5.6 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          44.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          120 W
# 6                  PPT:          162 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:     EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 28 Lanes (CPU only),                       0                1
# 0           # of Cores:               12
# 1         # of Threads:               24
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,              0                 1
# 0    Cache L1:  64 KB (per core)
# 1    Cache L2:   1 MB (per core)
# 2    Cache L3:   128 MB (shared)
# 3  3D V-Cache:     1x 64MB Slice,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Radeon graphics dynamic frequency: 400-2200MHz...], 'AMD Ryzen 9 5900X': [                   0               1
# 0            Socket:  AMD Socket AM4
# 1           Foundry:            TSMC
# 2      Process Size:            7 nm
# 3       Transistors:   8,300 million
# 4          Die Size:       2x 74 mm²
# 5  I/O Process Size:           12 nm
# 6      I/O Die Size:         125 mm²
# 7           Package:      µOPGA-1331
# 8          tCaseMax:            95°C,                     0              1
# 0             Market:        Desktop
# 1  Production Status:         Active
# 2       Release Date:  Nov 5th, 2020
# 3       Launch Price:           $549
# 4              Part#:  100-000000061,                       0              1
# 0            Frequency:        3.7 GHz
# 1          Turbo Clock:  up to 4.8 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          37.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                                                1
# 0          Codename:                                          Vermeer
# 1        Generation:                       Ryzen 9  (Zen 3 (Vermeer))
# 2    Memory Support:                                             DDR4
# 3       Rated Speed:                                        3200 MT/s
# 4        Memory Bus:                                     Dual-channel
# 5  Memory Bandwidth:                                        51.2 GB/s
# 6        ECC Memory:                                              Yes
# 7       PCI-Express:                                            Gen 4
# 8          Chipsets:  AMD 300 Series*, AMD 400 Series, AMD 500 Series,                       0     1
# 0           # of Cores:  12.0
# 1         # of Threads:  24.0
# 2           SMP # CPUs:   1.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  512 KB (per core)
# 2  Cache L3:              64 MB,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  AMD 300 Series chipset support is contingent o...], 'AMD Ryzen 5 7600X': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:   6,570 million
# 4          Die Size:          71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            61°C
# 9             tJMax:           100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3       Launch Price:            $299
# 4              Part#:   100-000000593,                       0              1
# 0            Frequency:        4.7 GHz
# 1          Turbo Clock:  up to 5.3 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          47.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:  Ryzen 5  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 24 Lanes (CPU only)
# 8          Chipsets:    X670E, X670, B650E, B650,                       0                1
# 0           # of Cores:                6
# 1         # of Threads:               12
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    32 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                              0
# 0  Radeon Graphics dynamic frequency: 2200 MHz], 'Intel Core i9-11900K': [               0                  1
# 0        Socket:  Intel Socket 1200
# 1       Foundry:              Intel
# 2  Process Size:              14 nm
# 3      Die Size:            276 mm²
# 4       Package:          FC-LGA14A
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:     End-of-life
# 2       Release Date:  Mar 16th, 2021
# 3       Launch Price:            $539
# 4              Part#:           SRKND,                         0              1
# 0              Frequency:        3.5 GHz
# 1     TDP-down Frequency:          3 GHz
# 2            Turbo Clock:  up to 5.3 GHz
# 3              Boost 3.0:  up to 5.2 GHz
# 4              Boost 2.0:  up to 5.1 GHz
# 5             Base Clock:        100 MHz
# 6             Multiplier:          35.0x
# 7    Multiplier Unlocked:            Yes
# 8                    TDP:          125 W
# 9  Configurable TDP-down:            95W,                    0                                                  1
# 0          Codename:                                        Rocket Lake
# 1        Generation:                           Core i9  (Rocket Lake-S)
# 2    Memory Support:                                               DDR4
# 3       Rated Speed:                                          3200 MT/s
# 4        Memory Bus:                                       Dual-channel
# 5  Memory Bandwidth:                                          51.2 GB/s
# 6        ECC Memory:                                                 No
# 7       PCI-Express:                         Gen 4, 20 Lanes (CPU only)
# 8          Chipsets:  H510, B560, H570, Q570, W580, Z590, Q470, H470...,                       0                 1
# 0           # of Cores:                 8
# 1         # of Threads:                16
# 2           SMP # CPUs:                 1
# 3  Integrated Graphics:  UHD Graphics 750,            0                  1
# 0  Cache L1:   80 KB (per core)
# 1  Cache L2:  512 KB (per core)
# 2  Cache L3:     16 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                               0
# 0  UHD Graphics dynamic frequency: 350-1300 MHz], 'AMD Ryzen 9 5950X': [                   0               1
# 0            Socket:  AMD Socket AM4
# 1           Foundry:            TSMC
# 2      Process Size:            7 nm
# 3       Transistors:   8,300 million
# 4          Die Size:       2x 74 mm²
# 5  I/O Process Size:           12 nm
# 6      I/O Die Size:         125 mm²
# 7           Package:      µOPGA-1331
# 8          tCaseMax:            95°C,                     0              1
# 0             Market:        Desktop
# 1  Production Status:         Active
# 2       Release Date:  Nov 5th, 2020
# 3       Launch Price:           $799
# 4              Part#:  100-000000059
# 5     Bundled Cooler:            NaN,                       0              1
# 0            Frequency:        3.4 GHz
# 1          Turbo Clock:  up to 4.9 GHz
# 2                  XFR:       5.05 GHz
# 3           Base Clock:        100 MHz
# 4           Multiplier:          34.0x
# 5  Multiplier Unlocked:            Yes
# 6                  TDP:          105 W
# 7                  PPT:          142 W,                    0                                                1
# 0          Codename:                                          Vermeer
# 1        Generation:                       Ryzen 9  (Zen 3 (Vermeer))
# 2    Memory Support:                                             DDR4
# 3       Rated Speed:                                        3200 MT/s
# 4        Memory Bus:                                     Dual-channel
# 5  Memory Bandwidth:                                        51.2 GB/s
# 6        ECC Memory:                                              Yes
# 7       PCI-Express:                       Gen 4, 20 Lanes (CPU only)
# 8          Chipsets:  AMD 300 Series*, AMD 400 Series, AMD 500 Series,                       0     1
# 0           # of Cores:  16.0
# 1         # of Threads:  32.0
# 2           SMP # CPUs:   1.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  512 KB (per core)
# 2  Cache L3:              64 MB,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  AMD 300 Series chipset support is contingent o...], 'AMD Ryzen 7 5800X': [                   0               1
# 0            Socket:  AMD Socket AM4
# 1           Foundry:            TSMC
# 2      Process Size:            7 nm
# 3       Transistors:   4,150 million
# 4          Die Size:          74 mm²
# 5  I/O Process Size:           12 nm
# 6      I/O Die Size:         125 mm²
# 7           Package:      µOPGA-1331
# 8          tCaseMax:            95°C,                     0              1
# 0             Market:        Desktop
# 1  Production Status:         Active
# 2       Release Date:  Nov 5th, 2020
# 3       Launch Price:           $449
# 4              Part#:  100-000000063,                       0              1
# 0            Frequency:        3.8 GHz
# 1          Turbo Clock:  up to 4.7 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          38.0x
# 4  Multiplier Unlocked:            Yes
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                                                1
# 0          Codename:                                          Vermeer
# 1        Generation:                       Ryzen 7  (Zen 3 (Vermeer))
# 2    Memory Support:                                             DDR4
# 3       Rated Speed:                                        3200 MT/s
# 4        Memory Bus:                                     Dual-channel
# 5  Memory Bandwidth:                                        51.2 GB/s
# 6        ECC Memory:                                              Yes
# 7       PCI-Express:                       Gen 4, 20 Lanes (CPU only)
# 8          Chipsets:  AMD 300 Series*, AMD 400 Series, AMD 500 Series,                       0     1
# 0           # of Cores:   8.0
# 1         # of Threads:  16.0
# 2           SMP # CPUs:   1.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  512 KB (per core)
# 2  Cache L3:              32 MB,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  AMD 300 Series chipset support is contingent o...], 'AMD Ryzen 7 5800X3D': [                   0               1
# 0            Socket:  AMD Socket AM4
# 1           Foundry:            TSMC
# 2      Process Size:            7 nm
# 3       Transistors:   8,850 million
# 4          Die Size:          74 mm²
# 5  I/O Process Size:           12 nm
# 6      I/O Die Size:         125 mm²
# 7           Package:      µOPGA-1331
# 8          tCaseMax:            90°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:     End-of-life
# 2       Release Date:  Apr 20th, 2022
# 3       Launch Price:            $449
# 4              Part#:   100-000000651,                       0              1
# 0            Frequency:        3.4 GHz
# 1          Turbo Clock:  up to 4.5 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          34.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          105 W
# 6                  PPT:          142 W,                    0                                                1
# 0          Codename:                                          Vermeer
# 1        Generation:                       Ryzen 7  (Zen 3 (Vermeer))
# 2    Memory Support:                                             DDR4
# 3       Rated Speed:                                        3200 MT/s
# 4        Memory Bus:                                     Dual-channel
# 5  Memory Bandwidth:                                        51.2 GB/s
# 6        ECC Memory:                                              Yes
# 7       PCI-Express:                       Gen 4, 20 Lanes (CPU only)
# 8          Chipsets:  AMD 300 Series*, AMD 400 Series, AMD 500 Series,                       0     1
# 0           # of Cores:   8.0
# 1         # of Threads:  16.0
# 2           SMP # CPUs:   1.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  512 KB (per core)
# 2  Cache L3:     96 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                    0
# 0  Level 3 cache arranged as 32MB 2D cache plus 6...], 'Intel Core i9-10900K': [               0                  1
# 0        Socket:  Intel Socket 1200
# 1       Foundry:              Intel
# 2  Process Size:              14 nm
# 3      Die Size:            206 mm²
# 4       Package:         FC-LGA1200
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:     End-of-life
# 2       Release Date:  Apr 30th, 2020
# 3       Launch Price:            $547
# 4              Part#:           SRH91,                       0               1
# 0            Frequency:         3.7 GHz
# 1          Turbo Clock:   up to 5.3 GHz
# 2  Boost 3.0 Frequency:         5.2 GHz
# 3           Base Clock:         100 MHz
# 4           Multiplier:           37.0x
# 5  Multiplier Unlocked:             Yes
# 6                  TDP:           125 W
# 7                  PL1:           125 W
# 8                  PL2:           250 W
# 9                 FP32:  1,696.0 GFLOPS,                    0                           1
# 0          Codename:                  Comet Lake
# 1        Generation:       Core i9  (Comet Lake)
# 2    Memory Support:                        DDR4
# 3       Rated Speed:                   2933 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   46.9 GB/s
# 6        ECC Memory:                          No
# 7       PCI-Express:  Gen 3, 16 Lanes (CPU only)
# 8          Chipsets:      H410, B460, H470, Z490,                       0                 1
# 0           # of Cores:                10
# 1         # of Threads:                20
# 2           SMP # CPUs:                 1
# 3  Integrated Graphics:  UHD Graphics 630,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  256 KB (per core)
# 2  Cache L3:     20 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...], 'Intel Core i5-13600K': [               0                  1
# 0        Socket:  Intel Socket 1700
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3      Die Size:            257 mm²
# 4       Package:          FC-LGA16A
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0               1
# 0             Market:         Desktop
# 1  Production Status:          Active
# 2       Release Date:  Sep 27th, 2022
# 3      Retail Launch:  Oct 20th, 2022
# 4       Launch Price:            $319
# 5              Part#:           SRMBD,                       0                       1
# 0            Frequency:                 3.5 GHz
# 1          Turbo Clock:           up to 5.1 GHz
# 2     E-Core Frequency:  2.6 GHz  up to 3.9 GHz
# 3           Base Clock:                 100 MHz
# 4           Multiplier:                   35.0x
# 5  Multiplier Unlocked:                     Yes
# 6                  TDP:                   125 W
# 7                  PL1:                   181 W
# 8                  PL2:                   181 W
# 9        PL2 Tau Limit:               Unlimited,                  0                           1
# 0        Codename:               Raptor Lake-S
# 1      Generation:      Core i5  (Raptor Lake)
# 2  Memory Support:                  DDR4, DDR5
# 3      DDR4 Speed:                   3200 MT/s
# 4      DDR5 Speed:                   5600 MT/s
# 5      Memory Bus:                Dual-channel
# 6      ECC Memory:                         Yes
# 7     PCI-Express:  Gen 5, 16 Lanes (CPU only)
# 8  Secondary PCIe:              Gen 4, 4 Lanes
# 9        Chipsets:                  Z690, Z790,                       0                       1
# 0           # of Cores:                      14
# 1         # of Threads:                      20
# 2         Hybrid Cores:  P-Cores: 6  E-Cores: 8
# 3           SMP # CPUs:                       1
# 4  Integrated Graphics:        UHD Graphics 770,             0                  1
# 0   Cache L1:   80 KB (per core)
# 1   Cache L2:    2 MB (per core)
# 2   Cache L3:     24 MB (shared)
# 3  E-Core L1:   96 KB (per core)
# 4  E-Core L2:  4 MB (per module),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                              0
# 0  UHD Graphics Dynamic Frequency: 300-1500MHz], 'AMD EPYC 4124P': [                   0               1
# 0            Socket:  AMD Socket AM5
# 1           Foundry:            TSMC
# 2      Process Size:            5 nm
# 3       Transistors:   6,570 million
# 4          Die Size:          71 mm²
# 5  I/O Process Size:            6 nm
# 6      I/O Die Size:         122 mm²
# 7           Package:      FC-LGA1718
# 8          tCaseMax:            61°C
# 9             tJMax:            95°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      May 21st, 2024
# 3       Launch Price:                $149
# 4              Part#:       100-000001570,                       0              1
# 0            Frequency:        3.8 GHz
# 1          Turbo Clock:  up to 5.1 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          38.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:           65 W
# 6                  PPT:           88 W,                    0                           1
# 0          Codename:                     Raphael
# 1        Generation:     EPYC  (Zen 4 (Raphael))
# 2    Memory Support:                        DDR5
# 3       Rated Speed:                   5200 MT/s
# 4        Memory Bus:                Dual-channel
# 5  Memory Bandwidth:                   83.2 GB/s
# 6        ECC Memory:                         Yes
# 7       PCI-Express:  Gen 5, 28 Lanes (CPU only),                       0                1
# 0           # of Cores:                4
# 1         # of Threads:                8
# 2           SMP # CPUs:                1
# 3  Integrated Graphics:  Radeon Graphics,            0                 1
# 0  Cache L1:  64 KB (per core)
# 1  Cache L2:   1 MB (per core)
# 2  Cache L3:    32 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4A  SSE4.1  SS...,                                                 0
# 0  Radeon Graphics dynamic frequency: 400-2200MHz], 'AMD Ryzen Threadripper 3970X': [                   0                1
# 0            Socket:  AMD Socket TRX4
# 1           Foundry:             TSMC
# 2      Process Size:             7 nm
# 3       Transistors:   15,200 million
# 4          Die Size:        4x 74 mm²
# 5  I/O Process Size:            14 nm
# 6      I/O Die Size:          416 mm²
# 7           Package:            sTRX4
# 8          tCaseMax:             95°C,                     0                               1
# 0             Market:                         Desktop
# 1  Production Status:                          Active
# 2       Release Date:                  Nov 25th, 2019
# 3       Launch Price:                           $1999
# 4              Part#:  100-000000011 100-100000011WOF,                       0               1
# 0            Frequency:         3.7 GHz
# 1          Turbo Clock:   up to 4.5 GHz
# 2           Base Clock:         100 MHz
# 3           Multiplier:           37.0x
# 4  Multiplier Unlocked:             Yes
# 5                  TDP:           280 W
# 6                 FP32:  6,912.0 GFLOPS,                    0                                          1
# ...
# 0          Codename:                  Sapphire Rapids
# 1        Generation:  Xeon Gold  (Sapphire Rapids-SP)
# 2    Memory Support:                             DDR5
# 3       Rated Speed:                        4800 MT/s
# 4        Memory Bus:                    Eight-channel
# 5  Memory Bandwidth:                       307.2 GB/s
# 6        ECC Memory:                              Yes
# 7       PCI-Express:       Gen 5, 80 Lanes (CPU only)
# 8           Chipset:                             C741,                       0     1
# 0           # of Cores:  32.0
# 1  High Priority Cores:  12.0
# 2   Low Priority Cores:  20.0
# 3         # of Threads:  64.0
# 4    AVX-512 FMA Ports:   2.0
# 5           SMP # CPUs:   1.0
# 6  Integrated Graphics:   NaN,            0                 1
# 0  Cache L1:  80 KB (per core)
# 1  Cache L2:   2 MB (per core)
# 2  Cache L3:             60 MB,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  PCI-Express PHY handles 16-Lanes of PCI-E 5.0 ...], 'Intel Xeon Gold 5416S': [               0                  1
# 0        Socket:  Intel Socket 4677
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3       Package:          FC-LGA16A
# 4      tCaseMax:               79°C,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:              Active
# 2       Release Date:      Jan 10th, 2023
# 3       Launch Price:                $944
# 4              Part#:               SRMH2,                            0            1
# 0                 Frequency:     2000 MHz
# 1               Turbo Clock:  up to 4 GHz
# 2            All Core Turbo:      2.8 GHz
# 3  High Priority Core Freq.:      2.1 GHz
# 4   Low Priority Core Freq.:      1.7 GHz
# 5                Base Clock:      100 MHz
# 6                Multiplier:        20.0x
# 7       Multiplier Unlocked:           No
# 8                       TDP:        150 W,                    0                                1
# 0          Codename:                  Sapphire Rapids
# 1        Generation:  Xeon Gold  (Sapphire Rapids-SP)
# 2    Memory Support:                             DDR5
# 3       Rated Speed:                        4400 MT/s
# 4        Memory Bus:                    Eight-channel
# 5  Memory Bandwidth:                       281.6 GB/s
# 6        ECC Memory:                              Yes
# 7       PCI-Express:       Gen 5, 80 Lanes (CPU only)
# 8         UPI Links:                     3 x24 16GT/s
# 9           Chipset:                             C741,                       0     1
# 0           # of Cores:  16.0
# 1  High Priority Cores:   4.0
# 2   Low Priority Cores:  12.0
# 3         # of Threads:  32.0
# 4    AVX-512 FMA Ports:   2.0
# 5           SMP # CPUs:   2.0
# 6  Integrated Graphics:   NaN,            0                 1
# 0  Cache L1:  80 KB (per core)
# 1  Cache L2:   2 MB (per core)
# 2  Cache L3:             30 MB,                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  Each PCI-Express PHY handles 16-Lanes of PCI-E...], 'Intel Xeon E5-2687W 0': [               0                  1
# 0        Socket:  Intel Socket 2011
# 1       Foundry:              Intel
# 2  Process Size:              32 nm
# 3   Transistors:      2,270 million
# 4      Die Size:            435 mm²
# 5       Package:           FC-LGA10,                     0                   1
# 0             Market:  Server/Workstation
# 1  Production Status:             unknown
# 2       Release Date:       Mar 6th, 2012
# 3              Part#:         SR0GX SR0KG,                       0              1
# 0            Frequency:        3.1 GHz
# 1          Turbo Clock:  up to 3.8 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          31.0x
# 4  Multiplier Unlocked:             No
# 5              Voltage:         1.35 V
# 6                  TDP:          150 W,                  0                           1
# 0        Codename:             Sandy Bridge-EP
# 1      Generation:  Xeon E5  (Sandy Bridge-EP)
# 2  Memory Support:                        DDR3
# 3      Memory Bus:                Quad-channel
# 4      ECC Memory:                         Yes
# 5     PCI-Express:                       Gen 3,                       0     1
# 0           # of Cores:   8.0
# 1         # of Threads:  16.0
# 2           SMP # CPUs:   2.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  256 KB (per core)
# 2  Cache L3:     20 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  EIST...], 'Intel Core i7-12700KF': [               0                  1
# 0        Socket:  Intel Socket 1700
# 1       Foundry:              Intel
# 2  Process Size:              10 nm
# 3      Die Size:            215 mm²
# 4       Package:          FC-LGA16A
# 5      tCaseMax:               72°C
# 6         tJMax:              100°C,                     0              1
# 0             Market:        Desktop
# 1  Production Status:         Active
# 2       Release Date:  Nov 4th, 2021
# 3       Launch Price:           $384
# 4              Part#:          SRL4P,                       0                       1
# 0            Frequency:                 3.6 GHz
# 1          Turbo Clock:             up to 5 GHz
# 2     E-Core Frequency:  2.7 GHz  up to 3.8 GHz
# 3           Base Clock:                 100 MHz
# 4           Multiplier:                   36.0x
# 5  Multiplier Unlocked:                     Yes
# 6                  TDP:                   125 W
# 7                  PL1:                    190W
# 8                  PL2:                    190W
# 9        PL2 Tau Limit:               Unlimited,                  0                           1
# 0        Codename:                Alder Lake-S
# 1      Generation:     Core i7  (Alder Lake-S)
# 2  Memory Support:                  DDR4, DDR5
# 3      DDR4 Speed:                   3200 MT/s
# 4      DDR5 Speed:                   4800 MT/s
# 5      Memory Bus:                Dual-channel
# 6      ECC Memory:                          No
# 7     PCI-Express:  Gen 4, 20 Lanes (CPU only)
# 8        Chipsets:      Z690, H670, B660, H610,                       0                       1
# 0           # of Cores:                      12
# 1         # of Threads:                      20
# 2         Hybrid Cores:  P-Cores: 8  E-Cores: 4
# 3           SMP # CPUs:                       1
# 4  Integrated Graphics:                     NaN,            0                   1
# 0  Cache L1:    80 KB (per core)
# 1  Cache L2:  1.25 MB (per core)
# 2  Cache L3:      25 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...], 'Intel Xeon Gold 6144': [               0                  1
# 0        Socket:  Intel Socket 3647
# 1       Foundry:              Intel
# 2  Process Size:              14 nm
# 3   Transistors:      8,000 million
# 4       Package:         FC-LGA3647,                     0                      1
# 0             Market:     Server/Workstation
# 1  Production Status:                unknown
# 2       Release Date:         Jul 11th, 2017
# 3              Part#:  SR3J5 CD8067303592700,                       0              1
# 0            Frequency:          3 GHz
# 1          Turbo Clock:  up to 3.7 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          30.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:          200 W,                  0                        1
# 0        Codename:               Skylake-SP
# 1      Generation:  Xeon Gold  (Skylake-SP)
# 2  Memory Support:                     DDR4
# 3      ECC Memory:                      Yes,                       0     1
# 0           # of Cores:  18.0
# 1         # of Threads:  36.0
# 2           SMP # CPUs:   4.0
# 3  Integrated Graphics:   NaN,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:    1 MB (per core)
# 2  Cache L3:  24.75 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...], 'Intel Core i7-1185G7E': [               0               1
# 0        Socket:  Intel BGA 1449
# 1       Foundry:           Intel
# 2  Process Size:           10 nm
# 3      Die Size:         144 mm²
# 4       Package:      FC-BGA1449
# 5         tJMax:           100°C,                     0              1
# 0             Market:         Mobile
# 1  Production Status:         Active
# 2       Release Date:  Sep 2nd, 2020
# 3       Launch Price:           $431
# 4              Part#:          SRK0X,                          0              1
# 0               Frequency:       1800 MHz
# 1      TDP-down Frequency:       1200 MHz
# 2        TDP-up Frequency:        2.8 GHz
# 3             Turbo Clock:  up to 4.4 GHz
# 4          All-Core Turbo:  up to 3.9 GHz
# 5              Base Clock:        100 MHz
# 6              Multiplier:          18.0x
# 7     Multiplier Unlocked:             No
# 8                     TDP:           15 W
# 9   Configurable TDP-down:           12 W
# 10    Configurable TDP-up:           28 W
# 11                    PL1:        12-28 W
# 12                    PL2:           52 W,                  0                          1
# 0        Codename:               Tiger Lake-U
# 1      Generation:   Core i7  (Willow Cove-U)
# 2  Memory Support:              DDR4, LPDDR4X
# 3      DDR4 Speed:                  3200 MT/s
# 4   LPDDR4x Speed:                  4267 MT/s
# 5      Memory Bus:               Dual-channel
# 6      ECC Memory:                         No
# 7     PCI-Express:  Gen 4, 4 Lanes (CPU only),                       0                            1
# 0           # of Cores:                            4
# 1         # of Threads:                            8
# 2           SMP # CPUs:                            1
# 3  Integrated Graphics:  Iris Xe-LP Graphics G7 96EU,            0                   1
# 0  Cache L1:    80 KB (per core)
# 1  Cache L2:  1.25 MB (per core)
# 2  Cache L3:      12 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  Iris Xe dynamic frequency: 1350 MHz Embedded s...], 'Intel Core i3-1005G1': [               0               1
# 0        Socket:  Intel BGA 1526
# 1       Foundry:           Intel
# 2  Process Size:           10 nm
# 3      Die Size:         123 mm²
# 4       Package:       FC-BGA16F
# 5      tCaseMax:            72°C,                     0              1
# 0             Market:         Mobile
# 1  Production Status:         Active
# 2       Release Date:  Aug 1st, 2019
# 3               MSRP:           $281
# 4              Part#:    SRG0S SRGKF,                       0              1
# 0            Frequency:       1200 MHz
# 1          Turbo Clock:  up to 3.4 GHz
# 2           Base Clock:        100 MHz
# 3           Multiplier:          12.0x
# 4  Multiplier Unlocked:             No
# 5                  TDP:           15 W
# 6            TDP Range:         13-15W,                    0                        1
# 0          Codename:               Ice Lake-U
# 1        Generation:  Core i3  (Sunny Cove-U)
# 2    Memory Support:                     DDR4
# 3      LPDDR4 Speed:                3733 MT/s
# 4       Rated Speed:                3200 MT/s
# 5        Memory Bus:             Dual-channel
# 6  Memory Bandwidth:                51.2 GB/s
# 7        ECC Memory:                       No
# 8       PCI-Express:                    Gen 3,                       0             1
# 0           # of Cores:             2
# 1         # of Threads:             4
# 2           SMP # CPUs:             1
# 3  Integrated Graphics:  UHD Graphics,            0                  1
# 0  Cache L1:   64 KB (per core)
# 1  Cache L2:  256 KB (per core)
# 2  Cache L3:      4 MB (shared),                                                    0
# 0  MMX  SSE  SSE2  SSE3  SSSE3  SSE4.2  AVX  AVX2...,                                                    0
# 0  UHD Graphics dynamic frequency: 900MHz TDP con...]}, 'errors': {}, 'resolved': {'AMD Ryzen 9 9950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-9950x.c3649', 'AMD RYZEN AI MAX+ 395': 'https://www.techpowerup.com/cpu-specs/ryzen-ai-max-395.c3994', 'Intel Core i9-13900K': 'https://www.techpowerup.com/cpu-specs/core-i9-13900k.c2817', 'AMD Ryzen 7 7700X': 'https://www.techpowerup.com/cpu-specs/ryzen-7-7700x.c2848', 'AMD Ryzen 9 7950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-7950x.c2846', 'Intel Core i9-14900K': 'https://www.techpowerup.com/cpu-specs/core-i9-14900k.c3269', 'AMD EPYC 4364P': 'https://www.techpowerup.com/cpu-specs/epyc-4364p.c3611', 'AMD Ryzen 9 7900X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-7900x.c2847', 'Intel Core i9-12900K': 'https://www.techpowerup.com/cpu-specs/core-i9-12900k.c2505', 'AMD EPYC 4564P': 'https://www.techpowerup.com/cpu-specs/epyc-4564p.c3613', 'AMD EPYC 4464P': 'https://www.techpowerup.com/cpu-specs/epyc-4464p.c3612', 'AMD EPYC 4584PX': 'https://www.techpowerup.com/cpu-specs/epyc-4584px.c3607', 'AMD EPYC 4484PX': 'https://www.techpowerup.com/cpu-specs/epyc-4484px.c3606', 'AMD Ryzen 9 5900X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-5900x.c2363', 'AMD Ryzen 5 7600X': 'https://www.techpowerup.com/cpu-specs/ryzen-5-7600x.c2849', 'Intel Core i9-11900K': 'https://www.techpowerup.com/cpu-specs/core-i9-11900k.c2366', 'AMD Ryzen 9 5950X': 'https://www.techpowerup.com/cpu-specs/ryzen-9-5950x.c2364', 'AMD Ryzen 7 5800X': 'https://www.techpowerup.com/cpu-specs/ryzen-7-5800x.c2362', 'AMD Ryzen 7 5800X3D': 'https://www.techpowerup.com/cpu-specs/ryzen-7-5800x3d.c2532', 'Intel Core i9-10900K': 'https://www.techpowerup.com/cpu-specs/core-i9-10900k.c2266', 'Intel Core i5-13600K': 'https://www.techpowerup.com/cpu-specs/core-i5-13600k.c2829', 'AMD EPYC 4124P': 'https://www.techpowerup.com/cpu-specs/epyc-4124p.c3610', 'AMD Ryzen Threadripper 3970X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3970x.c2269', 'AMD Ryzen Threadripper 3990X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3990x.c2271', 'AMD Ryzen 9 3900XT': 'https://www.techpowerup.com/cpu-specs/ryzen-9-3900xt.c2308', 'Intel Core i5-12600K': 'https://www.techpowerup.com/cpu-specs/core-i5-12600k.c2509', 'Intel Core i7-7900X': 'https://www.techpowerup.com/cpu-specs/core-i7-7800x.c1905', 'Intel Core i5-11600K': 'https://www.techpowerup.com/cpu-specs/core-i5-11600k.c2400', 'Intel Core i9-7980XE': 'https://www.techpowerup.com/cpu-specs/core-i9-7980xe.c1952', 'Intel Core i5-13400': 'https://www.techpowerup.com/cpu-specs/core-i5-13400.c2994', 'AMD Ryzen 7 PRO 5850U': 'https://www.techpowerup.com/cpu-specs/ryzen-7-pro-5850u.c2774', 'AMD Ryzen Threadripper 2990WX': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-2990wx.c2069', 'AMD Ryzen 7 PRO 6850U': 'https://www.techpowerup.com/cpu-specs/ryzen-7-pro-6850u.c2768', 'AMD Ryzen 5 3600XT': 'https://www.techpowerup.com/cpu-specs/ryzen-5-3600xt.c2313', 'AMD EPYC 73F3': 'https://www.techpowerup.com/cpu-specs/epyc-73f3.c2387', 'AMD EPYC 75F3': 'https://www.techpowerup.com/cpu-specs/epyc-75f3.c2378', 'AMD Ryzen Threadripper 3960X': 'https://www.techpowerup.com/cpu-specs/ryzen-threadripper-3960x.c2268', 'AMD EPYC 74F3': 'https://www.techpowerup.com/cpu-specs/epyc-74f3.c2383', 'Intel Xeon E-2278GEL': 'https://www.techpowerup.com/cpu-specs/xeon-e-2278gel.c3487', 'AMD Ryzen 7 1700 Eight-Core': 'https://www.techpowerup.com/cpu-specs/ryzen-7-1700.c1893', 'AMD EPYC 7713': 'https://www.techpowerup.com/cpu-specs/epyc-7713.c2374', 'Intel Core i9-9900KS': 'https://www.techpowerup.com/cpu-specs/core-i9-9900ks.c2242', 'AMD EPYC 7F52': 'https://www.techpowerup.com/cpu-specs/epyc-7f52.c2301', 'Intel Core i9-9900K': 'https://www.techpowerup.com/cpu-specs/core-i9-9900k.c2098', 'AMD EPYC 7513': 'https://www.techpowerup.com/cpu-specs/epyc-7513.c2381', 'AMD EPYC 7763': 'https://www.techpowerup.com/cpu-specs/epyc-7763.c2373', 'AMD Ryzen 5 4500U': 'https://www.techpowerup.com/cpu ...
